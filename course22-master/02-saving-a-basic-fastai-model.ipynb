# %% [markdown]
# ## Saving a Cats v Dogs Model

# %% [markdown]
# This is a minimal example showing how to train a fastai model on Kaggle, and save it so you can use it in your app.

# %%
# Make sure we've got the latest version of fastai:
#!pip install -Uqq fastai

# %% [markdown]
# First, import all the stuff we need from fastai:

# %%
from fastai.vision.all import *

# %% [markdown]
# Download and decompress our dataset, which is pictures of dogs and cats:

# %%
path = untar_data(URLs.PETS)/'images'

# %% [markdown]
# We need a way to label our images as dogs or cats. In this dataset, pictures of cats are given a filename that starts with a capital letter:

# %%
print(path)
# Out:
# C:\Users\josef\.fastai\data\oxford-iiit-pet\images

# %%
def is_cat(x): 
    print('is_cat',x[0],x[1])
    return x[0].isupper()

# %% [markdown]
# Now we can create our `DataLoaders`:

# %%
dls = ImageDataLoaders.from_name_func('.',
    get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_cat,
    item_tfms=Resize(192))
# Out:
# is_cat s
# is_cat R
# is_cat s
# is_cat j
# is_cat b
# is_cat R
# is_cat g
# is_cat k
# is_cat A
# is_cat p
# is_cat l
# is_cat a
# is_cat s
# is_cat S
# is_cat M
# is_cat g
# is_cat m
# is_cat e
# is_cat R
# is_cat m
# is_cat R
# is_cat a
# is_cat R
# is_cat g
# is_cat B
# is_cat s
# is_cat p
# is_cat m
# is_cat b
# is_cat j
# is_cat S
# is_cat P
# is_cat B
# is_cat b
# is_cat B
# is_cat g
# is_cat s
# is_cat E
# is_cat s
# is_cat j
# is_cat b
# is_cat k
# is_cat p
# is_cat S
# is_cat S
# is_cat R
# is_cat s
# is_cat s
# is_cat h
# is_cat a
# is_cat B
# is_cat e
# is_cat A
# is_cat B
# is_cat h
# is_cat c
# is_cat l
# is_cat S
# is_cat s
# is_cat l
# is_cat p
# is_cat S
# is_cat A
# is_cat R
# is_cat w
# is_cat R
# is_cat y
# is_cat p
# is_cat s
# is_cat c
# is_cat b
# is_cat s
# is_cat e
# is_cat s
# is_cat h
# is_cat l
# is_cat B
# is_cat b
# is_cat y
# is_cat l
# is_cat e
# is_cat s
# is_cat b
# is_cat a
# is_cat S
# is_cat B
# is_cat y
# is_cat a
# is_cat y
# is_cat B
# is_cat B
# is_cat S
# is_cat M
# is_cat A
# is_cat s
# is_cat b
# is_cat B
# is_cat a
# is_cat S
# is_cat B
# is_cat y
# is_cat b
# is_cat b
# is_cat E
# is_cat B
# is_cat y
# is_cat h
# is_cat h
# is_cat s
# is_cat a
# is_cat A
# is_cat A
# is_cat S
# is_cat R
# is_cat n
# is_cat S
# is_cat n
# is_cat M
# is_cat g
# is_cat s
# is_cat a
# is_cat y
# is_cat B
# is_cat n
# is_cat E
# is_cat b
# is_cat s
# is_cat B
# is_cat k
# is_cat g
# is_cat B
# is_cat j
# is_cat b
# is_cat p
# is_cat b
# is_cat c
# is_cat E
# is_cat B
# is_cat E
# is_cat e
# is_cat S
# is_cat y
# is_cat E
# is_cat n
# is_cat e
# is_cat h
# is_cat n
# is_cat B
# is_cat y
# is_cat l
# is_cat p
# is_cat a
# is_cat s
# is_cat s
# is_cat B
# is_cat B
# is_cat s
# is_cat p
# is_cat A
# is_cat b
# is_cat s
# is_cat h
# is_cat B
# is_cat R
# is_cat E
# is_cat s
# is_cat s
# is_cat a
# is_cat A
# is_cat s
# is_cat k
# is_cat a
# is_cat w
# is_cat j
# is_cat B
# is_cat j
# is_cat P
# is_cat a
# is_cat j
# is_cat S
# is_cat h
# is_cat s
# is_cat k
# is_cat s
# is_cat c
# is_cat B
# is_cat g
# is_cat b
# is_cat a
# is_cat g
# is_cat s
# is_cat y
# is_cat S
# is_cat B
# is_cat e
# is_cat c
# is_cat p
# is_cat h
# is_cat g
# is_cat s
# is_cat a
# is_cat n
# is_cat M
# is_cat y
# is_cat B
# is_cat b
# is_cat a
# is_cat E
# is_cat p
# is_cat R
# is_cat B
# is_cat b
# is_cat P
# is_cat R
# is_cat B
# is_cat y
# is_cat h
# is_cat k
# is_cat A
# is_cat y
# is_cat a
# is_cat B
# is_cat e
# is_cat a
# is_cat B
# is_cat S
# is_cat w
# is_cat g
# is_cat m
# is_cat s
# is_cat B
# is_cat E
# is_cat s
# is_cat s
# is_cat y
# is_cat s
# is_cat s
# is_cat B
# is_cat s
# is_cat s
# is_cat c
# is_cat a
# is_cat h
# is_cat B
# is_cat S
# is_cat a
# is_cat a
# is_cat g
# is_cat y
# is_cat R
# is_cat S
# is_cat B
# is_cat S
# is_cat P
# is_cat j
# is_cat b
# is_cat s
# is_cat g
# is_cat e
# is_cat B
# is_cat g
# is_cat s
# is_cat b
# is_cat R
# is_cat e
# is_cat e
# is_cat s
# is_cat k
# is_cat a
# is_cat A
# is_cat k
# is_cat s
# is_cat a
# is_cat p
# is_cat S
# is_cat R
# is_cat B
# is_cat R
# is_cat E
# is_cat l
# is_cat e
# is_cat y
# is_cat M
# is_cat s
# is_cat c
# is_cat g
# is_cat j
# is_cat A
# is_cat g
# is_cat R
# is_cat R
# is_cat A
# is_cat B
# is_cat a
# is_cat e
# is_cat c
# is_cat S
# is_cat S
# is_cat g
# is_cat R
# is_cat e
# is_cat h
# is_cat j
# is_cat B
# is_cat M
# is_cat y
# is_cat R
# is_cat M
# is_cat a
# is_cat g
# is_cat p
# is_cat p
# is_cat m
# is_cat s
# is_cat m
# is_cat E
# is_cat s
# is_cat b
# is_cat R
# is_cat B
# is_cat B
# is_cat s
# is_cat k
# is_cat h
# is_cat s
# is_cat S
# is_cat g
# is_cat B
# is_cat w
# is_cat R
# is_cat l
# is_cat B
# is_cat b
# is_cat R
# is_cat w
# is_cat c
# is_cat E
# is_cat j
# is_cat B
# is_cat w
# is_cat R
# is_cat s
# is_cat e
# is_cat R
# is_cat g
# is_cat w
# is_cat M
# is_cat e
# is_cat l
# is_cat B
# is_cat B
# is_cat B
# is_cat B
# is_cat a
# is_cat R
# is_cat g
# is_cat B
# is_cat e
# is_cat b
# is_cat k
# is_cat c
# is_cat e
# is_cat p
# is_cat j
# is_cat l
# is_cat R
# is_cat R
# is_cat g
# is_cat h
# is_cat S
# is_cat b
# is_cat s
# is_cat R
# is_cat e
# is_cat k
# is_cat a
# is_cat l
# is_cat c
# is_cat S
# is_cat a
# is_cat l
# is_cat s
# is_cat g
# is_cat s
# is_cat g
# is_cat g
# is_cat b
# is_cat B
# is_cat p
# is_cat E
# is_cat s
# is_cat g
# is_cat b
# is_cat a
# is_cat n
# is_cat y
# is_cat s
# is_cat P
# is_cat s
# is_cat s
# is_cat M
# is_cat h
# is_cat A
# is_cat s
# is_cat s
# is_cat b
# is_cat s
# is_cat E
# is_cat E
# is_cat S
# is_cat m
# is_cat A
# is_cat s
# is_cat s
# is_cat j
# is_cat S
# is_cat s
# is_cat s
# is_cat b
# is_cat S
# is_cat B
# is_cat j
# is_cat s
# is_cat c
# is_cat s
# is_cat n
# is_cat n
# is_cat a
# is_cat P
# is_cat p
# is_cat B
# is_cat n
# is_cat c
# is_cat a
# is_cat S
# is_cat j
# is_cat B
# is_cat e
# is_cat w
# is_cat B
# is_cat a
# is_cat B
# is_cat l
# is_cat j
# is_cat s
# is_cat p
# is_cat R
# is_cat s
# is_cat a
# is_cat B
# is_cat j
# is_cat S
# is_cat s
# is_cat y
# is_cat E
# is_cat e
# is_cat m
# is_cat e
# is_cat R
# is_cat e
# is_cat b
# is_cat B
# is_cat R
# is_cat B
# is_cat a
# is_cat a
# is_cat g
# is_cat p
# is_cat a
# is_cat B
# is_cat p
# is_cat g
# is_cat B
# is_cat E
# is_cat l
# is_cat s
# is_cat M
# is_cat l
# is_cat S
# is_cat e
# is_cat a
# is_cat A
# is_cat s
# is_cat g
# is_cat e
# is_cat S
# is_cat B
# is_cat j
# is_cat n
# is_cat R
# is_cat k
# is_cat M
# is_cat S
# is_cat B
# is_cat b
# is_cat B
# is_cat m
# is_cat P
# is_cat R
# is_cat s
# is_cat b
# is_cat c
# is_cat p
# is_cat B
# is_cat m
# is_cat e
# is_cat j
# is_cat S
# is_cat w
# is_cat p
# is_cat n
# is_cat p
# is_cat e
# is_cat a
# is_cat s
# is_cat a
# is_cat k
# is_cat w
# is_cat p
# is_cat S
# is_cat M
# is_cat e
# is_cat B
# is_cat y
# is_cat b
# is_cat w
# is_cat b
# is_cat n
# is_cat h
# is_cat n
# is_cat n
# is_cat B
# is_cat R
# is_cat M
# is_cat P
# is_cat a
# is_cat g
# is_cat k
# is_cat s
# is_cat B
# is_cat a
# is_cat j
# is_cat c
# is_cat e
# is_cat b
# is_cat s
# is_cat s
# is_cat P
# is_cat e
# is_cat b
# is_cat m
# is_cat b
# is_cat l
# is_cat j
# is_cat c
# is_cat g
# is_cat b
# is_cat h
# is_cat s
# is_cat M
# is_cat p
# is_cat g
# is_cat b
# is_cat s
# is_cat l
# is_cat b
# is_cat l
# is_cat s
# is_cat P
# is_cat A
# is_cat e
# is_cat n
# is_cat y
# is_cat M
# is_cat B
# is_cat b
# is_cat e
# is_cat a
# is_cat B
# is_cat g
# is_cat S
# is_cat s
# is_cat e
# is_cat s
# is_cat B
# is_cat g
# is_cat R
# is_cat p
# is_cat B
# is_cat a
# is_cat S
# is_cat s
# is_cat b
# is_cat R
# is_cat a
# is_cat E
# is_cat M
# is_cat B
# is_cat l
# is_cat B
# is_cat c
# is_cat M
# is_cat S
# is_cat a
# is_cat p
# is_cat a
# is_cat s
# is_cat P
# is_cat c
# is_cat s
# is_cat c
# is_cat b
# is_cat s
# is_cat m
# is_cat s
# is_cat p
# is_cat R
# is_cat R
# is_cat g
# is_cat m
# is_cat g
# is_cat B
# is_cat b
# is_cat a
# is_cat e
# is_cat l
# is_cat s
# is_cat y
# is_cat A
# is_cat s
# is_cat w
# is_cat M
# is_cat k
# is_cat k
# is_cat s
# is_cat s
# is_cat S
# is_cat s
# is_cat P
# is_cat B
# is_cat e
# is_cat h
# is_cat g
# is_cat B
# is_cat e
# is_cat S
# is_cat M
# is_cat P
# is_cat n
# is_cat j
# is_cat m
# is_cat n
# is_cat s
# is_cat a
# is_cat s
# is_cat y
# is_cat P
# is_cat e
# is_cat R
# is_cat E
# is_cat p
# is_cat k
# is_cat m
# is_cat S
# is_cat B
# is_cat B
# is_cat h
# is_cat h
# is_cat b
# is_cat s
# is_cat E
# is_cat s
# is_cat M
# is_cat j
# is_cat s
# is_cat B
# is_cat a
# is_cat A
# is_cat s
# is_cat y
# is_cat P
# is_cat B
# is_cat j
# is_cat s
# is_cat y
# is_cat m
# is_cat e
# is_cat B
# is_cat P
# is_cat a
# is_cat y
# is_cat b
# is_cat R
# is_cat g
# is_cat R
# is_cat g
# is_cat M
# is_cat g
# is_cat s
# is_cat E
# is_cat s
# is_cat g
# is_cat s
# is_cat w
# is_cat B
# is_cat b
# is_cat S
# is_cat a
# is_cat k
# is_cat g
# is_cat s
# is_cat b
# is_cat j
# is_cat s
# is_cat A
# is_cat n
# is_cat h
# is_cat M
# is_cat s
# is_cat s
# is_cat M
# is_cat R
# is_cat p
# is_cat e
# is_cat S
# is_cat s
# is_cat h
# is_cat h
# is_cat w
# is_cat s
# is_cat s
# is_cat B
# is_cat j
# is_cat s
# is_cat s
# is_cat n
# is_cat w
# is_cat S
# is_cat s
# is_cat y
# is_cat a
# is_cat b
# is_cat s
# is_cat g
# is_cat s
# is_cat P
# is_cat b
# is_cat l
# is_cat s
# is_cat b
# is_cat e
# is_cat a
# is_cat B
# is_cat h
# is_cat l
# is_cat s
# is_cat g
# is_cat e
# is_cat s
# is_cat p
# is_cat g
# is_cat b
# is_cat b
# is_cat g
# is_cat M
# is_cat s
# is_cat b
# is_cat e
# is_cat E
# is_cat S
# is_cat e
# is_cat s
# is_cat R
# is_cat S
# is_cat g
# is_cat s
# is_cat y
# is_cat b
# is_cat b
# is_cat m
# is_cat b
# is_cat b
# is_cat S
# is_cat b
# is_cat b
# is_cat c
# is_cat s
# is_cat E
# is_cat S
# is_cat M
# is_cat b
# is_cat R
# is_cat A
# is_cat k
# is_cat b
# is_cat P
# is_cat B
# is_cat b
# is_cat j
# is_cat B
# is_cat M
# is_cat s
# is_cat M
# is_cat b
# is_cat w
# is_cat R
# is_cat B
# is_cat g
# is_cat e
# is_cat e
# is_cat S
# is_cat A
# is_cat R
# is_cat s
# is_cat g
# is_cat B
# is_cat B
# is_cat B
# is_cat B
# is_cat R
# is_cat s
# is_cat S
# is_cat h
# is_cat E
# is_cat R
# is_cat b
# is_cat s
# is_cat p
# is_cat P
# is_cat a
# is_cat e
# is_cat R
# is_cat a
# is_cat S
# is_cat a
# is_cat s
# is_cat B
# is_cat g
# is_cat b
# is_cat g
# is_cat R
# is_cat g
# is_cat g
# is_cat p
# is_cat e
# is_cat S
# is_cat R
# is_cat j
# is_cat e
# is_cat B
# is_cat M
# is_cat B
# is_cat s
# is_cat a
# is_cat j
# is_cat M
# is_cat M
# is_cat S
# is_cat b
# is_cat a
# is_cat b
# is_cat n
# is_cat l
# is_cat e
# is_cat k
# is_cat b
# is_cat g
# is_cat b
# is_cat B
# is_cat B
# is_cat g
# is_cat s
# is_cat R
# is_cat n
# is_cat m
# is_cat g
# is_cat b
# is_cat B
# is_cat s
# is_cat p
# is_cat s
# is_cat h
# is_cat j
# is_cat m
# is_cat R
# is_cat b
# is_cat s
# is_cat B
# is_cat c
# is_cat B
# is_cat b
# is_cat g
# is_cat s
# is_cat e
# is_cat B
# is_cat w
# is_cat s
# is_cat E
# is_cat s
# is_cat R
# is_cat s
# is_cat s
# is_cat k
# is_cat B
# is_cat s
# is_cat g
# is_cat h
# is_cat R
# is_cat e
# is_cat B
# is_cat m
# is_cat h
# is_cat n
# is_cat B
# is_cat k
# is_cat B
# is_cat g
# is_cat s
# is_cat s
# is_cat c
# is_cat b
# is_cat b
# is_cat n
# is_cat y
# is_cat S
# is_cat A
# is_cat B
# is_cat a
# is_cat P
# is_cat B
# is_cat B
# is_cat b
# is_cat s
# is_cat B
# is_cat k
# is_cat n
# is_cat s
# is_cat a
# is_cat g
# is_cat n
# is_cat E
# is_cat s
# is_cat s
# is_cat l
# is_cat a
# is_cat R
# is_cat B
# is_cat B
# is_cat p
# is_cat s
# is_cat s
# is_cat A
# is_cat e
# is_cat n
# is_cat B
# is_cat M
# is_cat g
# is_cat l
# is_cat l
# is_cat b
# is_cat m
# is_cat c
# is_cat w
# is_cat R
# is_cat n
# is_cat p
# is_cat m
# is_cat s
# is_cat e
# is_cat B
# is_cat e
# is_cat s
# is_cat b
# is_cat p
# is_cat E
# is_cat R
# is_cat b
# is_cat A
# is_cat s
# is_cat j
# is_cat g
# is_cat k
# is_cat B
# is_cat s
# is_cat p
# is_cat P
# is_cat b
# is_cat g
# is_cat s
# is_cat n
# is_cat P
# is_cat a
# is_cat A
# is_cat S
# is_cat s
# is_cat p
# is_cat S
# is_cat a
# is_cat w
# is_cat c
# is_cat a
# is_cat g
# is_cat m
# is_cat B
# is_cat j
# is_cat S
# is_cat a
# is_cat w
# is_cat s
# is_cat s
# is_cat R
# is_cat B
# is_cat B
# is_cat w
# is_cat B
# is_cat A
# is_cat k
# is_cat p
# is_cat s
# is_cat e
# is_cat s
# is_cat B
# is_cat s
# is_cat s
# is_cat B
# is_cat R
# is_cat b
# is_cat R
# is_cat B
# is_cat s
# is_cat y
# is_cat l
# is_cat b
# is_cat S
# is_cat b
# is_cat s
# is_cat a
# is_cat l
# is_cat s
# is_cat R
# is_cat c
# is_cat M
# is_cat e
# is_cat p
# is_cat g
# is_cat y
# is_cat a
# is_cat e
# is_cat R
# is_cat R
# is_cat b
# is_cat e
# is_cat g
# is_cat k
# is_cat b
# is_cat j
# is_cat R
# is_cat p
# is_cat a
# is_cat S
# is_cat M
# is_cat S
# is_cat m
# is_cat S
# is_cat P
# is_cat w
# is_cat g
# is_cat B
# is_cat M
# is_cat m
# is_cat B
# is_cat j
# is_cat b
# is_cat p
# is_cat g
# is_cat p
# is_cat B
# is_cat E
# is_cat g
# is_cat S
# is_cat l
# is_cat A
# is_cat s
# is_cat M
# is_cat s
# is_cat R
# is_cat e
# is_cat R
# is_cat B
# is_cat s
# is_cat s
# is_cat s
# is_cat a
# is_cat B
# is_cat S
# is_cat B
# is_cat a
# is_cat n
# is_cat k
# is_cat y
# is_cat p
# is_cat B
# is_cat R
# is_cat g
# is_cat c
# is_cat p
# is_cat y
# is_cat s
# is_cat h
# is_cat c
# is_cat b
# is_cat a
# is_cat n
# is_cat g
# is_cat m
# is_cat s
# is_cat s
# is_cat m
# is_cat B
# is_cat p
# is_cat c
# is_cat b
# is_cat S
# is_cat e
# is_cat g
# is_cat B
# is_cat h
# is_cat c
# is_cat s
# is_cat B
# is_cat e
# is_cat w
# is_cat s
# is_cat B
# is_cat a
# is_cat g
# is_cat g
# is_cat w
# is_cat g
# is_cat j
# is_cat j
# is_cat b
# is_cat n
# is_cat n
# is_cat e
# is_cat e
# is_cat S
# is_cat j
# is_cat s
# is_cat S
# is_cat k
# is_cat m
# is_cat s
# is_cat M
# is_cat s
# is_cat s
# is_cat n
# is_cat k
# is_cat e
# is_cat h
# is_cat R
# is_cat S
# is_cat c
# is_cat B
# is_cat B
# is_cat B
# is_cat k
# is_cat S
# is_cat s
# is_cat a
# is_cat R
# is_cat S
# is_cat a
# is_cat w
# is_cat s
# is_cat s
# is_cat a
# is_cat b
# is_cat B
# is_cat S
# is_cat B
# is_cat y
# is_cat g
# is_cat B
# is_cat S
# is_cat S
# is_cat s
# is_cat w
# is_cat g
# is_cat l
# is_cat e
# is_cat p
# is_cat B
# is_cat E
# is_cat c
# is_cat m
# is_cat j
# is_cat R
# is_cat B
# is_cat s
# is_cat s
# is_cat g
# is_cat B
# is_cat s
# is_cat b
# is_cat c
# is_cat B
# is_cat j
# is_cat e
# is_cat B
# is_cat p
# is_cat a
# is_cat p
# is_cat w
# is_cat b
# is_cat g
# is_cat B
# is_cat s
# is_cat n
# is_cat b
# is_cat j
# is_cat w
# is_cat R
# is_cat g
# is_cat n
# is_cat s
# is_cat l
# is_cat a
# is_cat s
# is_cat S
# is_cat y
# is_cat R
# is_cat e
# is_cat a
# is_cat s
# is_cat S
# is_cat A
# is_cat m
# is_cat b
# is_cat B
# is_cat n
# is_cat k
# is_cat n
# is_cat p
# is_cat c
# is_cat R
# is_cat B
# is_cat g
# is_cat A
# is_cat w
# is_cat g
# is_cat h
# is_cat R
# is_cat h
# is_cat n
# is_cat R
# is_cat s
# is_cat w
# is_cat p
# is_cat s
# is_cat M
# is_cat j
# is_cat A
# is_cat M
# is_cat g
# is_cat B
# is_cat B
# is_cat j
# is_cat E
# is_cat g
# is_cat l
# is_cat s
# is_cat a
# is_cat g
# is_cat E
# is_cat B
# is_cat p
# is_cat s
# is_cat h
# is_cat a
# is_cat s
# is_cat k
# is_cat g
# is_cat p
# is_cat j
# is_cat E
# is_cat y
# is_cat e
# is_cat M
# is_cat P
# is_cat S
# is_cat M
# is_cat S
# is_cat l
# is_cat g
# is_cat g
# is_cat s
# is_cat w
# is_cat l
# is_cat B
# is_cat s
# is_cat B
# is_cat p
# is_cat P
# is_cat w
# is_cat g
# is_cat R
# is_cat j
# is_cat B
# is_cat n
# is_cat l
# is_cat M
# is_cat A
# is_cat S
# is_cat s
# is_cat g
# is_cat B
# is_cat k
# is_cat b
# is_cat l
# is_cat p
# is_cat B
# is_cat w
# is_cat m
# is_cat B
# is_cat a
# is_cat l
# is_cat b
# is_cat g
# is_cat e
# is_cat A
# is_cat B
# is_cat a
# is_cat b
# is_cat g
# is_cat b
# is_cat m
# is_cat s
# is_cat n
# is_cat s
# is_cat S
# is_cat b
# is_cat l
# is_cat k
# is_cat h
# is_cat n
# is_cat R
# is_cat M
# is_cat s
# is_cat A
# is_cat y
# is_cat a
# is_cat a
# is_cat B
# is_cat h
# is_cat g
# is_cat g
# is_cat b
# is_cat S
# is_cat s
# is_cat b
# is_cat R
# is_cat k
# is_cat S
# is_cat M
# is_cat n
# is_cat B
# is_cat s
# is_cat M
# is_cat P
# is_cat s
# is_cat h
# is_cat n
# is_cat A
# is_cat P
# is_cat s
# is_cat s
# is_cat a
# is_cat E
# is_cat m
# is_cat P
# is_cat e
# is_cat m
# is_cat A
# is_cat y
# is_cat s
# is_cat h
# is_cat n
# is_cat p
# is_cat k
# is_cat B
# is_cat w
# is_cat m
# is_cat l
# is_cat b
# is_cat b
# is_cat E
# is_cat s
# is_cat w
# is_cat e
# is_cat A
# is_cat b
# is_cat R
# is_cat R
# is_cat M
# is_cat e
# is_cat s
# is_cat j
# is_cat R
# is_cat S
# is_cat j
# is_cat B
# is_cat E
# is_cat k
# is_cat s
# is_cat s
# is_cat h
# is_cat c
# is_cat A
# is_cat m
# is_cat e
# is_cat P
# is_cat w
# is_cat b
# is_cat h
# is_cat s
# is_cat n
# is_cat s
# is_cat b
# is_cat a
# is_cat g
# is_cat y
# is_cat s
# is_cat a
# is_cat k
# is_cat S
# is_cat s
# is_cat R
# is_cat s
# is_cat y
# is_cat B
# is_cat b
# is_cat s
# is_cat k
# is_cat e
# is_cat s
# is_cat b
# is_cat R
# is_cat p
# is_cat b
# is_cat k
# is_cat m
# is_cat g
# is_cat l
# is_cat j
# is_cat R
# is_cat w
# is_cat M
# is_cat s
# is_cat S
# is_cat s
# is_cat S
# is_cat a
# is_cat e
# is_cat y
# is_cat p
# is_cat y
# is_cat S
# is_cat k
# is_cat h
# is_cat A
# is_cat g
# is_cat E
# is_cat w
# is_cat S
# is_cat E
# is_cat y
# is_cat l
# is_cat a
# is_cat g
# is_cat R
# is_cat k
# is_cat p
# is_cat p
# is_cat R
# is_cat m
# is_cat a
# is_cat B
# is_cat B
# is_cat e
# is_cat a
# is_cat w
# is_cat h
# is_cat a
# is_cat g
# is_cat e
# is_cat g
# is_cat h
# is_cat c
# is_cat l
# is_cat R
# is_cat s
# is_cat s
# is_cat A
# is_cat s
# is_cat s
# is_cat c
# is_cat g
# is_cat e
# is_cat A
# is_cat g
# is_cat c
# is_cat a
# is_cat E
# is_cat p
# is_cat b
# is_cat s
# is_cat g
# is_cat j
# is_cat p
# is_cat y
# is_cat P
# is_cat w
# is_cat j
# is_cat c
# is_cat l
# is_cat S
# is_cat A
# is_cat a
# is_cat s
# is_cat B
# is_cat E
# is_cat B
# is_cat a
# is_cat s
# is_cat s
# is_cat e
# is_cat l
# is_cat g
# is_cat l
# is_cat n
# is_cat m
# is_cat S
# is_cat s
# is_cat e
# is_cat B
# is_cat b
# is_cat c
# is_cat a
# is_cat s
# is_cat P
# is_cat e
# is_cat h
# is_cat b
# is_cat S
# is_cat c
# is_cat h
# is_cat b
# is_cat b
# is_cat w
# is_cat S
# is_cat A
# is_cat w
# is_cat s
# is_cat B
# is_cat R
# is_cat B
# is_cat b
# is_cat a
# is_cat e
# is_cat S
# is_cat M
# is_cat B
# is_cat e
# is_cat A
# is_cat s
# is_cat g
# is_cat B
# is_cat e
# is_cat n
# is_cat l
# is_cat S
# is_cat g
# is_cat s
# is_cat e
# is_cat c
# is_cat n
# is_cat E
# is_cat a
# is_cat b
# is_cat a
# is_cat B
# is_cat S
# is_cat e
# is_cat e
# is_cat s
# is_cat s
# is_cat s
# is_cat s
# is_cat a
# is_cat w
# is_cat s
# is_cat A
# is_cat B
# is_cat s
# is_cat s
# is_cat s
# is_cat S
# is_cat n
# is_cat M
# is_cat s
# is_cat y
# is_cat s
# is_cat n
# is_cat S
# is_cat s
# is_cat m
# is_cat S
# is_cat n
# is_cat p
# is_cat e
# is_cat l
# is_cat y
# is_cat s
# is_cat a
# is_cat s
# is_cat b
# is_cat R
# is_cat E
# is_cat B
# is_cat p
# is_cat R
# is_cat B
# is_cat B
# is_cat c
# is_cat A
# is_cat e
# is_cat b
# is_cat p
# is_cat M
# is_cat E
# is_cat P
# is_cat A
# is_cat w
# is_cat a
# is_cat R
# is_cat R
# is_cat s
# is_cat S
# is_cat g
# is_cat P
# is_cat g
# is_cat p
# is_cat S
# is_cat B
# is_cat E
# is_cat A
# is_cat P
# is_cat m
# is_cat l
# is_cat g
# is_cat s
# is_cat g
# is_cat g
# is_cat S
# is_cat a
# is_cat A
# is_cat b
# is_cat A
# is_cat S
# is_cat b
# is_cat s
# is_cat p
# is_cat y
# is_cat n
# is_cat h
# is_cat B
# is_cat p
# is_cat s
# is_cat R
# is_cat g
# is_cat w
# is_cat R
# is_cat w
# is_cat E
# is_cat s
# is_cat c
# is_cat e
# is_cat h
# is_cat p
# is_cat b
# is_cat B
# is_cat R
# is_cat n
# is_cat b
# is_cat s
# is_cat S
# is_cat B
# is_cat y
# is_cat k
# is_cat B
# is_cat s
# is_cat a
# is_cat e
# is_cat A
# is_cat k
# is_cat k
# is_cat b
# is_cat p
# is_cat s
# is_cat b
# is_cat b
# is_cat y
# is_cat p
# is_cat P
# is_cat g
# is_cat g
# is_cat B
# is_cat p
# is_cat e
# is_cat E
# is_cat s
# is_cat y
# is_cat s
# is_cat e
# is_cat R
# is_cat s
# is_cat j
# is_cat p
# is_cat A
# is_cat A
# is_cat e
# is_cat j
# is_cat e
# is_cat p
# is_cat s
# is_cat P
# is_cat c
# is_cat A
# is_cat B
# is_cat p
# is_cat b
# is_cat p
# is_cat w
# is_cat s
# is_cat s
# is_cat A
# is_cat k
# is_cat S
# is_cat j
# is_cat s
# is_cat g
# is_cat S
# is_cat w
# is_cat y
# is_cat e
# is_cat B
# is_cat s
# is_cat y
# is_cat B
# is_cat m
# is_cat y
# is_cat B
# is_cat B
# is_cat m
# is_cat b
# is_cat b
# is_cat h
# is_cat A
# is_cat k
# is_cat h
# is_cat s
# is_cat y
# is_cat s
# is_cat s
# is_cat R
# is_cat B
# is_cat y
# is_cat B
# is_cat g
# is_cat s
# is_cat R
# is_cat m
# is_cat E
# is_cat w
# is_cat b
# is_cat b
# is_cat p
# is_cat g
# is_cat g
# is_cat b
# is_cat e
# is_cat E
# is_cat M
# is_cat b
# is_cat m
# is_cat M
# is_cat b
# is_cat e
# is_cat R
# is_cat s
# is_cat g
# is_cat R
# is_cat m
# is_cat e
# is_cat E
# is_cat B
# is_cat b
# is_cat p
# is_cat s
# is_cat j
# is_cat b
# is_cat S
# is_cat s
# is_cat w
# is_cat e
# is_cat s
# is_cat g
# is_cat g
# is_cat S
# is_cat A
# is_cat B
# is_cat R
# is_cat b
# is_cat l
# is_cat p
# is_cat c
# is_cat p
# is_cat y
# is_cat n
# is_cat n
# is_cat p
# is_cat P
# is_cat p
# is_cat w
# is_cat p
# is_cat p
# is_cat a
# is_cat l
# is_cat e
# is_cat B
# is_cat s
# is_cat s
# is_cat p
# is_cat a
# is_cat B
# is_cat p
# is_cat g
# is_cat l
# is_cat E
# is_cat k
# is_cat s
# is_cat b
# is_cat A
# is_cat B
# is_cat s
# is_cat k
# is_cat k
# is_cat l
# is_cat k
# is_cat s
# is_cat s
# is_cat a
# is_cat c
# is_cat n
# is_cat P
# is_cat S
# is_cat R
# is_cat R
# is_cat a
# is_cat m
# is_cat g
# is_cat s
# is_cat R
# is_cat g
# is_cat S
# is_cat B
# is_cat S
# is_cat l
# is_cat S
# is_cat S
# is_cat a
# is_cat a
# is_cat s
# is_cat a
# is_cat l
# is_cat g
# is_cat p
# is_cat g
# is_cat c
# is_cat w
# is_cat B
# is_cat l
# is_cat h
# is_cat b
# is_cat B
# is_cat M
# is_cat h
# is_cat e
# is_cat s
# is_cat j
# is_cat B
# is_cat p
# is_cat p
# is_cat l
# is_cat B
# is_cat b
# is_cat p
# is_cat b
# is_cat p
# is_cat A
# is_cat a
# is_cat R
# is_cat B
# is_cat B
# is_cat s
# is_cat c
# is_cat s
# is_cat R
# is_cat s
# is_cat P
# is_cat p
# is_cat S
# is_cat b
# is_cat e
# is_cat b
# is_cat y
# is_cat b
# is_cat n
# is_cat s
# is_cat b
# is_cat b
# is_cat s
# is_cat k
# is_cat p
# is_cat E
# is_cat R
# is_cat a
# is_cat l
# is_cat p
# is_cat E
# is_cat e
# is_cat y
# is_cat m
# is_cat w
# is_cat s
# is_cat a
# is_cat B
# is_cat g
# is_cat p
# is_cat b
# is_cat a
# is_cat S
# is_cat S
# is_cat S
# is_cat A
# is_cat g
# is_cat p
# is_cat j
# is_cat B
# is_cat c
# is_cat R
# is_cat e
# is_cat e
# is_cat S
# is_cat e
# is_cat R
# is_cat e
# is_cat s
# is_cat R
# is_cat s
# is_cat h
# is_cat s
# is_cat a
# is_cat a
# is_cat s
# is_cat h
# is_cat R
# is_cat e
# is_cat E
# is_cat j
# is_cat R
# is_cat R
# is_cat S
# is_cat P
# is_cat m
# is_cat k
# is_cat B
# is_cat E
# is_cat a
# is_cat p
# is_cat w
# is_cat n
# is_cat a
# is_cat P
# is_cat B
# is_cat b
# is_cat p
# is_cat j
# is_cat s
# is_cat m
# is_cat b
# is_cat h
# is_cat s
# is_cat B
# is_cat w
# is_cat S
# is_cat j
# is_cat y
# is_cat R
# is_cat a
# is_cat b
# is_cat s
# is_cat e
# is_cat b
# is_cat g
# is_cat m
# is_cat R
# is_cat n
# is_cat l
# is_cat c
# is_cat h
# is_cat p
# is_cat P
# is_cat A
# is_cat y
# is_cat p
# is_cat S
# is_cat c
# is_cat P
# is_cat n
# is_cat e
# is_cat S
# is_cat B
# is_cat R
# is_cat g
# is_cat B
# is_cat p
# is_cat e
# is_cat s
# is_cat M
# is_cat R
# is_cat S
# is_cat A
# is_cat k
# is_cat l
# is_cat c
# is_cat w
# is_cat s
# is_cat a
# is_cat s
# is_cat m
# is_cat P
# is_cat e
# is_cat a
# is_cat B
# is_cat k
# is_cat s
# is_cat s
# is_cat w
# is_cat S
# is_cat P
# is_cat B
# is_cat s
# is_cat s
# is_cat P
# is_cat B
# is_cat R
# is_cat b
# is_cat M
# is_cat p
# is_cat b
# is_cat s
# is_cat B
# is_cat s
# is_cat m
# is_cat B
# is_cat n
# is_cat k
# is_cat b
# is_cat e
# is_cat B
# is_cat b
# is_cat b
# is_cat E
# is_cat B
# is_cat R
# is_cat w
# is_cat e
# is_cat y
# is_cat l
# is_cat A
# is_cat y
# is_cat l
# is_cat e
# is_cat h
# is_cat e
# is_cat s
# is_cat n
# is_cat R
# is_cat B
# is_cat w
# is_cat B
# is_cat b
# is_cat e
# is_cat B
# is_cat R
# is_cat l
# is_cat l
# is_cat g
# is_cat m
# is_cat B
# is_cat s
# is_cat b
# is_cat c
# is_cat R
# is_cat B
# is_cat m
# is_cat c
# is_cat w
# is_cat s
# is_cat b
# is_cat a
# is_cat s
# is_cat A
# is_cat M
# is_cat h
# is_cat S
# is_cat s
# is_cat s
# is_cat B
# is_cat b
# is_cat A
# is_cat b
# is_cat l
# is_cat E
# is_cat s
# is_cat l
# is_cat B
# is_cat P
# is_cat s
# is_cat P
# is_cat y
# is_cat P
# is_cat s
# is_cat b
# is_cat j
# is_cat B
# is_cat g
# is_cat e
# is_cat E
# is_cat k
# is_cat S
# is_cat P
# is_cat S
# is_cat j
# is_cat s
# is_cat e
# is_cat n
# is_cat b
# is_cat e
# is_cat a
# is_cat s
# is_cat P
# is_cat k
# is_cat E
# is_cat s
# is_cat k
# is_cat e
# is_cat y
# is_cat k
# is_cat s
# is_cat h
# is_cat j
# is_cat b
# is_cat s
# is_cat E
# is_cat E
# is_cat A
# is_cat P
# is_cat B
# is_cat p
# is_cat P
# is_cat B
# is_cat s
# is_cat s
# is_cat g
# is_cat M
# is_cat R
# is_cat M
# is_cat B
# is_cat p
# is_cat B
# is_cat P
# is_cat w
# is_cat n
# is_cat a
# is_cat g
# is_cat a
# is_cat B
# is_cat p
# is_cat s
# is_cat a
# is_cat n
# is_cat e
# is_cat k
# is_cat p
# is_cat M
# is_cat M
# is_cat s
# is_cat s
# is_cat A
# is_cat c
# is_cat m
# is_cat g
# is_cat c
# is_cat n
# is_cat R
# is_cat R
# is_cat R
# is_cat s
# is_cat e
# is_cat s
# is_cat p
# is_cat b
# is_cat b
# is_cat c
# is_cat R
# is_cat n
# is_cat B
# is_cat e
# is_cat k
# is_cat m
# is_cat S
# is_cat s
# is_cat w
# is_cat b
# is_cat s
# is_cat B
# is_cat y
# is_cat a
# is_cat g
# is_cat e
# is_cat S
# is_cat e
# is_cat j
# is_cat c
# is_cat A
# is_cat B
# is_cat s
# is_cat e
# is_cat S
# is_cat B
# is_cat g
# is_cat s
# is_cat P
# is_cat B
# is_cat y
# is_cat B
# is_cat e
# is_cat c
# is_cat b
# is_cat a
# is_cat E
# is_cat P
# is_cat B
# is_cat s
# is_cat p
# is_cat B
# is_cat M
# is_cat m
# is_cat B
# is_cat j
# is_cat s
# is_cat R
# is_cat M
# is_cat S
# is_cat s
# is_cat k
# is_cat p
# is_cat e
# is_cat R
# is_cat h
# is_cat b
# is_cat E
# is_cat e
# is_cat b
# is_cat e
# is_cat a
# is_cat b
# is_cat g
# is_cat R
# is_cat n
# is_cat b
# is_cat s
# is_cat p
# is_cat g
# is_cat n
# is_cat A
# is_cat h
# is_cat c
# is_cat a
# is_cat p
# is_cat w
# is_cat p
# is_cat w
# is_cat b
# is_cat w
# is_cat S
# is_cat E
# is_cat c
# is_cat S
# is_cat e
# is_cat p
# is_cat B
# is_cat c
# is_cat j
# is_cat b
# is_cat m
# is_cat S
# is_cat s
# is_cat s
# is_cat S
# is_cat g
# is_cat l
# is_cat B
# is_cat b
# is_cat e
# is_cat e
# is_cat b
# is_cat w
# is_cat M
# is_cat e
# is_cat E
# is_cat p
# is_cat e
# is_cat s
# is_cat n
# is_cat k
# is_cat y
# is_cat B
# is_cat B
# is_cat w
# is_cat b
# is_cat P
# is_cat s
# is_cat B
# is_cat R
# is_cat a
# is_cat s
# is_cat M
# is_cat B
# is_cat s
# is_cat e
# is_cat n
# is_cat P
# is_cat l
# is_cat e
# is_cat b
# is_cat B
# is_cat R
# is_cat k
# is_cat a
# is_cat b
# is_cat S
# is_cat A
# is_cat g
# is_cat B
# is_cat p
# is_cat s
# is_cat S
# is_cat y
# is_cat s
# is_cat E
# is_cat n
# is_cat y
# is_cat A
# is_cat c
# is_cat s
# is_cat s
# is_cat a
# is_cat b
# is_cat y
# is_cat A
# is_cat n
# is_cat l
# is_cat g
# is_cat l
# is_cat R
# is_cat h
# is_cat g
# is_cat E
# is_cat B
# is_cat s
# is_cat e
# is_cat s
# is_cat s
# is_cat S
# is_cat p
# is_cat s
# is_cat s
# is_cat B
# is_cat m
# is_cat B
# is_cat s
# is_cat g
# is_cat M
# is_cat B
# is_cat B
# is_cat B
# is_cat k
# is_cat a
# is_cat A
# is_cat e
# is_cat b
# is_cat s
# is_cat y
# is_cat R
# is_cat w
# is_cat p
# is_cat s
# is_cat h
# is_cat B
# is_cat a
# is_cat e
# is_cat A
# is_cat s
# is_cat s
# is_cat s
# is_cat A
# is_cat S
# is_cat h
# is_cat R
# is_cat B
# is_cat c
# is_cat k
# is_cat b
# is_cat c
# is_cat b
# is_cat B
# is_cat R
# is_cat m
# is_cat B
# is_cat g
# is_cat R
# is_cat b
# is_cat S
# is_cat P
# is_cat g
# is_cat n
# is_cat A
# is_cat l
# is_cat s
# is_cat S
# is_cat s
# is_cat A
# is_cat e
# is_cat w
# is_cat b
# is_cat s
# is_cat s
# is_cat b
# is_cat b
# is_cat m
# is_cat P
# is_cat s
# is_cat R
# is_cat B
# is_cat P
# is_cat l
# is_cat P
# is_cat s
# is_cat s
# is_cat R
# is_cat w
# is_cat S
# is_cat j
# is_cat s
# is_cat s
# is_cat S
# is_cat g
# is_cat S
# is_cat e
# is_cat b
# is_cat w
# is_cat b
# is_cat A
# is_cat h
# is_cat B
# is_cat b
# is_cat p
# is_cat b
# is_cat R
# is_cat s
# is_cat e
# is_cat B
# is_cat M
# is_cat E
# is_cat M
# is_cat k
# is_cat s
# is_cat b
# is_cat a
# is_cat e
# is_cat s
# is_cat B
# is_cat B
# is_cat e
# is_cat c
# is_cat S
# is_cat A
# is_cat R
# is_cat a
# is_cat p
# is_cat g
# is_cat s
# is_cat n
# is_cat g
# is_cat R
# is_cat s
# is_cat b
# is_cat B
# is_cat s
# is_cat A
# is_cat b
# is_cat g
# is_cat R
# is_cat s
# is_cat b
# is_cat p
# is_cat k
# is_cat s
# is_cat l
# is_cat B
# is_cat y
# is_cat B
# is_cat e
# is_cat n
# is_cat s
# is_cat S
# is_cat g
# is_cat g
# is_cat b
# is_cat p
# is_cat c
# is_cat b
# is_cat m
# is_cat A
# is_cat S
# is_cat b
# is_cat B
# is_cat s
# is_cat b
# is_cat b
# is_cat e
# is_cat P
# is_cat s
# is_cat y
# is_cat y
# is_cat c
# is_cat e
# is_cat y
# is_cat s
# is_cat m
# is_cat b
# is_cat B
# is_cat b
# is_cat B
# is_cat y
# is_cat S
# is_cat S
# is_cat B
# is_cat h
# is_cat B
# is_cat P
# is_cat M
# is_cat y
# is_cat b
# is_cat B
# is_cat a
# is_cat s
# is_cat e
# is_cat e
# is_cat h
# is_cat e
# is_cat b
# is_cat b
# is_cat P
# is_cat e
# is_cat n
# is_cat R
# is_cat h
# is_cat b
# is_cat y
# is_cat B
# is_cat M
# is_cat S
# is_cat b
# is_cat k
# is_cat b
# is_cat g
# is_cat e
# is_cat e
# is_cat e
# is_cat l
# is_cat h
# is_cat S
# is_cat B
# is_cat R
# is_cat g
# is_cat B
# is_cat e
# is_cat s
# is_cat p
# is_cat h
# is_cat p
# is_cat n
# is_cat p
# is_cat R
# is_cat B
# is_cat R
# is_cat b
# is_cat s
# is_cat l
# is_cat j
# is_cat p
# is_cat E
# is_cat c
# is_cat s
# is_cat a
# is_cat s
# is_cat k
# is_cat E
# is_cat A
# is_cat B
# is_cat A
# is_cat c
# is_cat R
# is_cat s
# is_cat h
# is_cat B
# is_cat B
# is_cat R
# is_cat b
# is_cat B
# is_cat S
# is_cat g
# is_cat a
# is_cat R
# is_cat g
# is_cat s
# is_cat E
# is_cat s
# is_cat k
# is_cat g
# is_cat s
# is_cat y
# is_cat a
# is_cat a
# is_cat b
# is_cat B
# is_cat w
# is_cat B
# is_cat R
# is_cat g
# is_cat s
# is_cat g
# is_cat e
# is_cat b
# is_cat s
# is_cat S
# is_cat p
# is_cat B
# is_cat h
# is_cat j
# is_cat n
# is_cat b
# is_cat R
# is_cat s
# is_cat B
# is_cat B
# is_cat s
# is_cat b
# is_cat n
# is_cat M
# is_cat p
# is_cat a
# is_cat p
# is_cat e
# is_cat P
# is_cat R
# is_cat s
# is_cat E
# is_cat e
# is_cat s
# is_cat h
# is_cat b
# is_cat E
# is_cat S
# is_cat p
# is_cat l
# is_cat s
# is_cat b
# is_cat h
# is_cat B
# is_cat p
# is_cat b
# is_cat g
# is_cat p
# is_cat w
# is_cat R
# is_cat g
# is_cat B
# is_cat A
# is_cat s
# is_cat w
# is_cat n
# is_cat B
# is_cat m
# is_cat R
# is_cat j
# is_cat s
# is_cat A
# is_cat P
# is_cat B
# is_cat s
# is_cat e
# is_cat k
# is_cat g
# is_cat p
# is_cat a
# is_cat s
# is_cat B
# is_cat k
# is_cat s
# is_cat b
# is_cat A
# is_cat M
# is_cat R
# is_cat S
# is_cat s
# is_cat a
# is_cat M
# is_cat a
# is_cat s
# is_cat s
# is_cat c
# is_cat j
# is_cat B
# is_cat n
# is_cat B
# is_cat p
# is_cat n
# is_cat P
# is_cat m
# is_cat b
# is_cat l
# is_cat p
# is_cat e
# is_cat h
# is_cat P
# is_cat b
# is_cat b
# is_cat m
# is_cat s
# is_cat j
# is_cat j
# is_cat s
# is_cat s
# is_cat y
# is_cat j
# is_cat S
# is_cat g
# is_cat p
# is_cat b
# is_cat e
# is_cat k
# is_cat s
# is_cat R
# is_cat A
# is_cat p
# is_cat a
# is_cat S
# is_cat m
# is_cat h
# is_cat h
# is_cat p
# is_cat E
# is_cat l
# is_cat s
# is_cat P
# is_cat n
# is_cat A
# is_cat s
# is_cat M
# is_cat w
# is_cat a
# is_cat S
# is_cat B
# is_cat s
# is_cat a
# is_cat p
# is_cat e
# is_cat m
# is_cat h
# is_cat b
# is_cat B
# is_cat c
# is_cat s
# is_cat E
# is_cat e
# is_cat b
# is_cat M
# is_cat j
# is_cat k
# is_cat R
# is_cat B
# is_cat k
# is_cat y
# is_cat w
# is_cat k
# is_cat n
# is_cat e
# is_cat a
# is_cat j
# is_cat n
# is_cat S
# is_cat a
# is_cat s
# is_cat s
# is_cat B
# is_cat g
# is_cat p
# is_cat p
# is_cat b
# is_cat B
# is_cat S
# is_cat s
# is_cat s
# is_cat B
# is_cat B
# is_cat s
# is_cat h
# is_cat y
# is_cat E
# is_cat E
# is_cat j
# is_cat m
# is_cat s
# is_cat c
# is_cat P
# is_cat R
# is_cat a
# is_cat b
# is_cat h
# is_cat B
# is_cat e
# is_cat B
# is_cat s
# is_cat h
# is_cat M
# is_cat g
# is_cat R
# is_cat m
# is_cat M
# is_cat g
# is_cat B
# is_cat R
# is_cat e
# is_cat A
# is_cat b
# is_cat p
# is_cat k
# is_cat M
# is_cat P
# is_cat S
# is_cat j
# is_cat s
# is_cat A
# is_cat s
# is_cat n
# is_cat B
# is_cat n
# is_cat R
# is_cat s
# is_cat R
# is_cat b
# is_cat P
# is_cat g
# is_cat s
# is_cat S
# is_cat b
# is_cat R
# is_cat b
# is_cat B
# is_cat b
# is_cat S
# is_cat R
# is_cat y
# is_cat e
# is_cat B
# is_cat w
# is_cat A
# is_cat j
# is_cat S
# is_cat a
# is_cat P
# is_cat R
# is_cat S
# is_cat b
# is_cat m
# is_cat h
# is_cat E
# is_cat S
# is_cat p
# is_cat S
# is_cat n
# is_cat a
# is_cat m
# is_cat l
# is_cat B
# is_cat h
# is_cat w
# is_cat a
# is_cat m
# is_cat g
# is_cat p
# is_cat k
# is_cat s
# is_cat m
# is_cat b
# is_cat a
# is_cat E
# is_cat B
# is_cat s
# is_cat y
# is_cat B
# is_cat m
# is_cat a
# is_cat B
# is_cat s
# is_cat y
# is_cat P
# is_cat j
# is_cat j
# is_cat E
# is_cat c
# is_cat c
# is_cat s
# is_cat s
# is_cat s
# is_cat M
# is_cat b
# is_cat P
# is_cat B
# is_cat h
# is_cat h
# is_cat k
# is_cat B
# is_cat s
# is_cat l
# is_cat R
# is_cat R
# is_cat B
# is_cat b
# is_cat R
# is_cat s
# is_cat k
# is_cat m
# is_cat l
# is_cat B
# is_cat e
# is_cat g
# is_cat g
# is_cat y
# is_cat p
# is_cat M
# is_cat R
# is_cat S
# is_cat b
# is_cat k
# is_cat b
# is_cat b
# is_cat b
# is_cat b
# is_cat n
# is_cat p
# is_cat h
# is_cat R
# is_cat b
# is_cat A
# is_cat w
# is_cat a
# is_cat a
# is_cat S
# is_cat M
# is_cat l
# is_cat R
# is_cat R
# is_cat a
# is_cat B
# is_cat j
# is_cat A
# is_cat b
# is_cat b
# is_cat S
# is_cat R
# is_cat w
# is_cat s
# is_cat B
# is_cat R
# is_cat E
# is_cat p
# is_cat B
# is_cat S
# is_cat a
# is_cat p
# is_cat g
# is_cat e
# is_cat b
# is_cat c
# is_cat c
# is_cat s
# is_cat p
# is_cat p
# is_cat S
# is_cat a
# is_cat n
# is_cat l
# is_cat a
# is_cat B
# is_cat b
# is_cat S
# is_cat s
# is_cat B
# is_cat s
# is_cat s
# is_cat B
# is_cat S
# is_cat R
# is_cat B
# is_cat c
# is_cat p
# is_cat s
# is_cat B
# is_cat c
# is_cat P
# is_cat l
# is_cat p
# is_cat B
# is_cat S
# is_cat b
# is_cat g
# is_cat B
# is_cat g
# is_cat R
# is_cat s
# is_cat s
# is_cat h
# is_cat S
# is_cat s
# is_cat E
# is_cat b
# is_cat B
# is_cat s
# is_cat w
# is_cat k
# is_cat g
# is_cat l
# is_cat B
# is_cat R
# is_cat B
# is_cat l
# is_cat j
# is_cat h
# is_cat b
# is_cat B
# is_cat m
# is_cat E
# is_cat b
# is_cat S
# is_cat R
# is_cat b
# is_cat S
# is_cat E
# is_cat p
# is_cat e
# is_cat S
# is_cat a
# is_cat w
# is_cat w
# is_cat a
# is_cat B
# is_cat P
# is_cat c
# is_cat s
# is_cat g
# is_cat m
# is_cat R
# is_cat g
# is_cat y
# is_cat c
# is_cat E
# is_cat k
# is_cat h
# is_cat B
# is_cat l
# is_cat y
# is_cat j
# is_cat e
# is_cat m
# is_cat w
# is_cat y
# is_cat e
# is_cat s
# is_cat p
# is_cat p
# is_cat b
# is_cat B
# is_cat s
# is_cat s
# is_cat s
# is_cat c
# is_cat E
# is_cat w
# is_cat j
# is_cat s
# is_cat h
# is_cat a
# is_cat b
# is_cat p
# is_cat s
# is_cat R
# is_cat M
# is_cat B
# is_cat B
# is_cat c
# is_cat h
# is_cat n
# is_cat g
# is_cat s
# is_cat w
# is_cat m
# is_cat s
# is_cat B
# is_cat B
# is_cat n
# is_cat b
# is_cat E
# is_cat g
# is_cat a
# is_cat P
# is_cat s
# is_cat h
# is_cat c
# is_cat a
# is_cat a
# is_cat y
# is_cat b
# is_cat R
# is_cat B
# is_cat g
# is_cat h
# is_cat B
# is_cat R
# is_cat h
# is_cat b
# is_cat h
# is_cat S
# is_cat S
# is_cat S
# is_cat m
# is_cat e
# is_cat y
# is_cat e
# is_cat B
# is_cat P
# is_cat m
# is_cat g
# is_cat a
# is_cat E
# is_cat s
# is_cat p
# is_cat R
# is_cat B
# is_cat p
# is_cat b
# is_cat s
# is_cat b
# is_cat w
# is_cat j
# is_cat b
# is_cat B
# is_cat s
# is_cat R
# is_cat w
# is_cat l
# is_cat b
# is_cat a
# is_cat a
# is_cat m
# is_cat A
# is_cat b
# is_cat s
# is_cat R
# is_cat n
# is_cat n
# is_cat M
# is_cat P
# is_cat R
# is_cat n
# is_cat s
# is_cat S
# is_cat s
# is_cat m
# is_cat a
# is_cat B
# is_cat B
# is_cat b
# is_cat S
# is_cat w
# is_cat S
# is_cat e
# is_cat e
# is_cat n
# is_cat s
# is_cat p
# is_cat p
# is_cat B
# is_cat c
# is_cat k
# is_cat l
# is_cat g
# is_cat a
# is_cat j
# is_cat g
# is_cat b
# is_cat c
# is_cat B
# is_cat b
# is_cat w
# is_cat b
# is_cat R
# is_cat y
# is_cat k
# is_cat s
# is_cat e
# is_cat b
# is_cat p
# is_cat e
# is_cat R
# is_cat n
# is_cat e
# is_cat n
# is_cat S
# is_cat a
# is_cat g
# is_cat p
# is_cat s
# is_cat e
# is_cat p
# is_cat B
# is_cat a
# is_cat R
# is_cat a
# is_cat R
# is_cat l
# is_cat E
# is_cat l
# is_cat b
# is_cat B
# is_cat h
# is_cat j
# is_cat B
# is_cat b
# is_cat w
# is_cat M
# is_cat b
# is_cat B
# is_cat B
# is_cat h
# is_cat S
# is_cat j
# is_cat g
# is_cat B
# is_cat b
# is_cat b
# is_cat l
# is_cat P
# is_cat R
# is_cat j
# is_cat k
# is_cat k
# is_cat c
# is_cat M
# is_cat B
# is_cat s
# is_cat M
# is_cat B
# is_cat B
# is_cat e
# is_cat b
# is_cat P
# is_cat p
# is_cat s
# is_cat b
# is_cat s
# is_cat p
# is_cat M
# is_cat h
# is_cat P
# is_cat y
# is_cat B
# is_cat s
# is_cat B
# is_cat k
# is_cat a
# is_cat s
# is_cat M
# is_cat e
# is_cat B
# is_cat s
# is_cat b
# is_cat b
# is_cat a
# is_cat b
# is_cat s
# is_cat c
# is_cat P
# is_cat a
# is_cat k
# is_cat n
# is_cat b
# is_cat B
# is_cat e
# is_cat g
# is_cat s
# is_cat g
# is_cat M
# is_cat e
# is_cat B
# is_cat p
# is_cat j
# is_cat P
# is_cat p
# is_cat k
# is_cat g
# is_cat b
# is_cat j
# is_cat P
# is_cat B
# is_cat j
# is_cat b
# is_cat R
# is_cat w
# is_cat y
# is_cat w
# is_cat j
# is_cat R
# is_cat B
# is_cat b
# is_cat R
# is_cat g
# is_cat g
# is_cat a
# is_cat B
# is_cat g
# is_cat p
# is_cat B
# is_cat p
# is_cat s
# is_cat E
# is_cat A
# is_cat e
# is_cat B
# is_cat a
# is_cat R
# is_cat B
# is_cat s
# is_cat j
# is_cat s
# is_cat B
# is_cat a
# is_cat b
# is_cat P
# is_cat b
# is_cat b
# is_cat A
# is_cat B
# is_cat s
# is_cat m
# is_cat e
# is_cat b
# is_cat s
# is_cat w
# is_cat s
# is_cat b
# is_cat S
# is_cat h
# is_cat P
# is_cat b
# is_cat s
# is_cat j
# is_cat B
# is_cat g
# is_cat R
# is_cat s
# is_cat p
# is_cat b
# is_cat M
# is_cat B
# is_cat S
# is_cat s
# is_cat m
# is_cat S
# is_cat S
# is_cat g
# is_cat l
# is_cat m
# is_cat g
# is_cat e
# is_cat R
# is_cat s
# is_cat s
# is_cat R
# is_cat k
# is_cat b
# is_cat E
# is_cat s
# is_cat b
# is_cat B
# is_cat n
# is_cat h
# is_cat M
# is_cat n
# is_cat c
# is_cat m
# is_cat M
# is_cat B
# is_cat l
# is_cat p
# is_cat w
# is_cat B
# is_cat B
# is_cat a
# is_cat s
# is_cat A
# is_cat e
# is_cat s
# is_cat B
# is_cat B
# is_cat a
# is_cat g
# is_cat g
# is_cat w
# is_cat M
# is_cat a
# is_cat l
# is_cat B
# is_cat b
# is_cat S
# is_cat s
# is_cat R
# is_cat a
# is_cat h
# is_cat m
# is_cat e
# is_cat k
# is_cat b
# is_cat B
# is_cat e
# is_cat g
# is_cat B
# is_cat s
# is_cat R
# is_cat s
# is_cat w
# is_cat B
# is_cat s
# is_cat c
# is_cat p
# is_cat n
# is_cat l
# is_cat m
# is_cat S
# is_cat k
# is_cat M
# is_cat R
# is_cat s
# is_cat B
# is_cat g
# is_cat w
# is_cat A
# is_cat B
# is_cat m
# is_cat h
# is_cat B
# is_cat p
# is_cat k
# is_cat e
# is_cat n
# is_cat g
# is_cat s
# is_cat M
# is_cat m
# is_cat R
# is_cat B
# is_cat g
# is_cat B
# is_cat B
# is_cat R
# is_cat A
# is_cat B
# is_cat g
# is_cat n
# is_cat a
# is_cat m
# is_cat M
# is_cat g
# is_cat B
# is_cat B
# is_cat B
# is_cat p
# is_cat B
# is_cat b
# is_cat b
# is_cat g
# is_cat m
# is_cat S
# is_cat b
# is_cat m
# is_cat s
# is_cat B
# is_cat B
# is_cat s
# is_cat y
# is_cat s
# is_cat h
# is_cat s
# is_cat g
# is_cat B
# is_cat p
# is_cat p
# is_cat k
# is_cat j
# is_cat E
# is_cat B
# is_cat g
# is_cat e
# is_cat B
# is_cat b
# is_cat w
# is_cat A
# is_cat R
# is_cat b
# is_cat j
# is_cat c
# is_cat P
# is_cat b
# is_cat s
# is_cat p
# is_cat s
# is_cat c
# is_cat w
# is_cat p
# is_cat R
# is_cat p
# is_cat S
# is_cat e
# is_cat s
# is_cat s
# is_cat E
# is_cat c
# is_cat B
# is_cat s
# is_cat e
# is_cat g
# is_cat R
# is_cat a
# is_cat B
# is_cat k
# is_cat n
# is_cat E
# is_cat c
# is_cat g
# is_cat R
# is_cat b
# is_cat n
# is_cat n
# is_cat g
# is_cat k
# is_cat y
# is_cat s
# is_cat s
# is_cat h
# is_cat p
# is_cat s
# is_cat S
# is_cat A
# is_cat j
# is_cat b
# is_cat B
# is_cat p
# is_cat l
# is_cat A
# is_cat g
# is_cat j
# is_cat c
# is_cat y
# is_cat B
# is_cat S
# is_cat S
# is_cat y
# is_cat R
# is_cat B
# is_cat b
# is_cat A
# is_cat s
# is_cat S
# is_cat p
# is_cat h
# is_cat b
# is_cat c
# is_cat g
# is_cat B
# is_cat s
# is_cat k
# is_cat R
# is_cat p
# is_cat M
# is_cat B
# is_cat p
# is_cat j
# is_cat R
# is_cat w
# is_cat B
# is_cat w
# is_cat g
# is_cat s
# is_cat a
# is_cat s
# is_cat p
# is_cat h
# is_cat R
# is_cat j
# is_cat k
# is_cat m
# is_cat b
# is_cat w
# is_cat p
# is_cat g
# is_cat g
# is_cat P
# is_cat S
# is_cat B
# is_cat y
# is_cat p
# is_cat c
# is_cat a
# is_cat R
# is_cat s
# is_cat p
# is_cat E
# is_cat h
# is_cat p
# is_cat b
# is_cat w
# is_cat e
# is_cat B
# is_cat R
# is_cat e
# is_cat h
# is_cat l
# is_cat p
# is_cat B
# is_cat c
# is_cat s
# is_cat c
# is_cat y
# is_cat n
# is_cat E
# is_cat e
# is_cat b
# is_cat S
# is_cat S
# is_cat b
# is_cat b
# is_cat R
# is_cat b
# is_cat a
# is_cat s
# is_cat e
# is_cat j
# is_cat a
# is_cat B
# is_cat B
# is_cat l
# is_cat s
# is_cat b
# is_cat l
# is_cat s
# is_cat w
# is_cat y
# is_cat M
# is_cat S
# is_cat b
# is_cat S
# is_cat m
# is_cat s
# is_cat a
# is_cat g
# is_cat S
# is_cat n
# is_cat p
# is_cat s
# is_cat n
# is_cat s
# is_cat n
# is_cat l
# is_cat n
# is_cat a
# is_cat a
# is_cat e
# is_cat e
# is_cat a
# is_cat R
# is_cat B
# is_cat s
# is_cat j
# is_cat s
# is_cat R
# is_cat n
# is_cat s
# is_cat S
# is_cat y
# is_cat B
# is_cat e
# is_cat g
# is_cat y
# is_cat s
# is_cat j
# is_cat c
# is_cat S
# is_cat s
# is_cat S
# is_cat S
# is_cat M
# is_cat s
# is_cat l
# is_cat E
# is_cat g
# is_cat g
# is_cat y
# is_cat A
# is_cat a
# is_cat g
# is_cat b
# is_cat s
# is_cat p
# is_cat n
# is_cat g
# is_cat B
# is_cat B
# is_cat k
# is_cat B
# is_cat s
# is_cat p
# is_cat P
# is_cat b
# is_cat s
# is_cat j
# is_cat n
# is_cat S
# is_cat a
# is_cat e
# is_cat e
# is_cat S
# is_cat P
# is_cat s
# is_cat g
# is_cat b
# is_cat h
# is_cat e
# is_cat S
# is_cat R
# is_cat s
# is_cat B
# is_cat l
# is_cat y
# is_cat B
# is_cat s
# is_cat s
# is_cat a
# is_cat M
# is_cat s
# is_cat S
# is_cat s
# is_cat B
# is_cat A
# is_cat s
# is_cat S
# is_cat h
# is_cat R
# is_cat y
# is_cat w
# is_cat B
# is_cat p
# is_cat M
# is_cat E
# is_cat p
# is_cat b
# is_cat p
# is_cat a
# is_cat R
# is_cat b
# is_cat b
# is_cat a
# is_cat P
# is_cat s
# is_cat e
# is_cat c
# is_cat P
# is_cat s
# is_cat B
# is_cat c
# is_cat p
# is_cat p
# is_cat b
# is_cat p
# is_cat p
# is_cat a
# is_cat P
# is_cat B
# is_cat s
# is_cat e
# is_cat s
# is_cat S
# is_cat c
# is_cat A
# is_cat s
# is_cat s
# is_cat a
# is_cat s
# is_cat M
# is_cat e
# is_cat y
# is_cat g
# is_cat c
# is_cat n
# is_cat B
# is_cat E
# is_cat a
# is_cat S
# is_cat s
# is_cat w
# is_cat a
# is_cat B
# is_cat n
# is_cat a
# is_cat k
# is_cat h
# is_cat e
# is_cat M
# is_cat p
# is_cat b
# is_cat B
# is_cat s
# is_cat n
# is_cat E
# is_cat s
# is_cat P
# is_cat E
# is_cat e
# is_cat s
# is_cat j
# is_cat y
# is_cat S
# is_cat b
# is_cat b
# is_cat a
# is_cat b
# is_cat b
# is_cat b
# is_cat b
# is_cat s
# is_cat A
# is_cat p
# is_cat a
# is_cat E
# is_cat p
# is_cat a
# is_cat B
# is_cat c
# is_cat s
# is_cat B
# is_cat j
# is_cat h
# is_cat B
# is_cat a
# is_cat s
# is_cat R
# is_cat P
# is_cat A
# is_cat y
# is_cat m
# is_cat s
# is_cat g
# is_cat S
# is_cat j
# is_cat k
# is_cat w
# is_cat m
# is_cat l
# is_cat b
# is_cat g
# is_cat B
# is_cat S
# is_cat a
# is_cat p
# is_cat B
# is_cat P
# is_cat l
# is_cat A
# is_cat B
# is_cat b
# is_cat s
# is_cat S
# is_cat b
# is_cat B
# is_cat e
# is_cat l
# is_cat e
# is_cat y
# is_cat j
# is_cat s
# is_cat B
# is_cat e
# is_cat R
# is_cat w
# is_cat b
# is_cat E
# is_cat e
# is_cat a
# is_cat P
# is_cat s
# is_cat p
# is_cat k
# is_cat l
# is_cat y
# is_cat R
# is_cat B
# is_cat y
# is_cat b
# is_cat e
# is_cat p
# is_cat p
# is_cat M
# is_cat b
# is_cat s
# is_cat s
# is_cat h
# is_cat b
# is_cat s
# is_cat b
# is_cat k
# is_cat l
# is_cat m
# is_cat s
# is_cat e
# is_cat m
# is_cat A
# is_cat P
# is_cat b
# is_cat s
# is_cat h
# is_cat k
# is_cat a
# is_cat s
# is_cat g
# is_cat p
# is_cat b
# is_cat B
# is_cat S
# is_cat s
# is_cat s
# is_cat S
# is_cat P
# is_cat M
# is_cat P
# is_cat g
# is_cat h
# is_cat a
# is_cat B
# is_cat g
# is_cat M
# is_cat B
# is_cat s
# is_cat B
# is_cat p
# is_cat b
# is_cat M
# is_cat E
# is_cat b
# is_cat B
# is_cat a
# is_cat P
# is_cat y
# is_cat a
# is_cat B
# is_cat g
# is_cat s
# is_cat b
# is_cat s
# is_cat B
# is_cat l
# is_cat l
# is_cat m
# is_cat b
# is_cat s
# is_cat g
# is_cat B
# is_cat E
# is_cat s
# is_cat b
# is_cat b
# is_cat s
# is_cat A
# is_cat s
# is_cat B
# is_cat B
# is_cat b
# is_cat s
# is_cat l
# is_cat k
# is_cat B
# is_cat P
# is_cat B
# is_cat p
# is_cat A
# is_cat e
# is_cat s
# is_cat S
# is_cat w
# is_cat e
# is_cat B
# is_cat b
# is_cat R
# is_cat j
# is_cat B
# is_cat S
# is_cat B
# is_cat k
# is_cat g
# is_cat S
# is_cat k
# is_cat B
# is_cat B
# is_cat S
# is_cat s
# is_cat s
# is_cat a
# is_cat B
# is_cat s
# is_cat a
# is_cat A
# is_cat n
# is_cat e
# is_cat B
# is_cat E
# is_cat S
# is_cat B
# is_cat B
# is_cat s
# is_cat E
# is_cat s
# is_cat g
# is_cat S
# is_cat p
# is_cat j
# is_cat l
# is_cat b
# is_cat a
# is_cat p
# is_cat g
# is_cat l
# is_cat M
# is_cat b
# is_cat a
# is_cat c
# is_cat s
# is_cat S
# is_cat p
# is_cat c
# is_cat s
# is_cat P
# is_cat b
# is_cat p
# is_cat g
# is_cat B
# is_cat y
# is_cat P
# is_cat B
# is_cat c
# is_cat E
# is_cat m
# is_cat a
# is_cat B
# is_cat e
# is_cat S
# is_cat s
# is_cat e
# is_cat j
# is_cat S
# is_cat b
# is_cat R
# is_cat S
# is_cat E
# is_cat s
# is_cat B
# is_cat e
# is_cat E
# is_cat p
# is_cat B
# is_cat a
# is_cat s
# is_cat m
# is_cat s
# is_cat s
# is_cat e
# is_cat b
# is_cat m
# is_cat l
# is_cat M
# is_cat a
# is_cat P
# is_cat g
# is_cat b
# is_cat S
# is_cat S
# is_cat M
# is_cat a
# is_cat e
# is_cat n
# is_cat k
# is_cat B
# is_cat e
# is_cat k
# is_cat g
# is_cat a
# is_cat A
# is_cat b
# is_cat e
# is_cat n
# is_cat b
# is_cat E
# is_cat B
# is_cat R
# is_cat a
# is_cat B
# is_cat S
# is_cat p
# is_cat h
# is_cat e
# is_cat b
# is_cat B
# is_cat b
# is_cat g
# is_cat R
# is_cat S
# is_cat s
# is_cat B
# is_cat k
# is_cat R
# is_cat s
# is_cat S
# is_cat g
# is_cat b
# is_cat B
# is_cat P
# is_cat s
# is_cat s
# is_cat s
# is_cat s
# is_cat m
# is_cat B
# is_cat h
# is_cat B
# is_cat s
# is_cat B
# is_cat w
# is_cat k
# is_cat h
# is_cat a
# is_cat b
# is_cat n
# is_cat b
# is_cat s
# is_cat e
# is_cat s
# is_cat s
# is_cat c
# is_cat s
# is_cat a
# is_cat a
# is_cat j
# is_cat A
# is_cat y
# is_cat s
# is_cat s
# is_cat R
# is_cat E
# is_cat R
# is_cat s
# is_cat s
# is_cat A
# is_cat s
# is_cat a
# is_cat w
# is_cat s
# is_cat a
# is_cat s
# is_cat g
# is_cat R
# is_cat s
# is_cat w
# is_cat p
# is_cat B
# is_cat B
# is_cat l
# is_cat B
# is_cat S
# is_cat b
# is_cat g
# is_cat S
# is_cat b
# is_cat w
# is_cat s
# is_cat p
# is_cat s
# is_cat w
# is_cat h
# is_cat s
# is_cat g
# is_cat c
# is_cat p
# is_cat c
# is_cat h
# is_cat B
# is_cat s
# is_cat p
# is_cat g
# is_cat b
# is_cat s
# is_cat y
# is_cat E
# is_cat E
# is_cat R
# is_cat s
# is_cat y
# is_cat w
# is_cat s
# is_cat b
# is_cat p
# is_cat m
# is_cat p
# is_cat B
# is_cat b
# is_cat B
# is_cat l
# is_cat b
# is_cat k
# is_cat h
# is_cat c
# is_cat R
# is_cat B
# is_cat b
# is_cat B
# is_cat a
# is_cat R
# is_cat c
# is_cat b
# is_cat B
# is_cat g
# is_cat g
# is_cat A
# is_cat s
# is_cat B
# is_cat s
# is_cat R
# is_cat l
# is_cat c
# is_cat b
# is_cat B
# is_cat B
# is_cat E
# is_cat S
# is_cat m
# is_cat e
# is_cat w
# is_cat n
# is_cat p
# is_cat w
# is_cat y
# is_cat b
# is_cat B
# is_cat A
# is_cat j
# is_cat w
# is_cat a
# is_cat j
# is_cat y
# is_cat b
# is_cat b
# is_cat j
# is_cat B
# is_cat A
# is_cat B
# is_cat w
# is_cat e
# is_cat s
# is_cat y
# is_cat a
# is_cat S
# is_cat R
# is_cat c
# is_cat S
# is_cat B
# is_cat s
# is_cat k
# is_cat s
# is_cat s
# is_cat R
# is_cat B
# is_cat P
# is_cat a
# is_cat g
# is_cat B
# is_cat B
# is_cat B
# is_cat n
# is_cat j
# is_cat s
# is_cat g
# is_cat p
# is_cat s
# is_cat a
# is_cat B
# is_cat E
# is_cat b
# is_cat s
# is_cat R
# is_cat e
# is_cat e
# is_cat c
# is_cat s
# is_cat g
# is_cat s
# is_cat g
# is_cat s
# is_cat e
# is_cat P
# is_cat e
# is_cat S
# is_cat s
# is_cat n
# is_cat b
# is_cat E
# is_cat l
# is_cat B
# is_cat A
# is_cat E
# is_cat S
# is_cat B
# is_cat s
# is_cat p
# is_cat s
# is_cat h
# is_cat g
# is_cat s
# is_cat s
# is_cat A
# is_cat s
# is_cat h
# is_cat R
# is_cat P
# is_cat S
# is_cat p
# is_cat b
# is_cat A
# is_cat p
# is_cat l
# is_cat S
# is_cat s
# is_cat m
# is_cat R
# is_cat s
# is_cat y
# is_cat B
# is_cat S
# is_cat E
# is_cat c
# is_cat s
# is_cat A
# is_cat R
# is_cat b
# is_cat P
# is_cat B
# is_cat b
# is_cat p
# is_cat j
# is_cat E
# is_cat k
# is_cat A
# is_cat m
# is_cat h
# is_cat M
# is_cat m
# is_cat m
# is_cat E
# is_cat y
# is_cat S
# is_cat M
# is_cat l
# is_cat B
# is_cat M
# is_cat s
# is_cat B
# is_cat e
# is_cat y
# is_cat S
# is_cat R
# is_cat p
# is_cat n
# is_cat s
# is_cat p
# is_cat A
# is_cat s
# is_cat B
# is_cat A
# is_cat e
# is_cat s
# is_cat g
# is_cat l
# is_cat M
# is_cat R
# is_cat a
# is_cat g
# is_cat n
# is_cat g
# is_cat c
# is_cat s
# is_cat c
# is_cat b
# is_cat w
# is_cat s
# is_cat s
# is_cat B
# is_cat l
# is_cat E
# is_cat B
# is_cat B
# is_cat c
# is_cat m
# is_cat y
# is_cat R
# is_cat S
# is_cat s
# is_cat c
# is_cat s
# is_cat p
# is_cat R
# is_cat B
# is_cat k
# is_cat p
# is_cat M
# is_cat a
# is_cat S
# is_cat b
# is_cat M
# is_cat S
# is_cat R
# is_cat S
# is_cat B
# is_cat B
# is_cat w
# is_cat E
# is_cat e
# is_cat y
# is_cat p
# is_cat A
# is_cat l
# is_cat A
# is_cat p
# is_cat a
# is_cat p
# is_cat B
# is_cat e
# is_cat j
# is_cat s
# is_cat s
# is_cat g
# is_cat y
# is_cat k
# is_cat S
# is_cat E
# is_cat h
# is_cat j
# is_cat s
# is_cat g
# is_cat M
# is_cat s
# is_cat E
# is_cat b
# is_cat P
# is_cat M
# is_cat s
# is_cat w
# is_cat k
# is_cat b
# is_cat M
# is_cat B
# is_cat p
# is_cat s
# is_cat g
# is_cat e
# is_cat g
# is_cat e
# is_cat g
# is_cat b
# is_cat p
# is_cat s
# is_cat B
# is_cat m
# is_cat B
# is_cat s
# is_cat l
# is_cat j
# is_cat s
# is_cat h
# is_cat e
# is_cat a
# is_cat b
# is_cat R
# is_cat M
# is_cat g
# is_cat s
# is_cat j
# is_cat j
# is_cat a
# is_cat y
# is_cat b
# is_cat g
# is_cat s
# is_cat M
# is_cat B
# is_cat s
# is_cat B
# is_cat h
# is_cat p
# is_cat p
# is_cat B
# is_cat e
# is_cat M
# is_cat S
# is_cat a
# is_cat w
# is_cat B
# is_cat w
# is_cat M
# is_cat B
# is_cat M
# is_cat S
# is_cat P
# is_cat a
# is_cat m
# is_cat S
# is_cat m
# is_cat s
# is_cat P
# is_cat M
# is_cat s
# is_cat b
# is_cat E
# is_cat p
# is_cat s
# is_cat a
# is_cat b
# is_cat n
# is_cat s
# is_cat h
# is_cat S
# is_cat p
# is_cat y
# is_cat B
# is_cat c
# is_cat h
# is_cat S
# is_cat a
# is_cat b
# is_cat b
# is_cat B
# is_cat S
# is_cat s
# is_cat s
# is_cat s
# is_cat w
# is_cat a
# is_cat S
# is_cat P
# is_cat a
# is_cat j
# is_cat w
# is_cat b
# is_cat n
# is_cat A
# is_cat e
# is_cat M
# is_cat M
# is_cat B
# is_cat s
# is_cat B
# is_cat b
# is_cat s
# is_cat s
# is_cat B
# is_cat s
# is_cat n
# is_cat B
# is_cat j
# is_cat g
# is_cat g
# is_cat P
# is_cat p
# is_cat h
# is_cat B
# is_cat h
# is_cat e
# is_cat s
# is_cat b
# is_cat B
# is_cat c
# is_cat A
# is_cat A
# is_cat l
# is_cat g
# is_cat R
# is_cat s
# is_cat m
# is_cat g
# is_cat a
# is_cat w
# is_cat b
# is_cat S
# is_cat g
# is_cat E
# is_cat b
# is_cat a
# is_cat A
# is_cat P
# is_cat g
# is_cat b
# is_cat b
# is_cat w
# is_cat B
# is_cat B
# is_cat j
# is_cat m
# is_cat M
# is_cat p
# is_cat j
# is_cat a
# is_cat h
# is_cat g
# is_cat b
# is_cat B
# is_cat s
# is_cat e
# is_cat l
# is_cat w
# is_cat B
# is_cat R
# is_cat b
# is_cat M
# is_cat s
# is_cat w
# is_cat E
# is_cat R
# is_cat S
# is_cat S
# is_cat a
# is_cat a
# is_cat g
# is_cat p
# is_cat P
# is_cat R
# is_cat s
# is_cat s
# is_cat P
# is_cat s
# is_cat s
# is_cat s
# is_cat g
# is_cat p
# is_cat y
# is_cat m
# is_cat S
# is_cat k
# is_cat b
# is_cat k
# is_cat s
# is_cat p
# is_cat s
# is_cat B
# is_cat b
# is_cat m
# is_cat l
# is_cat B
# is_cat B
# is_cat y
# is_cat b
# is_cat S
# is_cat n
# is_cat p
# is_cat R
# is_cat S
# is_cat b
# is_cat b
# is_cat k
# is_cat A
# is_cat l
# is_cat s
# is_cat e
# is_cat m
# is_cat e
# is_cat k
# is_cat B
# is_cat S
# is_cat E
# is_cat c
# is_cat s
# is_cat A
# is_cat p
# is_cat n
# is_cat j
# is_cat s
# is_cat p
# is_cat b
# is_cat E
# is_cat B
# is_cat s
# is_cat E
# is_cat y
# is_cat E
# is_cat p
# is_cat E
# is_cat s
# is_cat w
# is_cat g
# is_cat p
# is_cat j
# is_cat e
# is_cat c
# is_cat B
# is_cat a
# is_cat B
# is_cat s
# is_cat e
# is_cat s
# is_cat M
# is_cat g
# is_cat B
# is_cat p
# is_cat M
# is_cat p
# is_cat s
# is_cat n
# is_cat R
# is_cat k
# is_cat b
# is_cat B
# is_cat m
# is_cat E
# is_cat a
# is_cat B
# is_cat S
# is_cat j
# is_cat p
# is_cat b
# is_cat R
# is_cat a
# is_cat y
# is_cat B
# is_cat c
# is_cat A
# is_cat s
# is_cat l
# is_cat e
# is_cat p
# is_cat b
# is_cat p
# is_cat R
# is_cat c
# is_cat M
# is_cat m
# is_cat a
# is_cat b
# is_cat k
# is_cat c
# is_cat y
# is_cat b
# is_cat s
# is_cat j
# is_cat B
# is_cat h
# is_cat s
# is_cat b
# is_cat R
# is_cat b
# is_cat p
# is_cat w
# is_cat B
# is_cat P
# is_cat m
# is_cat A
# is_cat b
# is_cat s
# is_cat P
# is_cat e
# is_cat h
# is_cat S
# is_cat h
# is_cat w
# is_cat b
# is_cat m
# is_cat e
# is_cat a
# is_cat a
# is_cat E
# is_cat e
# is_cat R
# is_cat w
# is_cat k
# is_cat B
# is_cat j
# is_cat B
# is_cat k
# is_cat b
# is_cat s
# is_cat R
# is_cat p
# is_cat A
# is_cat w
# is_cat b
# is_cat A
# is_cat b
# is_cat A
# is_cat w
# is_cat R
# is_cat y
# is_cat B
# is_cat g
# is_cat j
# is_cat b
# is_cat E
# is_cat k
# is_cat B
# is_cat a
# is_cat m
# is_cat P
# is_cat k
# is_cat j
# is_cat j
# is_cat h
# is_cat B
# is_cat m
# is_cat p
# is_cat s
# is_cat b
# is_cat e
# is_cat R
# is_cat c
# is_cat m
# is_cat M
# is_cat g
# is_cat b
# is_cat B
# is_cat R
# is_cat E
# is_cat B
# is_cat s
# is_cat B
# is_cat w
# is_cat a
# is_cat E
# is_cat s
# is_cat e
# is_cat R
# is_cat B
# is_cat B
# is_cat R
# is_cat A
# is_cat S
# is_cat p
# is_cat e
# is_cat M
# is_cat a
# is_cat y
# is_cat y
# is_cat s
# is_cat A
# is_cat S
# is_cat B
# is_cat P
# is_cat B
# is_cat s
# is_cat R
# is_cat B
# is_cat a
# is_cat R
# is_cat w
# is_cat l
# is_cat p
# is_cat b
# is_cat b
# is_cat j
# is_cat a
# is_cat a
# is_cat A
# is_cat S
# is_cat g
# is_cat E
# is_cat S
# is_cat m
# is_cat S
# is_cat g
# is_cat e
# is_cat e
# is_cat b
# is_cat k
# is_cat B
# is_cat R
# is_cat B
# is_cat h
# is_cat M
# is_cat s
# is_cat s
# is_cat S
# is_cat a
# is_cat k
# is_cat b
# is_cat B
# is_cat e
# is_cat l
# is_cat R
# is_cat n
# is_cat n
# is_cat s
# is_cat e
# is_cat B
# is_cat p
# is_cat s
# is_cat B
# is_cat n
# is_cat m
# is_cat S
# is_cat A
# is_cat n
# is_cat e
# is_cat n
# is_cat B
# is_cat M
# is_cat s
# is_cat s
# is_cat B
# is_cat h
# is_cat B
# is_cat a
# is_cat s
# is_cat c
# is_cat B
# is_cat g
# is_cat n
# is_cat s
# is_cat n
# is_cat A
# is_cat j
# is_cat b
# is_cat s
# is_cat R
# is_cat R
# is_cat e
# is_cat B
# is_cat S
# is_cat B
# is_cat b
# is_cat s
# is_cat k
# is_cat E
# is_cat w
# is_cat g
# is_cat k
# is_cat b
# is_cat g
# is_cat h
# is_cat M
# is_cat n
# is_cat P
# is_cat s
# is_cat p
# is_cat B
# is_cat p
# is_cat S
# is_cat S
# is_cat w
# is_cat E
# is_cat B
# is_cat b
# is_cat s
# is_cat B
# is_cat b
# is_cat s
# is_cat b
# is_cat p
# is_cat h
# is_cat j
# is_cat P
# is_cat M
# is_cat a
# is_cat s
# is_cat j
# is_cat B
# is_cat p
# is_cat B
# is_cat s
# is_cat b
# is_cat k
# is_cat y
# is_cat n
# is_cat B
# is_cat e
# is_cat p
# is_cat b
# is_cat M
# is_cat y
# is_cat s
# is_cat a
# is_cat s
# is_cat n
# is_cat b
# is_cat h
# is_cat p
# is_cat R
# is_cat s
# is_cat j
# is_cat E
# is_cat B
# is_cat p
# is_cat A
# is_cat P
# is_cat B
# is_cat B
# is_cat M
# is_cat e
# is_cat E
# is_cat p
# is_cat B
# is_cat n
# is_cat R
# is_cat S
# is_cat a
# is_cat s
# is_cat a
# is_cat s
# is_cat R
# is_cat A
# is_cat M
# is_cat c
# is_cat g
# is_cat E
# is_cat y
# is_cat P
# is_cat A
# is_cat s
# is_cat s
# is_cat s
# is_cat S
# is_cat s
# is_cat y
# is_cat R
# is_cat M
# is_cat E
# is_cat e
# is_cat a
# is_cat S
# is_cat A
# is_cat c
# is_cat a
# is_cat a
# is_cat b
# is_cat e
# is_cat B
# is_cat j
# is_cat g
# is_cat g
# is_cat l
# is_cat k
# is_cat b
# is_cat p
# is_cat a
# is_cat b
# is_cat e
# is_cat y
# is_cat E
# is_cat g
# is_cat n
# is_cat e
# is_cat w
# is_cat e
# is_cat E
# is_cat g
# is_cat b
# is_cat s
# is_cat s
# is_cat b
# is_cat e
# is_cat l
# is_cat g
# is_cat E
# is_cat R
# is_cat b
# is_cat E
# is_cat w
# is_cat l
# is_cat w
# is_cat h
# is_cat R
# is_cat P
# is_cat w
# is_cat p
# is_cat B
# is_cat b
# is_cat M
# is_cat b
# is_cat g
# is_cat b
# is_cat P
# is_cat s
# is_cat s
# is_cat R
# is_cat s
# is_cat c
# is_cat b
# is_cat j
# is_cat y
# is_cat s
# is_cat k
# is_cat y
# is_cat B
# is_cat h
# is_cat g
# is_cat p
# is_cat g
# is_cat p
# is_cat p
# is_cat s
# is_cat m
# is_cat B
# is_cat m
# is_cat s
# is_cat h
# is_cat h
# is_cat k
# is_cat b
# is_cat n
# is_cat a
# is_cat h
# is_cat j
# is_cat S
# is_cat l
# is_cat h
# is_cat S
# is_cat b
# is_cat y
# is_cat E
# is_cat R
# is_cat e
# is_cat B
# is_cat E
# is_cat j
# is_cat j
# is_cat s
# is_cat B
# is_cat R
# is_cat B
# is_cat s
# is_cat l
# is_cat b
# is_cat j
# is_cat g
# is_cat B
# is_cat B
# is_cat s
# is_cat h
# is_cat b
# is_cat P
# is_cat h
# is_cat k
# is_cat p
# is_cat b
# is_cat l
# is_cat A
# is_cat e
# is_cat B
# is_cat c
# is_cat E
# is_cat B
# is_cat s
# is_cat s
# is_cat j
# is_cat A
# is_cat E
# is_cat a
# is_cat B
# is_cat g
# is_cat B
# is_cat R
# is_cat e
# is_cat s
# is_cat b
# is_cat k
# is_cat m
# is_cat e
# is_cat p
# is_cat E
# is_cat g
# is_cat j
# is_cat j
# is_cat m
# is_cat b
# is_cat s
# is_cat B
# is_cat p
# is_cat a
# is_cat s
# is_cat c
# is_cat s
# is_cat j
# is_cat P
# is_cat s
# is_cat s
# is_cat s
# is_cat e
# is_cat n
# is_cat s
# is_cat S
# is_cat e
# is_cat B
# is_cat B
# is_cat m
# is_cat h
# is_cat B
# is_cat c
# is_cat m
# is_cat h
# is_cat l
# is_cat y
# is_cat y
# is_cat s
# is_cat S
# is_cat b
# is_cat k
# is_cat a
# is_cat n
# is_cat P
# is_cat P
# is_cat P
# is_cat g
# is_cat B
# is_cat g
# is_cat R
# is_cat B
# is_cat a
# is_cat l
# is_cat a
# is_cat R
# is_cat g
# is_cat g
# is_cat g
# is_cat b
# is_cat g
# is_cat R
# is_cat g
# is_cat R
# is_cat e
# is_cat a
# is_cat y
# is_cat c
# is_cat b
# is_cat k
# is_cat s
# is_cat y
# is_cat B
# is_cat c
# is_cat w
# is_cat B
# is_cat c
# is_cat A
# is_cat b
# is_cat E
# is_cat n
# is_cat y
# is_cat p
# is_cat e
# is_cat w
# is_cat g
# is_cat s
# is_cat b
# is_cat S
# is_cat B
# is_cat a
# is_cat B
# is_cat E
# is_cat B
# is_cat k
# is_cat S
# is_cat e
# is_cat w
# is_cat s
# is_cat s
# is_cat b
# is_cat A
# is_cat B
# is_cat g
# is_cat m
# is_cat S
# is_cat p
# is_cat p
# is_cat S
# is_cat S
# is_cat y
# is_cat b
# is_cat c
# is_cat e
# is_cat l
# is_cat a
# is_cat s
# is_cat y
# is_cat s
# is_cat s
# is_cat B
# is_cat c
# is_cat s
# is_cat j
# is_cat s
# is_cat B
# is_cat R
# is_cat g
# is_cat s
# is_cat A
# is_cat s
# is_cat s
# is_cat a
# is_cat m
# is_cat n
# is_cat a
# is_cat e
# is_cat b
# is_cat b
# is_cat g
# is_cat S
# is_cat l
# is_cat b
# is_cat S
# is_cat l
# is_cat s
# is_cat B
# is_cat h
# is_cat b
# is_cat k
# is_cat g
# is_cat A
# is_cat a
# is_cat B
# is_cat E
# is_cat b
# is_cat s
# is_cat g
# is_cat R
# is_cat g
# is_cat a
# is_cat E
# is_cat a
# is_cat l
# is_cat e
# is_cat g
# is_cat e
# is_cat M
# is_cat b
# is_cat R
# is_cat b
# is_cat m
# is_cat e
# is_cat p
# is_cat S
# is_cat c
# is_cat j
# is_cat g
# is_cat S
# is_cat e
# is_cat j
# is_cat k
# is_cat a
# is_cat R
# is_cat s
# is_cat p
# is_cat c
# is_cat R
# is_cat A
# is_cat e
# is_cat p
# is_cat R
# is_cat m
# is_cat e
# is_cat s
# is_cat B
# is_cat R
# is_cat h
# is_cat M
# is_cat h
# is_cat A
# is_cat a
# is_cat E
# is_cat l
# is_cat k
# is_cat B
# is_cat s
# is_cat e
# is_cat M
# is_cat j
# is_cat a
# is_cat s
# is_cat B
# is_cat E
# is_cat A
# is_cat B
# is_cat R
# is_cat n
# is_cat w
# is_cat p
# is_cat e
# is_cat A
# is_cat y
# is_cat b
# is_cat P
# is_cat B
# is_cat n
# is_cat m
# is_cat R
# is_cat b
# is_cat n
# is_cat e
# is_cat R
# is_cat g
# is_cat w
# is_cat A
# is_cat s
# is_cat s
# is_cat M
# is_cat m
# is_cat n
# is_cat a
# is_cat j
# is_cat S
# is_cat h
# is_cat s
# is_cat s
# is_cat B
# is_cat B
# is_cat p
# is_cat j
# is_cat R
# is_cat c
# is_cat s
# is_cat s
# is_cat y
# is_cat k
# is_cat R
# is_cat b
# is_cat c
# is_cat R
# is_cat M
# is_cat k
# is_cat g
# is_cat s
# is_cat y
# is_cat P
# is_cat b
# is_cat j
# is_cat b
# is_cat h
# is_cat g
# is_cat s
# is_cat s
# is_cat M
# is_cat m
# is_cat s
# is_cat M
# is_cat h
# is_cat B
# is_cat S
# is_cat n
# is_cat s
# is_cat e
# is_cat s
# is_cat S
# is_cat E
# is_cat s
# is_cat s
# is_cat p
# is_cat s
# is_cat M
# is_cat B
# is_cat l
# is_cat B
# is_cat h
# is_cat e
# is_cat l
# is_cat a
# is_cat a
# is_cat g
# is_cat k
# is_cat E
# is_cat s
# is_cat g
# is_cat B
# is_cat M
# is_cat l
# is_cat p
# is_cat b
# is_cat m
# is_cat R
# is_cat S
# is_cat w
# is_cat R
# is_cat P
# is_cat p
# is_cat c
# is_cat g
# is_cat S
# is_cat g
# is_cat k
# is_cat y
# is_cat s
# is_cat w
# is_cat A
# is_cat a
# is_cat A
# is_cat p
# is_cat l
# is_cat a
# is_cat k
# is_cat w
# is_cat e
# is_cat R
# is_cat e
# is_cat B
# is_cat s
# is_cat p
# is_cat n
# is_cat s
# is_cat M
# is_cat e
# is_cat b
# is_cat b
# is_cat g
# is_cat s
# is_cat R
# is_cat c
# is_cat c
# is_cat b
# is_cat S
# is_cat j
# is_cat y
# is_cat A
# is_cat M
# is_cat c
# is_cat j
# is_cat b
# is_cat l
# is_cat B
# is_cat B
# is_cat j
# is_cat s
# is_cat P
# is_cat h
# is_cat m
# is_cat s
# is_cat a
# is_cat m
# is_cat B
# is_cat b
# is_cat a
# is_cat p
# is_cat c
# is_cat S
# is_cat s
# is_cat a
# is_cat E
# is_cat s
# is_cat a
# is_cat R
# is_cat a
# is_cat s
# is_cat h
# is_cat B
# is_cat s
# is_cat S
# is_cat l
# is_cat k
# is_cat s
# is_cat s
# is_cat b
# is_cat S
# is_cat B
# is_cat S
# is_cat R
# is_cat j
# is_cat s
# is_cat s
# is_cat s
# is_cat m
# is_cat R
# is_cat p
# is_cat B
# is_cat c
# is_cat w
# is_cat a
# is_cat l
# is_cat p
# is_cat S
# is_cat S
# is_cat b
# is_cat p
# is_cat g
# is_cat s
# is_cat s
# is_cat y
# is_cat b
# is_cat M
# is_cat s
# is_cat y
# is_cat m
# is_cat y
# is_cat S
# is_cat M
# is_cat B
# is_cat p
# is_cat s
# is_cat m
# is_cat e
# is_cat g
# is_cat g
# is_cat w
# is_cat p
# is_cat c
# is_cat b
# is_cat k
# is_cat k
# is_cat s
# is_cat R
# is_cat M
# is_cat g
# is_cat e
# is_cat S
# is_cat s
# is_cat b
# is_cat k
# is_cat y
# is_cat g
# is_cat B
# is_cat s
# is_cat e
# is_cat M
# is_cat g
# is_cat l
# is_cat e
# is_cat s
# is_cat S
# is_cat s
# is_cat p
# is_cat S
# is_cat p
# is_cat R
# is_cat a
# is_cat k
# is_cat B
# is_cat l
# is_cat a
# is_cat R
# is_cat a
# is_cat B
# is_cat E
# is_cat j
# is_cat y
# is_cat A
# is_cat B
# is_cat p
# is_cat s
# is_cat k
# is_cat a
# is_cat s
# is_cat k
# is_cat b
# is_cat g
# is_cat g
# is_cat B
# is_cat S
# is_cat B
# is_cat e
# is_cat h
# is_cat A
# is_cat b
# is_cat c
# is_cat g
# is_cat B
# is_cat h
# is_cat n
# is_cat s
# is_cat R
# is_cat j
# is_cat c
# is_cat m
# is_cat s
# is_cat R
# is_cat a
# is_cat s
# is_cat a
# is_cat a
# is_cat p
# is_cat M
# is_cat k
# is_cat j
# is_cat B
# is_cat h
# is_cat M
# is_cat b
# is_cat l
# is_cat s
# is_cat B
# is_cat p
# is_cat R
# is_cat B
# is_cat B
# is_cat m
# is_cat w
# is_cat n
# is_cat l
# is_cat e
# is_cat s
# is_cat g
# is_cat a
# is_cat e
# is_cat g
# is_cat S
# is_cat A
# is_cat h
# is_cat s
# is_cat g
# is_cat s
# is_cat P
# is_cat l
# is_cat p
# is_cat S
# is_cat h
# is_cat b
# is_cat y
# is_cat B
# is_cat b
# is_cat B
# is_cat P
# is_cat a
# is_cat l
# is_cat e
# is_cat B
# is_cat p
# is_cat s
# is_cat m
# is_cat w
# is_cat m
# is_cat c
# is_cat e
# is_cat s
# is_cat s
# is_cat a
# is_cat S
# is_cat s
# is_cat B
# is_cat y
# is_cat a
# is_cat B
# is_cat S
# is_cat s
# is_cat s
# is_cat w
# is_cat w
# is_cat R
# is_cat m
# is_cat B
# is_cat p
# is_cat g
# is_cat A
# is_cat P
# is_cat c
# is_cat j
# is_cat w
# is_cat P
# is_cat s
# is_cat B
# is_cat b
# is_cat g
# is_cat B
# is_cat B
# is_cat m
# is_cat g
# is_cat e
# is_cat B
# is_cat s
# is_cat g
# is_cat M
# is_cat a
# is_cat s
# is_cat s
# is_cat P
# is_cat y
# is_cat b
# is_cat s
# is_cat B
# is_cat p
# is_cat E
# is_cat y
# is_cat n
# is_cat y
# is_cat P
# is_cat E
# is_cat a
# is_cat R
# is_cat B
# is_cat p
# is_cat p
# is_cat E
# is_cat B
# is_cat y
# is_cat P
# is_cat B
# is_cat g
# is_cat e
# is_cat P
# is_cat B
# is_cat a
# is_cat s
# is_cat c
# is_cat A
# is_cat g
# is_cat a
# is_cat j
# is_cat l
# is_cat b
# is_cat s
# is_cat h
# is_cat y
# is_cat l
# is_cat a
# is_cat h
# is_cat p
# is_cat h
# is_cat k
# is_cat B
# is_cat R
# is_cat B
# is_cat l
# is_cat k
# is_cat R
# is_cat M
# is_cat p
# is_cat h
# is_cat s
# is_cat p
# is_cat e
# is_cat a
# is_cat a
# is_cat g
# is_cat S
# is_cat g
# is_cat B
# is_cat B
# is_cat l
# is_cat P
# is_cat b
# is_cat w
# is_cat s
# is_cat a
# is_cat R
# is_cat p
# is_cat a
# is_cat B
# is_cat S
# is_cat s
# is_cat s
# is_cat w
# is_cat w
# is_cat P
# is_cat y
# is_cat s
# is_cat s

# %% [markdown]
# ... and train our model, a resnet18 (to keep it small and fast):

# %%
print(dls.get_image_files['.'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(dls.get_image_files['.'])
#
# File c:\Users\josef\anaconda3\envs\kaggle\Lib\site-packages\fastcore\basics.py:527, in GetAttr.__getattr__(self, k)
#     525 if self._component_attr_filter(k):
#     526     attr = getattr(self,self._default,None)
# --> 527     if attr is not None: return getattr(attr,k)
#     528 raise AttributeError(k)
#
# File c:\Users\josef\anaconda3\envs\kaggle\Lib\site-packages\fastcore\basics.py:527, in GetAttr.__getattr__(self, k)
#     525 if self._component_attr_filter(k):
#     526     attr = getattr(self,self._default,None)
# --> 527     if attr is not None: return getattr(attr,k)
#     528 raise AttributeError(k)
#
# File c:\Users\josef\anaconda3\envs\kaggle\Lib\site-packages\fastai\data\core.py:452, in Datasets.__getattr__(self, k)
#     449     res = tuple([tl[it] for tl in self.tls])
#     450     return res if is_indexer(it) else list(zip(*res))
# --> 452 def __getattr__(self,k): return gather_attrs(self, k, 'tls')
#     453 def __dir__(self): return super().__dir__() + gather_attr_names(self, 'tls')
#     454 def __len__(self): return len(self.tls[0])
#
# File c:\Users\josef\anaconda3\envs\kaggle\Lib\site-packages\fastcore\transform.py:175, in gather_attrs(o, k, nm)
#     173 att = getattr(o,nm)
#     174 res = [t for t in att.attrgot(k) if t is not None]
# --> 175 if not res: raise AttributeError(k)
#     176 return res[0] if len(res)==1 else L(res)
#
# AttributeError: get_image_files

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.213313</td>
#       <td>0.052912</td>
#       <td>0.020298</td>
#       <td>25:02</td>
#     </tr>
#   </tbody>
# </table>
# is_cat b
# is_cat h
# is_cat B
# is_cat B
# is_cat S
# is_cat A
# is_cat S
# is_cat P
# is_cat B
# is_cat b
# is_cat s
# is_cat l
# is_cat l
# is_cat h
# is_cat s
# is_cat B
# is_cat a
# is_cat s
# is_cat a
# is_cat n
# is_cat w
# is_cat S
# is_cat B
# is_cat B
# is_cat b
# is_cat b
# is_cat y
# is_cat k
# is_cat y
# is_cat s
# is_cat a
# is_cat p
# is_cat M
# is_cat n
# is_cat s
# is_cat b
# is_cat s
# is_cat p
# is_cat M
# is_cat m
# is_cat E
# is_cat S
# is_cat e
# is_cat h
# is_cat R
# is_cat c
# is_cat A
# is_cat e
# is_cat M
# is_cat s
# is_cat s
# is_cat s
# is_cat s
# is_cat s
# is_cat E
# is_cat e
# is_cat h
# is_cat k
# is_cat a
# is_cat B
# is_cat h
# is_cat c
# is_cat M
# is_cat s
# is_cat j
# is_cat g
# is_cat s
# is_cat S
# is_cat S
# is_cat S
# is_cat e
# is_cat E
# is_cat n
# is_cat y
# is_cat B
# is_cat g
# is_cat a
# is_cat k
# is_cat s
# is_cat s
# is_cat w
# is_cat b
# is_cat n
# is_cat R
# is_cat g
# is_cat s
# is_cat b
# is_cat R
# is_cat s
# is_cat c
# is_cat j
# is_cat p
# is_cat S
# is_cat e
# is_cat w
# is_cat S
# is_cat b
# is_cat b
# is_cat a
# is_cat m
# is_cat j
# is_cat m
# is_cat j
# is_cat s
# is_cat A
# is_cat p
# is_cat e
# is_cat S
# is_cat w
# is_cat B
# is_cat P
# is_cat B
# is_cat R
# is_cat l
# is_cat e
# is_cat A
# is_cat s
# is_cat P
# is_cat g
# is_cat b
# is_cat e
# is_cat a
# is_cat a
# is_cat p
# is_cat g
# is_cat g
# is_cat s
# is_cat s
# is_cat e
# is_cat S
# is_cat n
# is_cat B
# is_cat e
# is_cat E
# is_cat B
# is_cat p
# is_cat M
# is_cat a
# is_cat a
# is_cat s
# is_cat B
# is_cat a
# is_cat b
# is_cat B
# is_cat e
# is_cat j
# is_cat w
# is_cat e
# is_cat s
# is_cat e
# is_cat s
# is_cat h
# is_cat B
# is_cat s
# is_cat E
# is_cat A
# is_cat a
# is_cat m
# is_cat b
# is_cat a
# is_cat b
# is_cat B
# is_cat g
# is_cat A
# is_cat p
# is_cat B
# is_cat R
# is_cat y
# is_cat B
# is_cat E
# is_cat b
# is_cat E
# is_cat s
# is_cat s
# is_cat a
# is_cat R
# is_cat k
# is_cat y
# is_cat e
# is_cat B
# is_cat R
# is_cat P
# is_cat w
# is_cat g
# is_cat s
# is_cat w
# is_cat e
# is_cat A
# is_cat B
# is_cat s
# is_cat a
# is_cat R
# is_cat k
# is_cat j
# is_cat E
# is_cat j
# is_cat s
# is_cat w
# is_cat k
# is_cat B
# is_cat a
# is_cat g
# is_cat s
# is_cat R
# is_cat a
# is_cat m
# is_cat e
# is_cat p
# is_cat g
# is_cat M
# is_cat p
# is_cat B
# is_cat b
# is_cat S
# is_cat p
# is_cat E
# is_cat R
# is_cat n
# is_cat P
# is_cat b
# is_cat M
# is_cat p
# is_cat e
# is_cat k
# is_cat b
# is_cat R
# is_cat w
# is_cat p
# is_cat R
# is_cat E
# is_cat s
# is_cat P
# is_cat l
# is_cat B
# is_cat s
# is_cat e
# is_cat b
# is_cat b
# is_cat R
# is_cat m
# is_cat P
# is_cat b
# is_cat B
# is_cat e
# is_cat e
# is_cat k
# is_cat M
# is_cat p
# is_cat s
# is_cat s
# is_cat B
# is_cat g
# is_cat n
# is_cat e
# is_cat a
# is_cat b
# is_cat w
# is_cat S
# is_cat a
# is_cat s
# is_cat n
# is_cat e
# is_cat B
# is_cat h
# is_cat y
# is_cat A
# is_cat E
# is_cat s
# is_cat a
# is_cat k
# is_cat E
# is_cat g
# is_cat e
# is_cat b
# is_cat B
# is_cat e
# is_cat R
# is_cat R
# is_cat R
# is_cat B
# is_cat B
# is_cat s
# is_cat g
# is_cat b
# is_cat s
# is_cat B
# is_cat B
# is_cat a
# is_cat s
# is_cat e
# is_cat M
# is_cat g
# is_cat c
# is_cat S
# is_cat j
# is_cat c
# is_cat A
# is_cat S
# is_cat m
# is_cat l
# is_cat s
# is_cat B
# is_cat E
# is_cat E
# is_cat g
# is_cat c
# is_cat w
# is_cat k
# is_cat a
# is_cat e
# is_cat a
# is_cat p
# is_cat b
# is_cat A
# is_cat s
# is_cat s
# is_cat b
# is_cat b
# is_cat s
# is_cat m
# is_cat P
# is_cat s
# is_cat g
# is_cat s
# is_cat s
# is_cat E
# is_cat l
# is_cat B
# is_cat g
# is_cat B
# is_cat j
# is_cat S
# is_cat B
# is_cat S
# is_cat n
# is_cat B
# is_cat s
# is_cat R
# is_cat B
# is_cat y
# is_cat j
# is_cat R
# is_cat b
# is_cat w
# is_cat b
# is_cat S
# is_cat M
# is_cat m
# is_cat l
# is_cat e
# is_cat b
# is_cat B
# is_cat R
# is_cat c
# is_cat s
# is_cat c
# is_cat S
# is_cat B
# is_cat e
# is_cat B
# is_cat P
# is_cat j
# is_cat n
# is_cat g
# is_cat B
# is_cat a
# is_cat s
# is_cat E
# is_cat P
# is_cat n
# is_cat a
# is_cat a
# is_cat s
# is_cat b
# is_cat E
# is_cat m
# is_cat s
# is_cat P
# is_cat b
# is_cat g
# is_cat E
# is_cat B
# is_cat B
# is_cat e
# is_cat s
# is_cat B
# is_cat a
# is_cat b
# is_cat R
# is_cat a
# is_cat l
# is_cat B
# is_cat s
# is_cat s
# is_cat j
# is_cat R
# is_cat s
# is_cat j
# is_cat E
# is_cat e
# is_cat e
# is_cat w
# is_cat e
# is_cat P
# is_cat R
# is_cat p
# is_cat m
# is_cat B
# is_cat s
# is_cat a
# is_cat s
# is_cat e
# is_cat b
# is_cat B
# is_cat g
# is_cat s
# is_cat R
# is_cat h
# is_cat h
# is_cat g
# is_cat j
# is_cat P
# is_cat s
# is_cat A
# is_cat s
# is_cat s
# is_cat g
# is_cat e
# is_cat E
# is_cat R
# is_cat B
# is_cat g
# is_cat R
# is_cat s
# is_cat B
# is_cat s
# is_cat s
# is_cat s
# is_cat S
# is_cat B
# is_cat S
# is_cat s
# is_cat B
# is_cat s
# is_cat b
# is_cat b
# is_cat a
# is_cat c
# is_cat S
# is_cat s
# is_cat c
# is_cat P
# is_cat B
# is_cat s
# is_cat s
# is_cat s
# is_cat s
# is_cat s
# is_cat A
# is_cat g
# is_cat a
# is_cat b
# is_cat b
# is_cat p
# is_cat n
# is_cat g
# is_cat h
# is_cat p
# is_cat g
# is_cat g
# is_cat b
# is_cat p
# is_cat S
# is_cat R
# is_cat B
# is_cat B
# is_cat b
# is_cat s
# is_cat s
# is_cat R
# is_cat b
# is_cat B
# is_cat n
# is_cat e
# is_cat P
# is_cat M
# is_cat n
# is_cat S
# is_cat e
# is_cat A
# is_cat w
# is_cat P
# is_cat w
# is_cat y
# is_cat y
# is_cat j
# is_cat w
# is_cat B
# is_cat a
# is_cat b
# is_cat s
# is_cat s
# is_cat b
# is_cat l
# is_cat c
# is_cat B
# is_cat R
# is_cat a
# is_cat S
# is_cat s
# is_cat h
# is_cat e
# is_cat g
# is_cat s
# is_cat E
# is_cat B
# is_cat j
# is_cat A
# is_cat R
# is_cat S
# is_cat e
# is_cat a
# is_cat P
# is_cat E
# is_cat P
# is_cat R
# is_cat w
# is_cat w
# is_cat R
# is_cat s
# is_cat S
# is_cat B
# is_cat S
# is_cat S
# is_cat a
# is_cat s
# is_cat b
# is_cat P
# is_cat S
# is_cat b
# is_cat a
# is_cat M
# is_cat s
# is_cat B
# is_cat R
# is_cat g
# is_cat s
# is_cat m
# is_cat n
# is_cat R
# is_cat p
# is_cat k
# is_cat b
# is_cat B
# is_cat c
# is_cat e
# is_cat n
# is_cat B
# is_cat p
# is_cat B
# is_cat b
# is_cat g
# is_cat e
# is_cat e
# is_cat b
# is_cat j
# is_cat g
# is_cat b
# is_cat w
# is_cat c
# is_cat n
# is_cat B
# is_cat a
# is_cat B
# is_cat g
# is_cat B
# is_cat g
# is_cat p
# is_cat b
# is_cat S
# is_cat B
# is_cat e
# is_cat l
# is_cat s
# is_cat s
# is_cat s
# is_cat B
# is_cat j
# is_cat A
# is_cat M
# is_cat s
# is_cat e
# is_cat w
# is_cat g
# is_cat j
# is_cat e
# is_cat j
# is_cat p
# is_cat b
# is_cat A
# is_cat j
# is_cat g
# is_cat E
# is_cat b
# is_cat R
# is_cat g
# is_cat R
# is_cat s
# is_cat b
# is_cat e
# is_cat s
# is_cat R
# is_cat n
# is_cat e
# is_cat b
# is_cat j
# is_cat E
# is_cat M
# is_cat s
# is_cat m
# is_cat B
# is_cat h
# is_cat k
# is_cat b
# is_cat j
# is_cat B
# is_cat s
# is_cat b
# is_cat l
# is_cat s
# is_cat S
# is_cat R
# is_cat b
# is_cat g
# is_cat B
# is_cat p
# is_cat j
# is_cat c
# is_cat b
# is_cat g
# is_cat p
# is_cat s
# is_cat p
# is_cat k
# is_cat b
# is_cat n
# is_cat R
# is_cat B
# is_cat B
# is_cat B
# is_cat e
# is_cat B
# is_cat b
# is_cat p
# is_cat h
# is_cat p
# is_cat s
# is_cat B
# is_cat e
# is_cat R
# is_cat g
# is_cat h
# is_cat S
# is_cat A
# is_cat P
# is_cat w
# is_cat n
# is_cat s
# is_cat P
# is_cat R
# is_cat B
# is_cat s
# is_cat c
# is_cat P
# is_cat c
# is_cat s
# is_cat s
# is_cat g
# is_cat P
# is_cat b
# is_cat b
# is_cat b
# is_cat s
# is_cat b
# is_cat g
# is_cat j
# is_cat R
# is_cat g
# is_cat k
# is_cat a
# is_cat B
# is_cat m
# is_cat g
# is_cat l
# is_cat R
# is_cat g
# is_cat B
# is_cat k
# is_cat e
# is_cat B
# is_cat B
# is_cat A
# is_cat n
# is_cat P
# is_cat P
# is_cat b
# is_cat m
# is_cat R
# is_cat s
# is_cat M
# is_cat B
# is_cat s
# is_cat R
# is_cat c
# is_cat p
# is_cat P
# is_cat B
# is_cat B
# is_cat g
# is_cat g
# is_cat a
# is_cat R
# is_cat l
# is_cat l
# is_cat A
# is_cat b
# is_cat p
# is_cat j
# is_cat s
# is_cat a
# is_cat B
# is_cat A
# is_cat b
# is_cat S
# is_cat M
# is_cat P
# is_cat R
# is_cat m
# is_cat y
# is_cat w
# is_cat e
# is_cat a
# is_cat e
# is_cat k
# is_cat g
# is_cat l
# is_cat s
# is_cat g
# is_cat s
# is_cat B
# is_cat y
# is_cat A
# is_cat B
# is_cat A
# is_cat w
# is_cat s
# is_cat m
# is_cat B
# is_cat l
# is_cat s
# is_cat b
# is_cat b
# is_cat A
# is_cat g
# is_cat w
# is_cat B
# is_cat e
# is_cat h
# is_cat b
# is_cat b
# is_cat h
# is_cat S
# is_cat A
# is_cat b
# is_cat j
# is_cat k
# is_cat s
# is_cat l
# is_cat R
# is_cat b
# is_cat M
# is_cat a
# is_cat b
# is_cat A
# is_cat y
# is_cat R
# is_cat g
# is_cat s
# is_cat s
# is_cat e
# is_cat y
# is_cat n
# is_cat B
# is_cat m
# is_cat R
# is_cat S
# is_cat l
# is_cat k
# is_cat S
# is_cat B
# is_cat R
# is_cat k
# is_cat y
# is_cat M
# is_cat h
# is_cat S
# is_cat b
# is_cat g
# is_cat s
# is_cat h
# is_cat l
# is_cat S
# is_cat c
# is_cat c
# is_cat P
# is_cat S
# is_cat a
# is_cat E
# is_cat j
# is_cat P
# is_cat B
# is_cat S
# is_cat s
# is_cat s
# is_cat b
# is_cat w
# is_cat S
# is_cat a
# is_cat j
# is_cat y
# is_cat p
# is_cat l
# is_cat b
# is_cat M
# is_cat b
# is_cat b
# is_cat B
# is_cat e
# is_cat e
# is_cat g
# is_cat s
# is_cat b
# is_cat h
# is_cat e
# is_cat l
# is_cat s
# is_cat s
# is_cat R
# is_cat g
# is_cat b
# is_cat M
# is_cat R
# is_cat S
# is_cat M
# is_cat e
# is_cat E
# is_cat e
# is_cat E
# is_cat B
# is_cat P
# is_cat s
# is_cat w
# is_cat n
# is_cat e
# is_cat s
# is_cat B
# is_cat S
# is_cat B
# is_cat j
# is_cat m
# is_cat w
# is_cat s
# is_cat j
# is_cat E
# is_cat P
# is_cat g
# is_cat p
# is_cat E
# is_cat B
# is_cat c
# is_cat c
# is_cat s
# is_cat S
# is_cat g
# is_cat h
# is_cat B
# is_cat g
# is_cat w
# is_cat s
# is_cat p
# is_cat b
# is_cat y
# is_cat p
# is_cat s
# is_cat S
# is_cat p
# is_cat h
# is_cat B
# is_cat b
# is_cat a
# is_cat R
# is_cat c
# is_cat R
# is_cat M
# is_cat p
# is_cat s
# is_cat n
# is_cat m
# is_cat l
# is_cat B
# is_cat M
# is_cat s
# is_cat S
# is_cat B
# is_cat k
# is_cat P
# is_cat b
# is_cat a
# is_cat p
# is_cat E
# is_cat b
# is_cat p
# is_cat p
# is_cat R
# is_cat p
# is_cat b
# is_cat s
# is_cat a
# is_cat R
# is_cat w
# is_cat w
# is_cat B
# is_cat B
# is_cat b
# is_cat B
# is_cat P
# is_cat B
# is_cat p
# is_cat B
# is_cat g
# is_cat s
# is_cat S
# is_cat B
# is_cat R
# is_cat p
# is_cat A
# is_cat m
# is_cat B
# is_cat s
# is_cat s
# is_cat S
# is_cat R
# is_cat p
# is_cat h
# is_cat b
# is_cat S
# is_cat s
# is_cat s
# is_cat S
# is_cat A
# is_cat h
# is_cat B
# is_cat M
# is_cat j
# is_cat a
# is_cat B
# is_cat y
# is_cat E
# is_cat n
# is_cat B
# is_cat s
# is_cat P
# is_cat B
# is_cat b
# is_cat s
# is_cat l
# is_cat E
# is_cat B
# is_cat B
# is_cat w
# is_cat y
# is_cat s
# is_cat b
# is_cat a
# is_cat y
# is_cat p
# is_cat R
# is_cat S
# is_cat B
# is_cat S
# is_cat S
# is_cat g
# is_cat R
# is_cat l
# is_cat e
# is_cat s
# is_cat n
# is_cat b
# is_cat B
# is_cat E
# is_cat b
# is_cat R
# is_cat E
# is_cat B
# is_cat p
# is_cat e
# is_cat B
# is_cat R
# is_cat w
# is_cat s
# is_cat b
# is_cat A
# is_cat s
# is_cat M
# is_cat B
# is_cat s
# is_cat M
# is_cat a
# is_cat A
# is_cat g
# is_cat a
# is_cat S
# is_cat j
# is_cat n
# is_cat g
# is_cat b
# is_cat B
# is_cat B
# is_cat y
# is_cat b
# is_cat k
# is_cat a
# is_cat k
# is_cat w
# is_cat s
# is_cat e
# is_cat B
# is_cat B
# is_cat E
# is_cat w
# is_cat A
# is_cat B
# is_cat B
# is_cat M
# is_cat S
# is_cat g
# is_cat c
# is_cat s
# is_cat p
# is_cat e
# is_cat E
# is_cat a
# is_cat B
# is_cat m
# is_cat S
# is_cat g
# is_cat e
# is_cat e
# is_cat e
# is_cat c
# is_cat e
# is_cat B
# is_cat b
# is_cat m
# is_cat S
# is_cat B
# is_cat c
# is_cat B
# is_cat s
# is_cat S
# is_cat B
# is_cat a
# is_cat l
# is_cat S
# is_cat S
# is_cat p
# is_cat s
# is_cat M
# is_cat a
# is_cat g
# is_cat p
# is_cat s
# is_cat b
# is_cat p
# is_cat a
# is_cat s
# is_cat a
# is_cat A
# is_cat A
# is_cat n
# is_cat M
# is_cat h
# is_cat c
# is_cat a
# is_cat j
# is_cat p
# is_cat a
# is_cat B
# is_cat b
# is_cat s
# is_cat R
# is_cat S
# is_cat j
# is_cat k
# is_cat A
# is_cat a
# is_cat p
# is_cat S
# is_cat e
# is_cat s
# is_cat s
# is_cat E
# is_cat n
# is_cat l
# is_cat b
# is_cat S
# is_cat e
# is_cat s
# is_cat s
# is_cat B
# is_cat n
# is_cat B
# is_cat h
# is_cat R
# is_cat s
# is_cat B
# is_cat b
# is_cat p
# is_cat j
# is_cat p
# is_cat p
# is_cat p
# is_cat p
# is_cat R
# is_cat m
# is_cat M
# is_cat s
# is_cat g
# is_cat B
# is_cat p
# is_cat e
# is_cat a
# is_cat n
# is_cat n
# is_cat j
# is_cat R
# is_cat s
# is_cat l
# is_cat B
# is_cat E
# is_cat y
# is_cat h
# is_cat s
# is_cat M
# is_cat p
# is_cat b
# is_cat s
# is_cat s
# is_cat l
# is_cat a
# is_cat S
# is_cat e
# is_cat g
# is_cat A
# is_cat p
# is_cat B
# is_cat g
# is_cat n
# is_cat b
# is_cat e
# is_cat B
# is_cat n
# is_cat A
# is_cat b
# is_cat p
# is_cat b
# is_cat R
# is_cat P
# is_cat S
# is_cat B
# is_cat e
# is_cat m
# is_cat s
# is_cat a
# is_cat m
# is_cat b
# is_cat p
# is_cat y
# is_cat g
# is_cat S
# is_cat e
# is_cat p
# is_cat b
# is_cat e
# is_cat s
# is_cat h
# is_cat B
# is_cat S
# is_cat e
# is_cat y
# is_cat M
# is_cat E
# is_cat R
# is_cat s
# is_cat y
# is_cat l
# is_cat b
# is_cat m
# is_cat k
# is_cat e
# is_cat M
# is_cat A
# is_cat S
# is_cat s
# is_cat g
# is_cat g
# is_cat l
# is_cat s
# is_cat B
# is_cat k
# is_cat k
# is_cat y
# is_cat p
# is_cat B
# is_cat S
# is_cat n
# is_cat m
# is_cat a
# is_cat s
# is_cat s
# is_cat s
# is_cat c
# is_cat p
# is_cat j
# is_cat R
# is_cat B
# is_cat b
# is_cat s
# is_cat p
# is_cat b
# is_cat e
# is_cat B
# is_cat k
# is_cat n
# is_cat w
# is_cat M
# is_cat a
# is_cat b
# is_cat s
# is_cat g
# is_cat b
# is_cat a
# is_cat S
# is_cat M
# is_cat R
# is_cat S
# is_cat h
# is_cat B
# is_cat h
# is_cat y
# is_cat s
# is_cat k
# is_cat B
# is_cat g
# is_cat g
# is_cat s
# is_cat s
# is_cat s
# is_cat g
# is_cat e
# is_cat l
# is_cat s
# is_cat B
# is_cat P
# is_cat n
# is_cat p
# is_cat c
# is_cat P
# is_cat g
# is_cat s
# is_cat a
# is_cat l
# is_cat S
# is_cat a
# is_cat s
# is_cat S
# is_cat b
# is_cat y
# is_cat S
# is_cat s
# is_cat w
# is_cat P
# is_cat y
# is_cat k
# is_cat B
# is_cat e
# is_cat S
# is_cat A
# is_cat E
# is_cat s
# is_cat e
# is_cat R
# is_cat P
# is_cat h
# is_cat s
# is_cat l
# is_cat b
# is_cat s
# is_cat a
# is_cat B
# is_cat g
# is_cat B
# is_cat b
# is_cat w
# is_cat g
# is_cat p
# is_cat w
# is_cat a
# is_cat A
# is_cat s
# is_cat g
# is_cat A
# is_cat S
# is_cat B
# is_cat w
# is_cat p
# is_cat B
# is_cat y
# is_cat c
# is_cat a
# is_cat y
# is_cat b
# is_cat E
# is_cat R
# is_cat B
# is_cat a
# is_cat s
# is_cat b
# is_cat b
# is_cat k
# is_cat s
# is_cat S
# is_cat M
# is_cat S
# is_cat g
# is_cat R
# is_cat n
# is_cat e
# is_cat e
# is_cat s
# is_cat e
# is_cat R
# is_cat b
# is_cat E
# is_cat g
# is_cat s
# is_cat m
# is_cat B
# is_cat S
# is_cat n
# is_cat R
# is_cat B
# is_cat w
# is_cat P
# is_cat A
# is_cat S
# is_cat E
# is_cat g
# is_cat s
# is_cat m
# is_cat y
# is_cat y
# is_cat e
# is_cat w
# is_cat e
# is_cat e
# is_cat n
# is_cat s
# is_cat b
# is_cat S
# is_cat B
# is_cat B
# is_cat p
# is_cat p
# is_cat e
# is_cat s
# is_cat n
# is_cat S
# is_cat p
# is_cat P
# is_cat B
# is_cat p
# is_cat b
# is_cat w
# is_cat g
# is_cat E
# is_cat b
# is_cat s
# is_cat c
# is_cat k
# is_cat b
# is_cat S
# is_cat s
# is_cat m
# is_cat e
# is_cat s
# is_cat s
# is_cat n
# is_cat B
# is_cat l
# is_cat l
# is_cat b
# is_cat a
# is_cat e
# is_cat p
# is_cat g
# is_cat p
# is_cat B
# is_cat e
# is_cat S
# is_cat s
# is_cat B
# is_cat y
# is_cat l
# is_cat b
# is_cat s
# is_cat k
# is_cat y
# is_cat P
# is_cat n
# is_cat m
# is_cat B
# is_cat w
# is_cat y
# is_cat B
# is_cat s
# is_cat B
# is_cat g
# is_cat M
# is_cat R
# is_cat h
# is_cat B
# is_cat j
# is_cat s
# is_cat B
# is_cat a
# is_cat b
# is_cat e
# is_cat R
# is_cat a
# is_cat m
# is_cat s
# is_cat P
# is_cat k
# is_cat B
# is_cat p
# is_cat s
# is_cat y
# is_cat B
# is_cat S
# is_cat s
# is_cat M
# is_cat p
# is_cat p
# is_cat p
# is_cat a
# is_cat B
# is_cat s
# is_cat h
# is_cat a
# is_cat m
# is_cat a
# is_cat s
# is_cat s
# is_cat b
# is_cat R
# is_cat B
# is_cat R
# is_cat s
# is_cat s
# is_cat S
# is_cat s
# is_cat R
# is_cat h
# is_cat k
# is_cat y
# is_cat b
# is_cat p
# is_cat B
# is_cat b
# is_cat h
# is_cat s
# is_cat s
# is_cat n
# is_cat B
# is_cat R
# is_cat p
# is_cat s
# is_cat p
# is_cat e
# is_cat k
# is_cat b
# is_cat B
# is_cat B
# is_cat k
# is_cat b
# is_cat a
# is_cat b
# is_cat a
# is_cat s
# is_cat h
# is_cat B
# is_cat g
# is_cat s
# is_cat e
# is_cat g
# is_cat B
# is_cat s
# is_cat h
# is_cat S
# is_cat p
# is_cat s
# is_cat M
# is_cat A
# is_cat l
# is_cat b
# is_cat E
# is_cat s
# is_cat w
# is_cat s
# is_cat e
# is_cat p
# is_cat S
# is_cat j
# is_cat b
# is_cat R
# is_cat k
# is_cat p
# is_cat B
# is_cat S
# is_cat l
# is_cat s
# is_cat s
# is_cat B
# is_cat s
# is_cat h
# is_cat k
# is_cat b
# is_cat B
# is_cat e
# is_cat B
# is_cat B
# is_cat j
# is_cat M
# is_cat S
# is_cat B
# is_cat g
# is_cat B
# is_cat E
# is_cat B
# is_cat p
# is_cat m
# is_cat R
# is_cat B
# is_cat A
# is_cat E
# is_cat e
# is_cat a
# is_cat b
# is_cat s
# is_cat M
# is_cat B
# is_cat s
# is_cat y
# is_cat j
# is_cat n
# is_cat g
# is_cat B
# is_cat s
# is_cat a
# is_cat s
# is_cat a
# is_cat s
# is_cat S
# is_cat k
# is_cat S
# is_cat c
# is_cat S
# is_cat s
# is_cat R
# is_cat B
# is_cat j
# is_cat s
# is_cat B
# is_cat b
# is_cat B
# is_cat b
# is_cat R
# is_cat j
# is_cat R
# is_cat P
# is_cat R
# is_cat B
# is_cat g
# is_cat E
# is_cat e
# is_cat R
# is_cat m
# is_cat b
# is_cat m
# is_cat h
# is_cat M
# is_cat R
# is_cat M
# is_cat a
# is_cat e
# is_cat p
# is_cat B
# is_cat E
# is_cat s
# is_cat p
# is_cat a
# is_cat e
# is_cat y
# is_cat A
# is_cat P
# is_cat R
# is_cat R
# is_cat m
# is_cat R
# is_cat B
# is_cat S
# is_cat k
# is_cat y
# is_cat g
# is_cat S
# is_cat k
# is_cat y
# is_cat n
# is_cat c
# is_cat g
# is_cat a
# is_cat b
# is_cat B
# is_cat R
# is_cat p
# is_cat B
# is_cat R
# is_cat h
# is_cat g
# is_cat B
# is_cat s
# is_cat B
# is_cat j
# is_cat y
# is_cat n
# is_cat A
# is_cat B
# is_cat R
# is_cat k
# is_cat M
# is_cat j
# is_cat p
# is_cat a
# is_cat e
# is_cat g
# is_cat h
# is_cat m
# is_cat s
# is_cat a
# is_cat s
# is_cat s
# is_cat s
# is_cat c
# is_cat P
# is_cat b
# is_cat s
# is_cat g
# is_cat B
# is_cat n
# is_cat R
# is_cat p
# is_cat S
# is_cat b
# is_cat S
# is_cat s
# is_cat b
# is_cat l
# is_cat e
# is_cat m
# is_cat R
# is_cat b
# is_cat A
# is_cat s
# is_cat R
# is_cat g
# is_cat B
# is_cat l
# is_cat e
# is_cat s
# is_cat e
# is_cat R
# is_cat a
# is_cat S
# is_cat a
# is_cat m
# is_cat b
# is_cat B
# is_cat n
# is_cat S
# is_cat k
# is_cat m
# is_cat e
# is_cat g
# is_cat k
# is_cat S
# is_cat s
# is_cat w
# is_cat l
# is_cat n
# is_cat e
# is_cat c
# is_cat E
# is_cat k
# is_cat w
# is_cat B
# is_cat g
# is_cat h
# is_cat b
# is_cat s
# is_cat S
# is_cat b
# is_cat h
# is_cat j
# is_cat E
# is_cat j
# is_cat s
# is_cat a
# is_cat P
# is_cat n
# is_cat b
# is_cat k
# is_cat B
# is_cat s
# is_cat B
# is_cat w
# is_cat A
# is_cat p
# is_cat y
# is_cat b
# is_cat b
# is_cat s
# is_cat w
# is_cat n
# is_cat s
# is_cat k
# is_cat s
# is_cat R
# is_cat B
# is_cat w
# is_cat y
# is_cat a
# is_cat j
# is_cat B
# is_cat R
# is_cat a
# is_cat R
# is_cat g
# is_cat s
# is_cat R
# is_cat y
# is_cat s
# is_cat S
# is_cat y
# is_cat R
# is_cat w
# is_cat g
# is_cat y
# is_cat b
# is_cat h
# is_cat A
# is_cat g
# is_cat R
# is_cat s
# is_cat g
# is_cat p
# is_cat S
# is_cat g
# is_cat s
# is_cat p
# is_cat E
# is_cat R
# is_cat j
# is_cat s
# is_cat s
# is_cat R
# is_cat b
# is_cat a
# is_cat B
# is_cat p
# is_cat b
# is_cat c
# is_cat b
# is_cat a
# is_cat y
# is_cat b
# is_cat k
# is_cat R
# is_cat e
# is_cat B
# is_cat n
# is_cat a
# is_cat p
# is_cat a
# is_cat k
# is_cat A
# is_cat R
# is_cat M
# is_cat m
# is_cat s
# is_cat A
# is_cat a
# is_cat m
# is_cat B
# is_cat c
# is_cat s
# is_cat B
# is_cat R
# is_cat a
# is_cat g
# is_cat A
# is_cat E
# is_cat e
# is_cat p
# is_cat p
# is_cat a
# is_cat M
# is_cat R
# is_cat e
# is_cat B
# is_cat s
# is_cat g
# is_cat e
# is_cat E
# is_cat w
# is_cat S
# is_cat b
# is_cat B
# is_cat p
# is_cat M
# is_cat B
# is_cat e
# is_cat l
# is_cat s
# is_cat E
# is_cat S
# is_cat e
# is_cat b
# is_cat g
# is_cat k
# is_cat k
# is_cat a
# is_cat p
# is_cat g
# is_cat R
# is_cat B
# is_cat m
# is_cat B
# is_cat p
# is_cat p
# is_cat s
# is_cat A
# is_cat M
# is_cat e
# is_cat B
# is_cat p
# is_cat S
# is_cat B
# is_cat B
# is_cat M
# is_cat P
# is_cat g
# is_cat a
# is_cat s
# is_cat E
# is_cat l
# is_cat h
# is_cat b
# is_cat k
# is_cat c
# is_cat n
# is_cat s
# is_cat M
# is_cat k
# is_cat S
# is_cat e
# is_cat s
# is_cat s
# is_cat B
# is_cat B
# is_cat s
# is_cat w
# is_cat R
# is_cat S
# is_cat m
# is_cat m
# is_cat S
# is_cat B
# is_cat B
# is_cat s
# is_cat s
# is_cat h
# is_cat M
# is_cat b
# is_cat n
# is_cat M
# is_cat y
# is_cat b
# is_cat B
# is_cat c
# is_cat w
# is_cat A
# is_cat g
# is_cat l
# is_cat h
# is_cat A
# is_cat p
# is_cat p
# is_cat y
# is_cat e
# is_cat g
# is_cat p
# is_cat s
# is_cat p
# is_cat e
# is_cat h
# is_cat B
# is_cat R
# is_cat B
# is_cat n
# is_cat R
# is_cat k
# is_cat a
# is_cat l
# is_cat g
# is_cat e
# is_cat w
# is_cat m
# is_cat B
# is_cat M
# is_cat a
# is_cat b
# is_cat S
# is_cat n
# is_cat M
# is_cat e
# is_cat s
# is_cat b
# is_cat k
# is_cat g
# is_cat k
# is_cat l
# is_cat E
# is_cat c
# is_cat h
# is_cat p
# is_cat s
# is_cat s
# is_cat B
# is_cat B
# is_cat s
# is_cat s
# is_cat l
# is_cat a
# is_cat g
# is_cat g
# is_cat b
# is_cat y
# is_cat S
# is_cat s
# is_cat b
# is_cat s
# is_cat b
# is_cat B
# is_cat s
# is_cat B
# is_cat y
# is_cat j
# is_cat M
# is_cat B
# is_cat b
# is_cat j
# is_cat s
# is_cat B
# is_cat B
# is_cat s
# is_cat l
# is_cat s
# is_cat w
# is_cat s
# is_cat a
# is_cat a
# is_cat a
# is_cat R
# is_cat y
# is_cat b
# is_cat b
# is_cat M
# is_cat l
# is_cat y
# is_cat B
# is_cat P
# is_cat s
# is_cat S
# is_cat e
# is_cat B
# is_cat n
# is_cat s
# is_cat a
# is_cat S
# is_cat p
# is_cat s
# is_cat B
# is_cat S
# is_cat c
# is_cat g
# is_cat R
# is_cat s
# is_cat k
# is_cat s
# is_cat e
# is_cat e
# is_cat S
# is_cat w
# is_cat h
# is_cat e
# is_cat A
# is_cat R
# is_cat w
# is_cat M
# is_cat b
# is_cat w
# is_cat S
# is_cat s
# is_cat y
# is_cat b
# is_cat g
# is_cat S
# is_cat M
# is_cat B
# is_cat g
# is_cat e
# is_cat s
# is_cat B
# is_cat p
# is_cat c
# is_cat j
# is_cat a
# is_cat R
# is_cat R
# is_cat B
# is_cat B
# is_cat g
# is_cat E
# is_cat j
# is_cat c
# is_cat S
# is_cat a
# is_cat g
# is_cat S
# is_cat B
# is_cat p
# is_cat s
# is_cat s
# is_cat E
# is_cat A
# is_cat B
# is_cat B
# is_cat j
# is_cat s
# is_cat s
# is_cat l
# is_cat p
# is_cat h
# is_cat A
# is_cat R
# is_cat A
# is_cat n
# is_cat j
# is_cat B
# is_cat B
# is_cat c
# is_cat B
# is_cat B
# is_cat e
# is_cat R
# is_cat B
# is_cat y
# is_cat S
# is_cat k
# is_cat j
# is_cat S
# is_cat e
# is_cat n
# is_cat s
# is_cat E
# is_cat M
# is_cat k
# is_cat R
# is_cat w
# is_cat B
# is_cat e
# is_cat s
# is_cat p
# is_cat g
# is_cat e
# is_cat s
# is_cat R
# is_cat s
# is_cat w
# is_cat P
# is_cat w
# is_cat s
# is_cat p
# is_cat B
# is_cat n
# is_cat b
# is_cat B
# is_cat A
# is_cat p
# is_cat s
# is_cat j
# is_cat S
# is_cat l
# is_cat S
# is_cat l
# is_cat s
# is_cat B
# is_cat S
# is_cat R
# is_cat b
# is_cat s
# is_cat s
# is_cat R
# is_cat p
# is_cat s
# is_cat P
# is_cat M
# is_cat b
# is_cat e
# is_cat j
# is_cat B
# is_cat b
# is_cat B
# is_cat b
# is_cat s
# is_cat y
# is_cat B
# is_cat k
# is_cat E
# is_cat m
# is_cat y
# is_cat a
# is_cat s
# is_cat b
# is_cat S
# is_cat j
# is_cat a
# is_cat B
# is_cat w
# is_cat B
# is_cat P
# is_cat R
# is_cat y
# is_cat B
# is_cat p
# is_cat g
# is_cat B
# is_cat j
# is_cat A
# is_cat S
# is_cat p
# is_cat p
# is_cat m
# is_cat a
# is_cat A
# is_cat B
# is_cat a
# is_cat h
# is_cat g
# is_cat e
# is_cat h
# is_cat a
# is_cat y
# is_cat n
# is_cat S
# is_cat k
# is_cat S
# is_cat E
# is_cat g
# is_cat E
# is_cat M
# is_cat y
# is_cat h
# is_cat A
# is_cat R
# is_cat R
# is_cat k
# is_cat e
# is_cat m
# is_cat s
# is_cat R
# is_cat M
# is_cat j
# is_cat s
# is_cat B
# is_cat w
# is_cat w
# is_cat g
# is_cat h
# is_cat e
# is_cat a
# is_cat B
# is_cat h
# is_cat S
# is_cat w
# is_cat p
# is_cat p
# is_cat h
# is_cat B
# is_cat h
# is_cat k
# is_cat w
# is_cat B
# is_cat a
# is_cat s
# is_cat c
# is_cat b
# is_cat k
# is_cat E
# is_cat S
# is_cat B
# is_cat s
# is_cat g
# is_cat A
# is_cat a
# is_cat g
# is_cat M
# is_cat R
# is_cat e
# is_cat s
# is_cat l
# is_cat a
# is_cat a
# is_cat B
# is_cat h
# is_cat E
# is_cat b
# is_cat g
# is_cat B
# is_cat B
# is_cat b
# is_cat e
# is_cat c
# is_cat g
# is_cat e
# is_cat c
# is_cat c
# is_cat s
# is_cat g
# is_cat e
# is_cat h
# is_cat B
# is_cat k
# is_cat g
# is_cat n
# is_cat g
# is_cat a
# is_cat M
# is_cat w
# is_cat e
# is_cat p
# is_cat B
# is_cat M
# is_cat b
# is_cat g
# is_cat y
# is_cat S
# is_cat E
# is_cat S
# is_cat c
# is_cat k
# is_cat E
# is_cat A
# is_cat B
# is_cat l
# is_cat g
# is_cat e
# is_cat k
# is_cat B
# is_cat j
# is_cat p
# is_cat R
# is_cat s
# is_cat p
# is_cat k
# is_cat B
# is_cat l
# is_cat a
# is_cat e
# is_cat B
# is_cat P
# is_cat j
# is_cat s
# is_cat b
# is_cat l
# is_cat S
# is_cat m
# is_cat B
# is_cat s
# is_cat B
# is_cat s
# is_cat P
# is_cat S
# is_cat j
# is_cat B
# is_cat b
# is_cat M
# is_cat p
# is_cat p
# is_cat P
# is_cat S
# is_cat M
# is_cat A
# is_cat s
# is_cat l
# is_cat w
# is_cat a
# is_cat s
# is_cat m
# is_cat B
# is_cat B
# is_cat p
# is_cat b
# is_cat g
# is_cat M
# is_cat B
# is_cat b
# is_cat y
# is_cat y
# is_cat c
# is_cat c
# is_cat s
# is_cat g
# is_cat R
# is_cat a
# is_cat b
# is_cat y
# is_cat R
# is_cat R
# is_cat A
# is_cat s
# is_cat s
# is_cat b
# is_cat j
# is_cat B
# is_cat s
# is_cat p
# is_cat b
# is_cat B
# is_cat B
# is_cat s
# is_cat y
# is_cat h
# is_cat B
# is_cat M
# is_cat w
# is_cat b
# is_cat s
# is_cat g
# is_cat p
# is_cat S
# is_cat a
# is_cat l
# is_cat M
# is_cat S
# is_cat l
# is_cat p
# is_cat b
# is_cat m
# is_cat B
# is_cat B
# is_cat S
# is_cat B
# is_cat s
# is_cat B
# is_cat a
# is_cat j
# is_cat g
# is_cat c
# is_cat p
# is_cat E
# is_cat B
# is_cat B
# is_cat c
# is_cat b
# is_cat B
# is_cat E
# is_cat b
# is_cat R
# is_cat s
# is_cat e
# is_cat c
# is_cat l
# is_cat P
# is_cat p
# is_cat l
# is_cat b
# is_cat a
# is_cat S
# is_cat g
# is_cat j
# is_cat w
# is_cat E
# is_cat e
# is_cat E
# is_cat A
# is_cat s
# is_cat w
# is_cat n
# is_cat a
# is_cat b
# is_cat p
# is_cat p
# is_cat a
# is_cat a
# is_cat m
# is_cat M
# is_cat B
# is_cat b
# is_cat R
# is_cat B
# is_cat b
# is_cat k
# is_cat s
# is_cat a
# is_cat B
# is_cat k
# is_cat p
# is_cat E
# is_cat l
# is_cat b
# is_cat y
# is_cat R
# is_cat w
# is_cat s
# is_cat p
# is_cat s
# is_cat n
# is_cat R
# is_cat c
# is_cat k
# is_cat a
# is_cat p
# is_cat s
# is_cat j
# is_cat B
# is_cat w
# is_cat R
# is_cat e
# is_cat m
# is_cat n
# is_cat b
# is_cat B
# is_cat p
# is_cat n
# is_cat s
# is_cat B
# is_cat e
# is_cat m
# is_cat b
# is_cat m
# is_cat l
# is_cat m
# is_cat M
# is_cat g
# is_cat j
# is_cat S
# is_cat A
# is_cat e
# is_cat M
# is_cat j
# is_cat b
# is_cat n
# is_cat s
# is_cat R
# is_cat c
# is_cat m
# is_cat P
# is_cat a
# is_cat c
# is_cat A
# is_cat b
# is_cat B
# is_cat m
# is_cat b
# is_cat n
# is_cat m
# is_cat E
# is_cat R
# is_cat k
# is_cat y
# is_cat s
# is_cat s
# is_cat w
# is_cat c
# is_cat S
# is_cat A
# is_cat p
# is_cat p
# is_cat p
# is_cat s
# is_cat e
# is_cat S
# is_cat B
# is_cat y
# is_cat R
# is_cat A
# is_cat S
# is_cat b
# is_cat s
# is_cat a
# is_cat a
# is_cat c
# is_cat b
# is_cat h
# is_cat g
# is_cat b
# is_cat B
# is_cat k
# is_cat R
# is_cat s
# is_cat s
# is_cat a
# is_cat b
# is_cat p
# is_cat s
# is_cat h
# is_cat E
# is_cat R
# is_cat B
# is_cat n
# is_cat l
# is_cat m
# is_cat P
# is_cat B
# is_cat R
# is_cat A
# is_cat s
# is_cat S
# is_cat a
# is_cat s
# is_cat g
# is_cat b
# is_cat B
# is_cat h
# is_cat b
# is_cat p
# is_cat s
# is_cat S
# is_cat k
# is_cat y
# is_cat B
# is_cat p
# is_cat c
# is_cat b
# is_cat s
# is_cat j
# is_cat s
# is_cat a
# is_cat p
# is_cat s
# is_cat s
# is_cat g
# is_cat k
# is_cat j
# is_cat B
# is_cat w
# is_cat p
# is_cat m
# is_cat a
# is_cat s
# is_cat k
# is_cat S
# is_cat s
# is_cat s
# is_cat e
# is_cat g
# is_cat s
# is_cat p
# is_cat g
# is_cat p
# is_cat s
# is_cat b
# is_cat l
# is_cat w
# is_cat y
# is_cat B
# is_cat b
# is_cat b
# is_cat h
# is_cat s
# is_cat a
# is_cat w
# is_cat g
# is_cat s
# is_cat k
# is_cat m
# is_cat P
# is_cat j
# is_cat g
# is_cat E
# is_cat l
# is_cat b
# is_cat g
# is_cat s
# is_cat y
# is_cat b
# is_cat A
# is_cat s
# is_cat M
# is_cat j
# is_cat m
# is_cat B
# is_cat e
# is_cat n
# is_cat R
# is_cat b
# is_cat a
# is_cat l
# is_cat w
# is_cat s
# is_cat s
# is_cat w
# is_cat b
# is_cat k
# is_cat j
# is_cat P
# is_cat s
# is_cat b
# is_cat s
# is_cat h
# is_cat s
# is_cat R
# is_cat P
# is_cat y
# is_cat l
# is_cat R
# is_cat p
# is_cat p
# is_cat S
# is_cat B
# is_cat p
# is_cat P
# is_cat P
# is_cat R
# is_cat y
# is_cat b
# is_cat m
# is_cat B
# is_cat s
# is_cat k
# is_cat g
# is_cat R
# is_cat s
# is_cat e
# is_cat b
# is_cat B
# is_cat B
# is_cat A
# is_cat p
# is_cat k
# is_cat w
# is_cat p
# is_cat b
# is_cat R
# is_cat b
# is_cat b
# is_cat E
# is_cat a
# is_cat s
# is_cat S
# is_cat M
# is_cat p
# is_cat b
# is_cat e
# is_cat s
# is_cat s
# is_cat R
# is_cat S
# is_cat y
# is_cat a
# is_cat b
# is_cat b
# is_cat s
# is_cat c
# is_cat s
# is_cat s
# is_cat b
# is_cat s
# is_cat y
# is_cat S
# is_cat g
# is_cat b
# is_cat s
# is_cat s
# is_cat s
# is_cat h
# is_cat a
# is_cat s
# is_cat s
# is_cat s
# is_cat E
# is_cat j
# is_cat s
# is_cat b
# is_cat s
# is_cat P
# is_cat k
# is_cat R
# is_cat e
# is_cat s
# is_cat B
# is_cat b
# is_cat B
# is_cat a
# is_cat b
# is_cat p
# is_cat s
# is_cat R
# is_cat e
# is_cat c
# is_cat c
# is_cat m
# is_cat m
# is_cat g
# is_cat s
# is_cat S
# is_cat S
# is_cat j
# is_cat n
# is_cat b
# is_cat l
# is_cat B
# is_cat h
# is_cat e
# is_cat R
# is_cat n
# is_cat g
# is_cat g
# is_cat p
# is_cat s
# is_cat S
# is_cat R
# is_cat p
# is_cat E
# is_cat S
# is_cat s
# is_cat e
# is_cat s
# is_cat s
# is_cat R
# is_cat b
# is_cat a
# is_cat y
# is_cat R
# is_cat p
# is_cat B
# is_cat s
# is_cat m
# is_cat g
# is_cat w
# is_cat c
# is_cat k
# is_cat A
# is_cat e
# is_cat p
# is_cat p
# is_cat e
# is_cat M
# is_cat e
# is_cat S
# is_cat h
# is_cat R
# is_cat g
# is_cat B
# is_cat s
# is_cat S
# is_cat B
# is_cat b
# is_cat a
# is_cat B
# is_cat s
# is_cat A
# is_cat e
# is_cat c
# is_cat S
# is_cat a
# is_cat s
# is_cat h
# is_cat b
# is_cat m
# is_cat w
# is_cat y
# is_cat e
# is_cat R
# is_cat n
# is_cat E
# is_cat s
# is_cat k
# is_cat g
# is_cat c
# is_cat g
# is_cat S
# is_cat s
# is_cat y
# is_cat S
# is_cat R
# is_cat a
# is_cat s
# is_cat B
# is_cat w
# is_cat e
# is_cat p
# is_cat e
# is_cat a
# is_cat m
# is_cat l
# is_cat g
# is_cat l
# is_cat s
# is_cat l
# is_cat A
# is_cat S
# is_cat w
# is_cat R
# is_cat S
# is_cat e
# is_cat B
# is_cat s
# is_cat A
# is_cat y
# is_cat y
# is_cat R
# is_cat c
# is_cat B
# is_cat p
# is_cat l
# is_cat s
# is_cat h
# is_cat w
# is_cat y
# is_cat c
# is_cat s
# is_cat g
# is_cat s
# is_cat c
# is_cat e
# is_cat a
# is_cat S
# is_cat m
# is_cat b
# is_cat s
# is_cat c
# is_cat p
# is_cat w
# is_cat S
# is_cat g
# is_cat P
# is_cat a
# is_cat b
# is_cat w
# is_cat c
# is_cat b
# is_cat j
# is_cat A
# is_cat g
# is_cat e
# is_cat b
# is_cat S
# is_cat n
# is_cat h
# is_cat l
# is_cat s
# is_cat n
# is_cat b
# is_cat b
# is_cat s
# is_cat p
# is_cat l
# is_cat l
# is_cat h
# is_cat S
# is_cat h
# is_cat A
# is_cat p
# is_cat B
# is_cat a
# is_cat w
# is_cat R
# is_cat s
# is_cat b
# is_cat s
# is_cat w
# is_cat s
# is_cat k
# is_cat b
# is_cat s
# is_cat a
# is_cat j
# is_cat k
# is_cat y
# is_cat w
# is_cat j
# is_cat j
# is_cat b
# is_cat s
# is_cat b
# is_cat b
# is_cat e
# is_cat S
# is_cat n
# is_cat c
# is_cat h
# is_cat R
# is_cat c
# is_cat b
# is_cat b
# is_cat e
# is_cat h
# is_cat B
# is_cat b
# is_cat s
# is_cat S
# is_cat s
# is_cat M
# is_cat c
# is_cat n
# is_cat a
# is_cat b
# is_cat p
# is_cat b
# is_cat m
# is_cat M
# is_cat b
# is_cat y
# is_cat p
# is_cat P
# is_cat s
# is_cat s
# is_cat B
# is_cat g
# is_cat R
# is_cat p
# is_cat l
# is_cat E
# is_cat R
# is_cat s
# is_cat M
# is_cat b
# is_cat e
# is_cat n
# is_cat B
# is_cat b
# is_cat B
# is_cat M
# is_cat p
# is_cat a
# is_cat l
# is_cat S
# is_cat P
# is_cat s
# is_cat s
# is_cat B
# is_cat s
# is_cat a
# is_cat a
# is_cat m
# is_cat B
# is_cat l
# is_cat g
# is_cat B
# is_cat b
# is_cat c
# is_cat p
# is_cat e
# is_cat s
# is_cat l
# is_cat s
# is_cat e
# is_cat S
# is_cat A
# is_cat B
# is_cat s
# is_cat p
# is_cat E
# is_cat R
# is_cat g
# is_cat R
# is_cat R
# is_cat b
# is_cat w
# is_cat S
# is_cat P
# is_cat S
# is_cat l
# is_cat w
# is_cat p
# is_cat s
# is_cat S
# is_cat s
# is_cat E
# is_cat S
# is_cat R
# is_cat c
# is_cat R
# is_cat w
# is_cat P
# is_cat w
# is_cat R
# is_cat g
# is_cat w
# is_cat s
# is_cat b
# is_cat b
# is_cat a
# is_cat s
# is_cat a
# is_cat e
# is_cat S
# is_cat b
# is_cat h
# is_cat n
# is_cat a
# is_cat A
# is_cat m
# is_cat A
# is_cat b
# is_cat s
# is_cat m
# is_cat a
# is_cat B
# is_cat b
# is_cat n
# is_cat g
# is_cat R
# is_cat c
# is_cat B
# is_cat k
# is_cat S
# is_cat y
# is_cat b
# is_cat R
# is_cat P
# is_cat s
# is_cat y
# is_cat A
# is_cat a
# is_cat w
# is_cat s
# is_cat P
# is_cat M
# is_cat p
# is_cat c
# is_cat n
# is_cat e
# is_cat b
# is_cat s
# is_cat m
# is_cat s
# is_cat a
# is_cat s
# is_cat a
# is_cat B
# is_cat p
# is_cat w
# is_cat A
# is_cat c
# is_cat p
# is_cat B
# is_cat a
# is_cat g
# is_cat l
# is_cat a
# is_cat l
# is_cat e
# is_cat R
# is_cat B
# is_cat S
# is_cat l
# is_cat s
# is_cat n
# is_cat a
# is_cat w
# is_cat B
# is_cat p
# is_cat y
# is_cat s
# is_cat y
# is_cat S
# is_cat b
# is_cat S
# is_cat c
# is_cat E
# is_cat g
# is_cat b
# is_cat S
# is_cat B
# is_cat B
# is_cat h
# is_cat A
# is_cat n
# is_cat j
# is_cat A
# is_cat B
# is_cat R
# is_cat R
# is_cat M
# is_cat s
# is_cat E
# is_cat n
# is_cat E
# is_cat b
# is_cat b
# is_cat b
# is_cat c
# is_cat B
# is_cat l
# is_cat a
# is_cat p
# is_cat R
# is_cat s
# is_cat g
# is_cat M
# is_cat j
# is_cat n
# is_cat M
# is_cat k
# is_cat w
# is_cat R
# is_cat s
# is_cat j
# is_cat g
# is_cat s
# is_cat M
# is_cat e
# is_cat E
# is_cat y
# is_cat s
# is_cat n
# is_cat B
# is_cat E
# is_cat s
# is_cat e
# is_cat R
# is_cat y
# is_cat b
# is_cat a
# is_cat s
# is_cat y
# is_cat E
# is_cat B
# is_cat P
# is_cat s
# is_cat s
# is_cat S
# is_cat b
# is_cat s
# is_cat b
# is_cat B
# is_cat B
# is_cat n
# is_cat B
# is_cat j
# is_cat b
# is_cat B
# is_cat j
# is_cat p
# is_cat S
# is_cat b
# is_cat y
# is_cat s
# is_cat s
# is_cat S
# is_cat b
# is_cat s
# is_cat B
# is_cat B
# is_cat e
# is_cat p
# is_cat g
# is_cat p
# is_cat w
# is_cat E
# is_cat B
# is_cat S
# is_cat p
# is_cat s
# is_cat B
# is_cat m
# is_cat a
# is_cat B
# is_cat p
# is_cat s
# is_cat B
# is_cat e
# is_cat k
# is_cat g
# is_cat w
# is_cat b
# is_cat s
# is_cat R
# is_cat k
# is_cat l
# is_cat c
# is_cat m
# is_cat s
# is_cat B
# is_cat s
# is_cat b
# is_cat B
# is_cat h
# is_cat g
# is_cat s
# is_cat w
# is_cat s
# is_cat h
# is_cat a
# is_cat B
# is_cat s
# is_cat M
# is_cat a
# is_cat c
# is_cat B
# is_cat w
# is_cat h
# is_cat l
# is_cat b
# is_cat s
# is_cat R
# is_cat M
# is_cat e
# is_cat b
# is_cat s
# is_cat m
# is_cat a
# is_cat R
# is_cat e
# is_cat s
# is_cat S
# is_cat R
# is_cat k
# is_cat B
# is_cat B
# is_cat k
# is_cat b
# is_cat B
# is_cat h
# is_cat S
# is_cat s
# is_cat s
# is_cat s
# is_cat m
# is_cat s
# is_cat c
# is_cat w
# is_cat b
# is_cat b
# is_cat B
# is_cat y
# is_cat B
# is_cat B
# is_cat b
# is_cat p
# is_cat l
# is_cat B
# is_cat B
# is_cat g
# is_cat h
# is_cat B
# is_cat m
# is_cat b
# is_cat R
# is_cat m
# is_cat S
# is_cat S
# is_cat s
# is_cat w
# is_cat s
# is_cat S
# is_cat n
# is_cat s
# is_cat M
# is_cat g
# is_cat E
# is_cat B
# is_cat R
# is_cat B
# is_cat e
# is_cat y
# is_cat j
# is_cat p
# is_cat B
# is_cat P
# is_cat l
# is_cat p
# is_cat B
# is_cat s
# is_cat a
# is_cat B
# is_cat A
# is_cat p
# is_cat c
# is_cat s
# is_cat s
# is_cat e
# is_cat g
# is_cat m
# is_cat g
# is_cat a
# is_cat k
# is_cat b
# is_cat b
# is_cat n
# is_cat g
# is_cat s
# is_cat b
# is_cat B
# is_cat n
# is_cat B
# is_cat e
# is_cat h
# is_cat c
# is_cat M
# is_cat s
# is_cat e
# is_cat b
# is_cat A
# is_cat s
# is_cat y
# is_cat j
# is_cat y
# is_cat s
# is_cat M
# is_cat R
# is_cat e
# is_cat E
# is_cat c
# is_cat n
# is_cat R
# is_cat y
# is_cat b
# is_cat b
# is_cat s
# is_cat g
# is_cat b
# is_cat M
# is_cat h
# is_cat n
# is_cat R
# is_cat B
# is_cat B
# is_cat g
# is_cat a
# is_cat s
# is_cat e
# is_cat B
# is_cat b
# is_cat g
# is_cat B
# is_cat a
# is_cat a
# is_cat e
# is_cat M
# is_cat b
# is_cat B
# is_cat E
# is_cat b
# is_cat b
# is_cat j
# is_cat b
# is_cat b
# is_cat s
# is_cat c
# is_cat y
# is_cat A
# is_cat B
# is_cat B
# is_cat s
# is_cat j
# is_cat p
# is_cat b
# is_cat c
# is_cat g
# is_cat s
# is_cat b
# is_cat R
# is_cat j
# is_cat s
# is_cat j
# is_cat s
# is_cat b
# is_cat n
# is_cat a
# is_cat e
# is_cat g
# is_cat B
# is_cat M
# is_cat b
# is_cat g
# is_cat b
# is_cat p
# is_cat p
# is_cat B
# is_cat g
# is_cat M
# is_cat g
# is_cat s
# is_cat R
# is_cat b
# is_cat s
# is_cat s
# is_cat g
# is_cat P
# is_cat B
# is_cat g
# is_cat E
# is_cat g
# is_cat c
# is_cat E
# is_cat g
# is_cat R
# is_cat b
# is_cat E
# is_cat n
# is_cat h
# is_cat M
# is_cat s
# is_cat B
# is_cat B
# is_cat B
# is_cat n
# is_cat c
# is_cat l
# is_cat g
# is_cat e
# is_cat S
# is_cat b
# is_cat E
# is_cat l
# is_cat s
# is_cat a
# is_cat b
# is_cat S
# is_cat b
# is_cat c
# is_cat k
# is_cat A
# is_cat s
# is_cat h
# is_cat B
# is_cat y
# is_cat a
# is_cat M
# is_cat m
# is_cat k
# is_cat h
# is_cat s
# is_cat j
# is_cat B
# is_cat B
# is_cat S
# is_cat a
# is_cat g
# is_cat B
# is_cat g
# is_cat a
# is_cat B
# is_cat e
# is_cat c
# is_cat P
# is_cat S
# is_cat e
# is_cat n
# is_cat e
# is_cat s
# is_cat k
# is_cat c
# is_cat s
# is_cat c
# is_cat R
# is_cat g
# is_cat e
# is_cat m
# is_cat B
# is_cat h
# is_cat w
# is_cat R
# is_cat p
# is_cat A
# is_cat w
# is_cat s
# is_cat a
# is_cat B
# is_cat A
# is_cat g
# is_cat b
# is_cat p
# is_cat B
# is_cat s
# is_cat n
# is_cat g
# is_cat b
# is_cat s
# is_cat m
# is_cat A
# is_cat E
# is_cat e
# is_cat B
# is_cat s
# is_cat B
# is_cat s
# is_cat h
# is_cat M
# is_cat A
# is_cat g
# is_cat h
# is_cat p
# is_cat l
# is_cat b
# is_cat w
# is_cat h
# is_cat M
# is_cat l
# is_cat b
# is_cat g
# is_cat s
# is_cat B
# is_cat g
# is_cat A
# is_cat A
# is_cat h
# is_cat p
# is_cat B
# is_cat R
# is_cat p
# is_cat b
# is_cat g
# is_cat S
# is_cat k
# is_cat A
# is_cat M
# is_cat s
# is_cat a
# is_cat R
# is_cat s
# is_cat n
# is_cat s
# is_cat b
# is_cat w
# is_cat m
# is_cat b
# is_cat c
# is_cat h
# is_cat m
# is_cat m
# is_cat b
# is_cat s
# is_cat b
# is_cat n
# is_cat R
# is_cat M
# is_cat A
# is_cat S
# is_cat s
# is_cat b
# is_cat E
# is_cat a
# is_cat B
# is_cat s
# is_cat B
# is_cat M
# is_cat m
# is_cat S
# is_cat a
# is_cat A
# is_cat p
# is_cat b
# is_cat B
# is_cat l
# is_cat R
# is_cat R
# is_cat n
# is_cat e
# is_cat c
# is_cat g
# is_cat g
# is_cat p
# is_cat S
# is_cat s
# is_cat n
# is_cat n
# is_cat c
# is_cat g
# is_cat s
# is_cat a
# is_cat B
# is_cat B
# is_cat h
# is_cat R
# is_cat w
# is_cat m
# is_cat R
# is_cat c
# is_cat s
# is_cat s
# is_cat B
# is_cat k
# is_cat A
# is_cat e
# is_cat s
# is_cat m
# is_cat p
# is_cat b
# is_cat P
# is_cat p
# is_cat s
# is_cat a
# is_cat n
# is_cat B
# is_cat e
# is_cat P
# is_cat g
# is_cat S
# is_cat l
# is_cat n
# is_cat b
# is_cat j
# is_cat j
# is_cat e
# is_cat s
# is_cat R
# is_cat c
# is_cat B
# is_cat a
# is_cat j
# is_cat g
# is_cat a
# is_cat g
# is_cat p
# is_cat S
# is_cat P
# is_cat p
# is_cat s
# is_cat a
# is_cat b
# is_cat c
# is_cat B
# is_cat b
# is_cat s
# is_cat b
# is_cat P
# is_cat s
# is_cat m
# is_cat m
# is_cat s
# is_cat P
# is_cat e
# is_cat m
# is_cat a
# is_cat P
# is_cat s
# is_cat M
# is_cat B
# is_cat g
# is_cat p
# is_cat B
# is_cat s
# is_cat e
# is_cat h
# is_cat B
# is_cat P
# is_cat A
# is_cat b
# is_cat a
# is_cat e
# is_cat g
# is_cat s
# is_cat s
# is_cat g
# is_cat P
# is_cat w
# is_cat b
# is_cat S
# is_cat B
# is_cat n
# is_cat R
# is_cat b
# is_cat s
# is_cat s
# is_cat s
# is_cat S
# is_cat B
# is_cat B
# is_cat B
# is_cat k
# is_cat a
# is_cat b
# is_cat A
# is_cat y
# is_cat b
# is_cat B
# is_cat s
# is_cat a
# is_cat s
# is_cat l
# is_cat M
# is_cat b
# is_cat E
# is_cat a
# is_cat j
# is_cat y
# is_cat B
# is_cat w
# is_cat B
# is_cat y
# is_cat k
# is_cat B
# is_cat B
# is_cat b
# is_cat B
# is_cat E
# is_cat B
# is_cat h
# is_cat M
# is_cat R
# is_cat b
# is_cat A
# is_cat s
# is_cat R
# is_cat R
# is_cat c
# is_cat e
# is_cat e
# is_cat m
# is_cat M
# is_cat a
# is_cat s
# is_cat P
# is_cat b
# is_cat s
# is_cat s
# is_cat s
# is_cat y
# is_cat E
# is_cat w
# is_cat p
# is_cat M
# is_cat p
# is_cat y
# is_cat s
# is_cat B
# is_cat M
# is_cat s
# is_cat B
# is_cat R
# is_cat M
# is_cat R
# is_cat b
# is_cat g
# is_cat B
# is_cat S
# is_cat g
# is_cat B
# is_cat w
# is_cat A
# is_cat l
# is_cat M
# is_cat S
# is_cat l
# is_cat P
# is_cat E
# is_cat e
# is_cat B
# is_cat h
# is_cat y
# is_cat p
# is_cat A
# is_cat B
# is_cat s
# is_cat P
# is_cat S
# is_cat n
# is_cat R
# is_cat p
# is_cat R
# is_cat j
# is_cat g
# is_cat R
# is_cat e
# is_cat g
# is_cat m
# is_cat e
# is_cat B
# is_cat B
# is_cat B
# is_cat m
# is_cat h
# is_cat n
# is_cat y
# is_cat p
# is_cat E
# is_cat g
# is_cat j
# is_cat S
# is_cat M
# is_cat n
# is_cat P
# is_cat h
# is_cat a
# is_cat y
# is_cat e
# is_cat e
# is_cat S
# is_cat p
# is_cat e
# is_cat B
# is_cat m
# is_cat e
# is_cat e
# is_cat B
# is_cat B
# is_cat c
# is_cat m
# is_cat h
# is_cat B
# is_cat b
# is_cat s
# is_cat B
# is_cat s
# is_cat p
# is_cat p
# is_cat S
# is_cat b
# is_cat b
# is_cat a
# is_cat B
# is_cat R
# is_cat n
# is_cat a
# is_cat l
# is_cat g
# is_cat b
# is_cat e
# is_cat s
# is_cat e
# is_cat s
# is_cat A
# is_cat P
# is_cat b
# is_cat j
# is_cat s
# is_cat S
# is_cat e
# is_cat A
# is_cat E
# is_cat g
# is_cat a
# is_cat B
# is_cat P
# is_cat s
# is_cat a
# is_cat s
# is_cat b
# is_cat h
# is_cat g
# is_cat g
# is_cat a
# is_cat M
# is_cat S
# is_cat s
# is_cat s
# is_cat e
# is_cat p
# is_cat p
# is_cat B
# is_cat s
# is_cat e
# is_cat n
# is_cat B
# is_cat P
# is_cat b
# is_cat a
# is_cat e
# is_cat a
# is_cat s
# is_cat b
# is_cat s
# is_cat m
# is_cat h
# is_cat b
# is_cat s
# is_cat B
# is_cat p
# is_cat j
# is_cat m
# is_cat A
# is_cat a
# is_cat p
# is_cat s
# is_cat M
# is_cat S
# is_cat A
# is_cat k
# is_cat R
# is_cat a
# is_cat b
# is_cat a
# is_cat R
# is_cat b
# is_cat g
# is_cat e
# is_cat s
# is_cat k
# is_cat g
# is_cat R
# is_cat e
# is_cat a
# is_cat n
# is_cat a
# is_cat A
# is_cat s
# is_cat p
# is_cat a
# is_cat P
# is_cat R
# is_cat B
# is_cat S
# is_cat b
# is_cat y
# is_cat a
# is_cat a
# is_cat h
# is_cat B
# is_cat B
# is_cat s
# is_cat b
# is_cat A
# is_cat g
# is_cat S
# is_cat c
# is_cat g
# is_cat b
# is_cat a
# is_cat s
# is_cat M
# is_cat s
# is_cat w
# is_cat B
# is_cat g
# is_cat s
# is_cat p
# is_cat c
# is_cat b
# is_cat g
# is_cat b
# is_cat w
# is_cat a
# is_cat B
# is_cat B
# is_cat B
# is_cat s
# is_cat g
# is_cat s
# is_cat y
# is_cat p
# is_cat B
# is_cat k
# is_cat b
# is_cat b
# is_cat p
# is_cat s
# is_cat g
# is_cat a
# is_cat B
# is_cat p
# is_cat B
# is_cat B
# is_cat g
# is_cat M
# is_cat E
# is_cat y
# is_cat s
# is_cat h
# is_cat b
# is_cat s
# is_cat b
# is_cat e
# is_cat m
# is_cat n
# is_cat b
# is_cat j
# is_cat b
# is_cat m
# is_cat p
# is_cat b
# is_cat P
# is_cat a
# is_cat j
# is_cat k
# is_cat l
# is_cat B
# is_cat c
# is_cat p
# is_cat w
# is_cat s
# is_cat p
# is_cat g
# is_cat b
# is_cat y
# is_cat j
# is_cat P
# is_cat l
# is_cat B
# is_cat s
# is_cat h
# is_cat B
# is_cat h
# is_cat b
# is_cat w
# is_cat S
# is_cat y
# is_cat j
# is_cat M
# is_cat P
# is_cat B
# is_cat a
# is_cat n
# is_cat e
# is_cat g
# is_cat S
# is_cat h
# is_cat e
# is_cat h
# is_cat p
# is_cat s
# is_cat a
# is_cat s
# is_cat S
# is_cat s
# is_cat s
# is_cat s
# is_cat c
# is_cat B
# is_cat w
# is_cat l
# is_cat s
# is_cat b
# is_cat E
# is_cat s
# is_cat s
# is_cat g
# is_cat a
# is_cat E
# is_cat R
# is_cat B
# is_cat A
# is_cat P
# is_cat y
# is_cat s
# is_cat B
# is_cat a
# is_cat c
# is_cat b
# is_cat l
# is_cat y
# is_cat p
# is_cat S
# is_cat y
# is_cat g
# is_cat g
# is_cat B
# is_cat B
# is_cat E
# is_cat g
# is_cat b
# is_cat w
# is_cat b
# is_cat s
# is_cat s
# is_cat s
# is_cat a
# is_cat k
# is_cat R
# is_cat s
# is_cat B
# is_cat S
# is_cat y
# is_cat y
# is_cat s
# is_cat m
# is_cat P
# is_cat c
# is_cat e
# is_cat A
# is_cat g
# is_cat P
# is_cat j
# is_cat a
# is_cat g
# is_cat S
# is_cat P
# is_cat m
# is_cat c
# is_cat h
# is_cat h
# is_cat p
# is_cat h
# is_cat a
# is_cat s
# is_cat k
# is_cat s
# is_cat R
# is_cat s
# is_cat w
# is_cat a
# is_cat g
# is_cat A
# is_cat m
# is_cat l
# is_cat c
# is_cat B
# is_cat b
# is_cat B
# is_cat h
# is_cat l
# is_cat s
# is_cat e
# is_cat y
# is_cat R
# is_cat s
# is_cat b
# is_cat j
# is_cat m
# is_cat j
# is_cat b
# is_cat B
# is_cat s
# is_cat n
# is_cat M
# is_cat n
# is_cat e
# is_cat s
# is_cat B
# is_cat g
# is_cat B
# is_cat e
# is_cat b
# is_cat g
# is_cat p
# is_cat p
# is_cat b
# is_cat R
# is_cat S
# is_cat a
# is_cat y
# is_cat s
# is_cat b
# is_cat s
# is_cat E
# is_cat B
# is_cat k
# is_cat a
# is_cat S
# is_cat P
# is_cat y
# is_cat e
# is_cat s
# is_cat h
# is_cat b
# is_cat h
# is_cat e
# is_cat A
# is_cat k
# is_cat s
# is_cat h
# is_cat j
# is_cat A
# is_cat g
# is_cat k
# is_cat l
# is_cat m
# is_cat p
# is_cat l
# is_cat p
# is_cat j
# is_cat e
# is_cat R
# is_cat y
# is_cat g
# is_cat M
# is_cat S
# is_cat n
# is_cat B
# is_cat l
# is_cat y
# is_cat g
# is_cat k
# is_cat M
# is_cat e
# is_cat b
# is_cat e
# is_cat n
# is_cat b
# is_cat E
# is_cat b
# is_cat R
# is_cat m
# is_cat j
# is_cat E
# is_cat s
# is_cat g
# is_cat M
# is_cat s
# is_cat h
# is_cat g
# is_cat S
# is_cat l
# is_cat p
# is_cat b
# is_cat S
# is_cat s
# is_cat R
# is_cat B
# is_cat R
# is_cat c
# is_cat s
# is_cat S
# is_cat e
# is_cat b
# is_cat B
# is_cat g
# is_cat M
# is_cat s
# is_cat g
# is_cat m
# is_cat s
# is_cat a
# is_cat s
# is_cat a
# is_cat g
# is_cat E
# is_cat a
# is_cat h
# is_cat B
# is_cat B
# is_cat m
# is_cat g
# is_cat s
# is_cat B
# is_cat m
# is_cat s
# is_cat g
# is_cat e
# is_cat g
# is_cat j
# is_cat E
# is_cat m
# is_cat n
# is_cat e
# is_cat s
# is_cat k
# is_cat g
# is_cat a
# is_cat S
# is_cat y
# is_cat M
# is_cat l
# is_cat S
# is_cat m
# is_cat j
# is_cat M
# is_cat j
# is_cat c
# is_cat M
# is_cat l
# is_cat n
# is_cat s
# is_cat S
# is_cat s
# is_cat e
# is_cat h
# is_cat g
# is_cat e
# is_cat S
# is_cat a
# is_cat c
# is_cat B
# is_cat e
# is_cat a
# is_cat h
# is_cat B
# is_cat B
# is_cat a
# is_cat B
# is_cat a
# is_cat l
# is_cat B
# is_cat e
# is_cat E
# is_cat e
# is_cat l
# is_cat B
# is_cat a
# is_cat s
# is_cat B
# is_cat b
# is_cat h
# is_cat A
# is_cat a
# is_cat m
# is_cat a
# is_cat g
# is_cat E
# is_cat j
# is_cat e
# is_cat g
# is_cat B
# is_cat M
# is_cat m
# is_cat s
# is_cat a
# is_cat m
# is_cat a
# is_cat b
# is_cat n
# is_cat m
# is_cat n
# is_cat P
# is_cat e
# is_cat w
# is_cat k
# is_cat B
# is_cat S
# is_cat e
# is_cat g
# is_cat B
# is_cat h
# is_cat B
# is_cat a
# is_cat e
# is_cat b
# is_cat k
# is_cat l
# is_cat p
# is_cat B
# is_cat A
# is_cat s
# is_cat a
# is_cat s
# is_cat a
# is_cat y
# is_cat b
# is_cat s
# is_cat p
# is_cat g
# is_cat s
# is_cat B
# is_cat a
# is_cat a
# is_cat S
# is_cat s
# is_cat k
# is_cat k
# is_cat s
# is_cat b
# is_cat y
# is_cat s
# is_cat p
# is_cat S
# is_cat k
# is_cat B
# is_cat y
# is_cat B
# is_cat s
# is_cat p
# is_cat M
# is_cat R
# is_cat p
# is_cat b
# is_cat e
# is_cat s
# is_cat B
# is_cat B
# is_cat m
# is_cat l
# is_cat s
# is_cat h
# is_cat s
# is_cat e
# is_cat y
# is_cat g
# is_cat j
# is_cat A
# is_cat p
# is_cat k
# is_cat A
# is_cat a
# is_cat R
# is_cat l
# is_cat B
# is_cat R
# is_cat S
# is_cat R
# is_cat g
# is_cat e
# is_cat h
# is_cat A
# is_cat s
# is_cat S
# is_cat A
# is_cat p
# is_cat s
# is_cat e
# is_cat p
# is_cat R
# is_cat b
# is_cat S
# is_cat b
# is_cat g
# is_cat s
# is_cat y
# is_cat e
# is_cat B
# is_cat R
# is_cat R
# is_cat R
# is_cat l
# is_cat B
# is_cat c
# is_cat s
# is_cat S
# is_cat p
# is_cat P
# is_cat R
# is_cat E
# is_cat B
# is_cat s
# is_cat M
# is_cat S
# is_cat p
# is_cat s
# is_cat p
# is_cat a
# is_cat S
# is_cat y
# is_cat h
# is_cat w
# is_cat w
# is_cat b
# is_cat b
# is_cat s
# is_cat S
# is_cat a
# is_cat s
# is_cat S
# is_cat P
# is_cat m
# is_cat S
# is_cat w
# is_cat A
# is_cat E
# is_cat m
# is_cat s
# is_cat b
# is_cat j
# is_cat s
# is_cat e
# is_cat B
# is_cat j
# is_cat s
# is_cat a
# is_cat c
# is_cat S
# is_cat b
# is_cat s
# is_cat p
# is_cat k
# is_cat g
# is_cat l
# is_cat s
# is_cat b
# is_cat s
# is_cat b
# is_cat j
# is_cat R
# is_cat b
# is_cat a
# is_cat B
# is_cat S
# is_cat B
# is_cat S
# is_cat A
# is_cat m
# is_cat h
# is_cat g
# is_cat n
# is_cat h
# is_cat B
# is_cat R
# is_cat e
# is_cat A
# is_cat p
# is_cat B
# is_cat p
# is_cat s
# is_cat S
# is_cat s
# is_cat y
# is_cat S
# is_cat b
# is_cat S
# is_cat j
# is_cat A
# is_cat l
# is_cat R
# is_cat l
# is_cat j
# is_cat m
# is_cat R
# is_cat e
# is_cat s
# is_cat p
# is_cat g
# is_cat b
# is_cat B
# is_cat B
# is_cat b
# is_cat y
# is_cat B
# is_cat B
# is_cat w
# is_cat A
# is_cat e
# is_cat S
# is_cat w
# is_cat a
# is_cat M
# is_cat e
# is_cat a
# is_cat n
# is_cat h
# is_cat s
# is_cat B
# is_cat M
# is_cat B
# is_cat e
# is_cat c
# is_cat e
# is_cat R
# is_cat B
# is_cat k
# is_cat B
# is_cat a
# is_cat A
# is_cat n
# is_cat S
# is_cat M
# is_cat a
# is_cat g
# is_cat p
# is_cat g
# is_cat P
# is_cat e
# is_cat s
# is_cat B
# is_cat s
# is_cat b
# is_cat y
# is_cat b
# is_cat p
# is_cat l
# is_cat k
# is_cat E
# is_cat h
# is_cat j
# is_cat w
# is_cat a
# is_cat g
# is_cat b
# is_cat E
# is_cat B
# is_cat B
# is_cat p
# is_cat w
# is_cat g
# is_cat j
# is_cat k
# is_cat e
# is_cat c
# is_cat s
# is_cat e
# is_cat e
# is_cat l
# is_cat B
# is_cat w
# is_cat y
# is_cat g
# is_cat B
# is_cat R
# is_cat g
# is_cat R
# is_cat B
# is_cat S
# is_cat S
# is_cat h
# is_cat R
# is_cat s
# is_cat a
# is_cat j
# is_cat E
# is_cat b
# is_cat b
# is_cat s
# is_cat l
# is_cat S
# is_cat a
# is_cat p
# is_cat B
# is_cat h
# is_cat s
# is_cat A
# is_cat k
# is_cat p
# is_cat w
# is_cat w
# is_cat s
# is_cat A
# is_cat p
# is_cat n
# is_cat h
# is_cat e
# is_cat P
# is_cat E
# is_cat a
# is_cat s
# is_cat e
# is_cat s
# is_cat s
# is_cat g
# is_cat l
# is_cat e
# is_cat E
# is_cat m
# is_cat M
# is_cat g
# is_cat a
# is_cat p
# is_cat A
# is_cat b
# is_cat B
# is_cat P
# is_cat B
# is_cat B
# is_cat R
# is_cat B
# is_cat s
# is_cat B
# is_cat B
# is_cat h
# is_cat R
# is_cat R
# is_cat y
# is_cat S
# is_cat b
# is_cat A
# is_cat s
# is_cat R
# is_cat M
# is_cat M
# is_cat a
# is_cat b
# is_cat s
# is_cat s
# is_cat s
# is_cat P
# is_cat R
# is_cat R
# is_cat e
# is_cat n
# is_cat R
# is_cat R
# is_cat w
# is_cat R
# is_cat l
# is_cat S
# is_cat k
# is_cat n
# is_cat h
# is_cat B
# is_cat s
# is_cat E
# is_cat s
# is_cat g
# is_cat R
# is_cat E
# is_cat s
# is_cat h
# is_cat k
# is_cat E
# is_cat s
# is_cat S
# is_cat b
# is_cat g
# is_cat g
# is_cat R
# is_cat E
# is_cat e
# is_cat s
# is_cat S
# is_cat c
# is_cat g
# is_cat l
# is_cat R
# is_cat c
# is_cat g
# is_cat h
# is_cat P
# is_cat s
# is_cat s
# is_cat k
# is_cat s
# is_cat s
# is_cat S
# is_cat s
# is_cat B
# is_cat E
# is_cat w
# is_cat s
# is_cat l
# is_cat y
# is_cat P
# is_cat S
# is_cat B
# is_cat p
# is_cat c
# is_cat s
# is_cat s
# is_cat p
# is_cat n
# is_cat b
# is_cat y
# is_cat e
# is_cat h
# is_cat a
# is_cat j
# is_cat P
# is_cat l
# is_cat g
# is_cat B
# is_cat M
# is_cat b
# is_cat a
# is_cat b
# is_cat E
# is_cat s
# is_cat M
# is_cat p
# is_cat h
# is_cat E
# is_cat A
# is_cat b
# is_cat y
# is_cat S
# is_cat R
# is_cat w
# is_cat s
# is_cat A
# is_cat E
# is_cat g
# is_cat P
# is_cat b
# is_cat S
# is_cat B
# is_cat a
# is_cat j
# is_cat B
# is_cat b
# is_cat b
# is_cat l
# is_cat l
# is_cat s
# is_cat n
# is_cat p
# is_cat B
# is_cat E
# is_cat E
# is_cat E
# is_cat S
# is_cat R
# is_cat b
# is_cat l
# is_cat R
# is_cat S
# is_cat p
# is_cat s
# is_cat B
# is_cat w
# is_cat j
# is_cat s
# is_cat w
# is_cat B
# is_cat n
# is_cat E
# is_cat s
# is_cat A
# is_cat w
# is_cat n
# is_cat S
# is_cat s
# is_cat y
# is_cat E
# is_cat B
# is_cat e
# is_cat s
# is_cat P
# is_cat b
# is_cat g
# is_cat j
# is_cat b
# is_cat s
# is_cat a
# is_cat k
# is_cat k
# is_cat c
# is_cat a
# is_cat S
# is_cat s
# is_cat s
# is_cat y
# is_cat e
# is_cat s
# is_cat R
# is_cat A
# is_cat P
# is_cat M
# is_cat h
# is_cat j
# is_cat k
# is_cat B
# is_cat p
# is_cat n
# is_cat a
# is_cat s
# is_cat b
# is_cat R
# is_cat A
# is_cat B
# is_cat e
# is_cat E
# is_cat b
# is_cat B
# is_cat s
# is_cat M
# is_cat a
# is_cat s
# is_cat a
# is_cat B
# is_cat s
# is_cat R
# is_cat y
# is_cat c
# is_cat B
# is_cat s
# is_cat h
# is_cat s
# is_cat y
# is_cat s
# is_cat M
# is_cat P
# is_cat R
# is_cat R
# is_cat E
# is_cat M
# is_cat g
# is_cat e
# is_cat s
# is_cat n
# is_cat S
# is_cat B
# is_cat E
# is_cat h
# is_cat j
# is_cat p
# is_cat s
# is_cat a
# is_cat B
# is_cat s
# is_cat b
# is_cat g
# is_cat M
# is_cat c
# is_cat A
# is_cat e
# is_cat S
# is_cat P
# is_cat S
# is_cat n
# is_cat B
# is_cat S
# is_cat S
# is_cat p
# is_cat R
# is_cat e
# is_cat M
# is_cat E
# is_cat P
# is_cat s
# is_cat M
# is_cat E
# is_cat p
# is_cat p
# is_cat e
# is_cat e
# is_cat s
# is_cat s
# is_cat s
# is_cat P
# is_cat s
# is_cat s
# is_cat e
# is_cat g
# is_cat g
# is_cat B
# is_cat n
# is_cat h
# is_cat P
# is_cat p
# is_cat M
# is_cat s
# is_cat B
# is_cat h
# is_cat E
# is_cat b
# is_cat g
# is_cat c
# is_cat e
# is_cat s
# is_cat B
# is_cat k
# is_cat h
# is_cat B
# is_cat s
# is_cat a
# is_cat m
# is_cat s
# is_cat g
# is_cat p
# is_cat j
# is_cat h
# is_cat S
# is_cat y
# is_cat l
# is_cat b
# is_cat b
# is_cat s
# is_cat e
# is_cat s
# is_cat S
# is_cat p
# is_cat B
# is_cat b
# is_cat k
# is_cat h
# is_cat B
# is_cat P
# is_cat P
# is_cat E
# is_cat S
# is_cat s
# is_cat p
# is_cat S
# is_cat c
# is_cat a
# is_cat B
# is_cat g
# is_cat R
# is_cat P
# is_cat h
# is_cat g
# is_cat B
# is_cat s
# is_cat e
# is_cat E
# is_cat B
# is_cat e
# is_cat k
# is_cat R
# is_cat y
# is_cat s
# is_cat B
# is_cat B
# is_cat B
# is_cat c
# is_cat h
# is_cat S
# is_cat m
# is_cat k
# is_cat s
# is_cat M
# is_cat B
# is_cat n
# is_cat c
# is_cat l
# is_cat k
# is_cat a
# is_cat a
# is_cat k
# is_cat h
# is_cat s
# is_cat B
# is_cat A
# is_cat B
# is_cat s
# is_cat e
# is_cat b
# is_cat a
# is_cat B
# is_cat M
# is_cat p
# is_cat P
# is_cat j
# is_cat E
# is_cat S
# is_cat B
# is_cat s
# is_cat p
# is_cat b
# is_cat P
# is_cat m
# is_cat s
# is_cat p
# is_cat b
# is_cat s
# is_cat B
# is_cat k
# is_cat k
# is_cat S
# is_cat k
# is_cat c
# is_cat g
# is_cat g
# is_cat M
# is_cat l
# is_cat R
# is_cat y
# is_cat s
# is_cat a
# is_cat l
# is_cat s
# is_cat w
# is_cat j
# is_cat B
# is_cat s
# is_cat b
# is_cat k
# is_cat B
# is_cat j
# is_cat s
# is_cat h
# is_cat w
# is_cat S
# is_cat k
# is_cat k
# is_cat s
# is_cat w
# is_cat m
# is_cat n
# is_cat j
# is_cat s
# is_cat w
# is_cat k
# is_cat S
# is_cat m
# is_cat b
# is_cat k
# is_cat R
# is_cat g
# is_cat w
# is_cat R
# is_cat B
# is_cat p
# is_cat B
# is_cat g
# is_cat g
# is_cat B
# is_cat a
# is_cat E
# is_cat s
# is_cat B
# is_cat B
# is_cat B
# is_cat R
# is_cat A
# is_cat S
# is_cat a
# is_cat s
# is_cat p
# is_cat b
# is_cat w
# is_cat E
# is_cat c
# is_cat s
# is_cat n
# is_cat B
# is_cat E
# is_cat e
# is_cat l
# is_cat b
# is_cat B
# is_cat E
# is_cat B
# is_cat B
# is_cat s
# is_cat y
# is_cat p
# is_cat s
# is_cat R
# is_cat c
# is_cat M
# is_cat m
# is_cat s
# is_cat s
# is_cat b
# is_cat s
# is_cat l
# is_cat s
# is_cat g
# is_cat s
# is_cat e
# is_cat R
# is_cat k
# is_cat A
# is_cat s
# is_cat n
# is_cat n
# is_cat s
# is_cat c
# is_cat n
# is_cat g
# is_cat R
# is_cat B
# is_cat b
# is_cat j
# is_cat j
# is_cat b
# is_cat y
# is_cat B
# is_cat E
# is_cat M
# is_cat a
# is_cat g
# is_cat n
# is_cat b
# is_cat S
# is_cat n
# is_cat h
# is_cat B
# is_cat y
# is_cat p
# is_cat s
# is_cat g
# is_cat E
# is_cat s
# is_cat a
# is_cat B
# is_cat g
# is_cat s
# is_cat e
# is_cat S
# is_cat c
# is_cat B
# is_cat S
# is_cat R
# is_cat b
# is_cat s
# is_cat c
# is_cat g
# is_cat e
# is_cat a
# is_cat S
# is_cat B
# is_cat p
# is_cat p
# is_cat y
# is_cat P
# is_cat s
# is_cat a
# is_cat b
# is_cat R
# is_cat j
# is_cat a
# is_cat y
# is_cat c
# is_cat n
# is_cat c
# is_cat p
# is_cat S
# is_cat y
# is_cat g
# is_cat P
# is_cat s
# is_cat R
# is_cat B
# is_cat k
# is_cat a
# ...
# is_cat s
# is_cat b
# is_cat s
# is_cat s
# is_cat a
# is_cat k
# is_cat a
# is_cat a
# is_cat c
# is_cat s
# is_cat R
# is_cat S
# is_cat g
# is_cat b
# is_cat m
# is_cat S
# is_cat s
# is_cat b
# is_cat p
# is_cat S
# is_cat R
# is_cat A
# is_cat s
# is_cat k
# is_cat c
# is_cat S
# is_cat R
# is_cat m
# is_cat B
# is_cat R
# is_cat R
# is_cat M
# is_cat B
# is_cat P
# is_cat R
# is_cat S
# is_cat b
# is_cat l
# is_cat E
# is_cat g
# is_cat e
# is_cat h
# is_cat s
# is_cat b
# is_cat y
# is_cat m
# is_cat S
# is_cat p
# is_cat B
# is_cat b
# is_cat R
# is_cat g
# is_cat E
# is_cat b
# is_cat y
# is_cat e
# is_cat R
# is_cat l
# is_cat R
# is_cat n
# is_cat B
# is_cat c
# is_cat s
# is_cat B
# is_cat p
# is_cat s
# is_cat e
# is_cat S
# is_cat S
# is_cat S
# is_cat A
# is_cat b
# is_cat B
# is_cat h
# is_cat n
# is_cat s
# is_cat a
# is_cat A
# is_cat b
# is_cat A
# is_cat R
# is_cat B
# is_cat g
# is_cat p
# is_cat S
# is_cat y
# is_cat s
# is_cat A
# is_cat p
# is_cat e
# is_cat B
# is_cat B
# is_cat y
# is_cat h
# is_cat p
# is_cat p
# is_cat s
# is_cat c
# is_cat l
# is_cat l
# is_cat S
# is_cat s
# is_cat w
# is_cat M
# is_cat s
# is_cat B
# is_cat B
# is_cat y
# is_cat b
# is_cat B
# is_cat b
# is_cat j
# is_cat n
# is_cat a
# is_cat j
# is_cat B
# is_cat e
# is_cat l
# is_cat p
# is_cat s
# is_cat s
# is_cat b
# is_cat c
# is_cat B
# is_cat b
# is_cat w
# is_cat s
# is_cat y
# is_cat j
# is_cat g
# is_cat s
# is_cat c
# is_cat l
# is_cat j
# is_cat g
# is_cat n
# is_cat p
# is_cat B
# is_cat B
# is_cat s
# is_cat e
# is_cat s
# is_cat s
# is_cat s
# is_cat p
# is_cat a
# is_cat g
# is_cat p
# is_cat l
# is_cat l
# is_cat a
# is_cat e
# is_cat h
# is_cat p
# is_cat s
# is_cat p
# is_cat e
# is_cat c
# is_cat s
# is_cat R
# is_cat m
# is_cat b
# is_cat c
# is_cat a
# is_cat k
# is_cat l
# is_cat w
# is_cat s
# is_cat A
# is_cat p
# is_cat g
# is_cat s
# is_cat s
# is_cat m
# is_cat g
# is_cat P
# is_cat s
# is_cat b
# is_cat b
# is_cat p
# is_cat m
# is_cat a
# is_cat B
# is_cat b
# is_cat s
# is_cat P
# is_cat e
# is_cat B
# is_cat b
# is_cat p
# is_cat B
# is_cat b
# is_cat R
# is_cat b
# is_cat p
# is_cat s
# is_cat j
# is_cat P
# is_cat P
# is_cat s
# is_cat s
# is_cat s
# is_cat p
# is_cat B
# is_cat S
# is_cat a
# is_cat b
# is_cat h
# is_cat B
# is_cat s
# is_cat R
# is_cat s
# is_cat s
# is_cat B
# is_cat B
# is_cat e
# is_cat B
# is_cat s
# is_cat h
# is_cat b
# is_cat B
# is_cat B
# is_cat p
# is_cat s
# is_cat B
# is_cat j
# is_cat a
# is_cat n
# is_cat b
# is_cat h
# is_cat g
# is_cat B
# is_cat B
# is_cat M
# is_cat A
# is_cat R
# is_cat j
# is_cat g
# is_cat B
# is_cat s
# is_cat j
# is_cat g
# is_cat a
# is_cat a
# is_cat A
# is_cat l
# is_cat e
# is_cat c
# is_cat b
# is_cat A
# is_cat B
# is_cat A
# is_cat w
# is_cat h
# is_cat s
# is_cat B
# is_cat b
# is_cat s
# is_cat b
# is_cat s
# is_cat y
# is_cat B
# is_cat s
# is_cat s
# is_cat b
# is_cat S
# is_cat b
# is_cat e
# is_cat y
# is_cat h
# is_cat m
# is_cat j
# is_cat e
# is_cat l
# is_cat a
# is_cat s
# is_cat p
# is_cat b
# is_cat g
# is_cat e
# is_cat e
# is_cat R
# is_cat B
# is_cat P
# is_cat g
# is_cat b
# is_cat s
# is_cat n
# is_cat S
# is_cat j
# is_cat B
# is_cat A
# is_cat a
# is_cat a
# is_cat B
# is_cat n
# is_cat g
# is_cat j
# is_cat M
# is_cat w
# is_cat s
# is_cat p
# is_cat s
# is_cat S
# is_cat B
# is_cat P
# is_cat R
# is_cat n
# is_cat g
# is_cat B
# is_cat B
# is_cat a
# is_cat s
# is_cat p
# is_cat e
# is_cat R
# is_cat b
# is_cat s
# is_cat a
# is_cat s
# is_cat h
# is_cat m
# is_cat k
# is_cat g
# is_cat a
# is_cat b
# is_cat S
# is_cat h
# is_cat b
# is_cat S
# is_cat S
# is_cat g
# is_cat s
# is_cat m
# is_cat j
# is_cat R
# is_cat p
# is_cat j
# is_cat g
# is_cat S
# is_cat y
# is_cat w
# is_cat P
# is_cat w
# is_cat w
# is_cat E
# is_cat B
# is_cat y
# is_cat R
# is_cat g
# is_cat g
# is_cat a
# is_cat s
# is_cat s
# is_cat p
# is_cat B
# is_cat B
# is_cat S
# is_cat E
# is_cat M
# is_cat E
# is_cat R
# is_cat s
# is_cat s
# is_cat E
# is_cat B
# is_cat e
# is_cat B
# is_cat l
# is_cat s
# is_cat a
# is_cat p
# is_cat P
# is_cat k
# is_cat e
# is_cat R
# is_cat n
# is_cat R
# is_cat h
# is_cat p
# is_cat B
# is_cat s
# is_cat R
# is_cat p
# is_cat n
# is_cat s
# is_cat w
# is_cat A
# is_cat B
# is_cat a
# is_cat A
# is_cat s
# is_cat s
# is_cat M
# is_cat k
# is_cat g
# is_cat b
# is_cat S
# is_cat B
# is_cat s
# is_cat s
# is_cat R
# is_cat B
# is_cat w
# is_cat R
# is_cat M
# is_cat m
# is_cat b
# is_cat b
# is_cat y
# is_cat b
# is_cat n
# is_cat g
# is_cat y
# is_cat m
# is_cat k
# is_cat R
# is_cat s
# is_cat B
# is_cat g
# is_cat B
# is_cat B
# is_cat c
# is_cat b
# is_cat j
# is_cat B
# is_cat h
# is_cat E
# is_cat S
# is_cat n
# is_cat B
# is_cat a
# is_cat e
# is_cat R
# is_cat s
# is_cat B
# is_cat l
# is_cat s
# is_cat R
# is_cat h
# is_cat S
# is_cat n
# is_cat e
# is_cat s
# is_cat e
# is_cat R
# is_cat s
# is_cat h
# is_cat M
# is_cat w
# is_cat R
# is_cat a
# is_cat b
# is_cat g
# is_cat A
# is_cat b
# is_cat s
# is_cat s
# is_cat R
# is_cat S
# is_cat s
# is_cat p
# is_cat e
# is_cat s
# is_cat S
# is_cat g
# is_cat S
# is_cat b
# is_cat B
# is_cat e
# is_cat B
# is_cat B
# is_cat P
# is_cat c
# is_cat k
# is_cat B
# is_cat a
# is_cat g
# is_cat a
# is_cat b
# is_cat B
# is_cat S
# is_cat y
# is_cat h
# is_cat B
# is_cat R
# is_cat B
# is_cat c
# is_cat w
# is_cat s
# is_cat R
# is_cat E
# is_cat k
# is_cat p
# is_cat s
# is_cat n
# is_cat s
# is_cat a
# is_cat n
# is_cat p
# is_cat s
# is_cat B
# is_cat c
# is_cat c
# is_cat m
# is_cat B
# is_cat P
# is_cat B
# is_cat p
# is_cat M
# is_cat B
# is_cat m
# is_cat y
# is_cat S
# is_cat R
# is_cat S
# is_cat l
# is_cat s
# is_cat m
# is_cat B
# is_cat E
# is_cat c
# is_cat p
# is_cat P
# is_cat B
# is_cat c
# is_cat a
# is_cat b
# is_cat j
# is_cat p
# is_cat k
# is_cat p
# is_cat s
# is_cat B
# is_cat a
# is_cat e
# is_cat R
# is_cat P
# is_cat a
# is_cat w
# is_cat w
# is_cat p
# is_cat w
# is_cat m
# is_cat P
# is_cat s
# is_cat b
# is_cat h
# is_cat p
# is_cat B
# is_cat S
# is_cat s
# is_cat B
# is_cat s
# is_cat P
# is_cat b
# is_cat k
# is_cat p
# is_cat e
# is_cat b
# is_cat a
# is_cat a
# is_cat e
# is_cat c
# is_cat R
# is_cat w
# is_cat A
# is_cat A
# is_cat s
# is_cat c
# is_cat B
# is_cat l
# is_cat R
# is_cat s
# is_cat S
# is_cat k
# is_cat R
# is_cat P
# is_cat h
# is_cat c
# is_cat b
# is_cat M
# is_cat s
# is_cat g
# is_cat s
# is_cat n
# is_cat h
# is_cat S
# is_cat a
# is_cat b
# is_cat B
# is_cat w
# is_cat M
# is_cat s
# is_cat P
# is_cat s
# is_cat s
# is_cat e
# is_cat b
# is_cat y
# is_cat y
# is_cat s
# is_cat B
# is_cat E
# is_cat S
# is_cat g
# is_cat M
# is_cat a
# is_cat e
# is_cat n
# is_cat l
# is_cat S
# is_cat B
# is_cat y
# is_cat B
# is_cat P
# is_cat s
# is_cat l
# is_cat e
# is_cat B
# is_cat g
# is_cat l
# is_cat b
# is_cat a
# is_cat s
# is_cat a
# is_cat p
# is_cat s
# is_cat R
# is_cat S
# is_cat e
# is_cat B
# is_cat e
# is_cat S
# is_cat j
# is_cat w
# is_cat m
# is_cat y
# is_cat b
# is_cat c
# is_cat m
# is_cat p
# is_cat w
# is_cat S
# is_cat j
# is_cat w
# is_cat e
# is_cat s
# is_cat e
# is_cat h
# is_cat p
# is_cat s
# is_cat b
# is_cat s
# is_cat S
# is_cat A
# is_cat R
# is_cat g
# is_cat m
# is_cat j
# is_cat E
# is_cat e
# is_cat R
# is_cat S
# is_cat s
# is_cat c
# is_cat e
# is_cat c
# is_cat e
# is_cat j
# is_cat R
# is_cat s
# is_cat l
# is_cat S
# is_cat w
# is_cat l
# is_cat a
# is_cat B
# is_cat j
# is_cat y
# is_cat e
# is_cat p
# is_cat y
# is_cat a
# is_cat R
# is_cat a
# is_cat A
# is_cat s
# is_cat B
# is_cat R
# is_cat m
# is_cat g
# is_cat k
# is_cat b
# is_cat b
# is_cat S
# is_cat j
# is_cat k
# is_cat a
# is_cat b
# is_cat h
# is_cat m
# is_cat E
# is_cat B
# is_cat p
# is_cat c
# is_cat e
# is_cat M
# is_cat s
# is_cat b
# is_cat b
# is_cat B
# is_cat a
# is_cat S
# is_cat S
# is_cat h
# is_cat s
# is_cat a
# is_cat b
# is_cat s
# is_cat R
# is_cat s
# is_cat a
# is_cat B
# is_cat b
# is_cat s
# is_cat s
# is_cat R
# is_cat s
# is_cat h
# is_cat e
# is_cat b
# is_cat s
# is_cat s
# is_cat b
# is_cat y
# is_cat M
# is_cat s
# is_cat k
# is_cat b
# is_cat k
# is_cat h
# is_cat m
# is_cat s
# is_cat S
# is_cat P
# is_cat e
# is_cat b
# is_cat S
# is_cat p
# is_cat s
# is_cat B
# is_cat g
# is_cat m
# is_cat s
# is_cat j
# is_cat s
# is_cat s
# is_cat l
# is_cat A
# is_cat p
# is_cat P
# is_cat b
# is_cat y
# is_cat k
# is_cat y
# is_cat b
# is_cat h
# is_cat p
# is_cat s
# is_cat g
# is_cat b
# is_cat B
# is_cat B
# is_cat h
# is_cat B
# is_cat B
# is_cat e
# is_cat p
# is_cat b
# is_cat w
# is_cat R
# is_cat R
# is_cat e
# is_cat s
# is_cat b
# is_cat E
# is_cat j
# is_cat j
# is_cat s
# is_cat c
# is_cat A
# is_cat E
# is_cat S
# is_cat B
# is_cat a
# is_cat S
# is_cat s
# is_cat M
# is_cat R
# is_cat w
# is_cat b
# is_cat s
# is_cat E
# is_cat k
# is_cat g
# is_cat s
# is_cat R
# is_cat s
# is_cat B
# is_cat P
# is_cat s
# is_cat g
# is_cat c
# is_cat p
# is_cat n
# is_cat y
# is_cat m
# is_cat p
# is_cat B
# is_cat s
# is_cat b
# is_cat B
# is_cat b
# is_cat y
# is_cat P
# is_cat j
# is_cat e
# is_cat b
# is_cat s
# is_cat b
# is_cat e
# is_cat s
# is_cat B
# is_cat b
# is_cat s
# is_cat s
# is_cat k
# is_cat c
# is_cat g
# is_cat B
# is_cat b
# is_cat w
# is_cat P
# is_cat R
# is_cat s
# is_cat m
# is_cat h
# is_cat b
# is_cat B
# is_cat e
# is_cat s
# is_cat R
# is_cat s
# is_cat j
# is_cat c
# is_cat a
# is_cat c
# is_cat b
# is_cat g
# is_cat s
# is_cat B
# is_cat k
# is_cat B
# is_cat R
# is_cat M
# is_cat s
# is_cat s
# is_cat y
# is_cat p
# is_cat R
# is_cat B
# is_cat a
# is_cat S
# is_cat a
# is_cat g
# is_cat a
# is_cat j
# is_cat B
# is_cat B
# is_cat R
# is_cat b
# is_cat g
# is_cat a
# is_cat P
# is_cat B
# is_cat j
# is_cat e
# is_cat k
# is_cat n
# is_cat n
# is_cat w
# is_cat s
# is_cat B
# is_cat h
# is_cat p
# is_cat M
# is_cat B
# is_cat h
# is_cat B
# is_cat p
# is_cat e
# is_cat R
# is_cat s
# is_cat R
# is_cat B
# is_cat p
# is_cat c
# is_cat R
# is_cat A
# is_cat h
# is_cat s
# is_cat B
# is_cat h
# is_cat g
# is_cat g
# is_cat g
# is_cat k
# is_cat b
# is_cat M
# is_cat g
# is_cat b
# is_cat s
# is_cat p
# is_cat g
# is_cat s
# is_cat n
# is_cat B
# is_cat P
# is_cat S
# is_cat c
# is_cat n
# is_cat g
# is_cat M
# is_cat g
# is_cat j
# is_cat l
# is_cat m
# is_cat g
# is_cat R
# is_cat b
# is_cat p
# is_cat a
# is_cat s
# is_cat s
# is_cat B
# is_cat c
# is_cat s
# is_cat R
# is_cat j
# is_cat g
# is_cat l
# is_cat S
# is_cat h
# is_cat e
# is_cat M
# is_cat E
# is_cat A
# is_cat p
# is_cat P
# is_cat a
# is_cat n
# is_cat A
# is_cat S
# is_cat a
# is_cat b
# is_cat s
# is_cat b
# is_cat a
# is_cat E
# is_cat E
# is_cat s
# is_cat n
# is_cat l
# is_cat p
# is_cat p
# is_cat e
# is_cat s
# is_cat p
# is_cat s
# is_cat b
# is_cat l
# is_cat j
# is_cat b
# is_cat M
# is_cat S
# is_cat k
# is_cat E
# is_cat A
# is_cat m
# is_cat j
# is_cat b
# is_cat n
# is_cat A
# is_cat b
# is_cat b
# is_cat h
# is_cat s
# is_cat w
# is_cat c
# is_cat a
# is_cat s
# is_cat n
# is_cat p
# is_cat y
# is_cat w
# is_cat B
# is_cat h
# is_cat s
# is_cat w
# is_cat P
# is_cat B
# is_cat h
# is_cat g
# is_cat s
# is_cat B
# is_cat e
# is_cat b
# is_cat a
# is_cat B
# is_cat w
# is_cat B
# is_cat m
# is_cat j
# is_cat e
# is_cat h
# is_cat p
# is_cat B
# is_cat B
# is_cat B
# is_cat j
# is_cat k
# is_cat S
# is_cat E
# is_cat b
# is_cat A
# is_cat y
# is_cat k
# is_cat e
# is_cat s
# is_cat j
# is_cat e
# is_cat M
# is_cat S
# is_cat a
# is_cat g
# is_cat y
# is_cat h
# is_cat g
# is_cat B
# is_cat n
# is_cat w
# is_cat S
# is_cat y
# is_cat a
# is_cat p
# is_cat A
# is_cat B
# is_cat p
# is_cat E
# is_cat h
# is_cat n
# is_cat B
# is_cat y
# is_cat e
# is_cat b
# is_cat R
# is_cat B
# is_cat w
# is_cat y
# is_cat E
# is_cat b
# is_cat P
# is_cat p
# is_cat n
# is_cat l
# is_cat e
# is_cat M
# is_cat S
# is_cat g
# is_cat R
# is_cat w
# is_cat R
# is_cat p
# is_cat B
# is_cat c
# is_cat s
# is_cat p
# is_cat h
# is_cat e
# is_cat g
# is_cat s
# is_cat A
# is_cat a
# is_cat e
# is_cat B
# is_cat e
# is_cat y
# is_cat b
# is_cat p
# is_cat s
# is_cat R
# is_cat h
# is_cat g
# is_cat b
# is_cat e
# is_cat s
# is_cat n
# is_cat c
# is_cat g
# is_cat a
# is_cat k
# is_cat k
# is_cat c
# is_cat s
# is_cat S
# is_cat b
# is_cat S
# is_cat g
# is_cat a
# is_cat a
# is_cat y
# is_cat A
# is_cat j
# is_cat R
# is_cat n
# is_cat w
# is_cat B
# is_cat B
# is_cat A
# is_cat s
# is_cat P
# is_cat S
# is_cat m
# is_cat a
# is_cat M
# is_cat g
# is_cat j
# is_cat k
# is_cat s
# is_cat e
# is_cat B
# is_cat s
# is_cat B
# is_cat B
# is_cat p
# is_cat j
# is_cat w
# is_cat m
# is_cat w
# is_cat b
# is_cat m
# is_cat s
# is_cat A
# is_cat s
# is_cat B
# is_cat M
# is_cat c
# is_cat A
# is_cat s
# is_cat s
# is_cat b
# is_cat P
# is_cat w
# is_cat p
# is_cat R
# is_cat A
# is_cat B
# is_cat c
# is_cat l
# is_cat s
# is_cat s
# is_cat p
# is_cat b
# is_cat B
# is_cat p
# is_cat E
# is_cat y
# is_cat R
# is_cat B
# is_cat B
# is_cat R
# is_cat B
# is_cat s
# is_cat s
# is_cat B
# is_cat p
# is_cat s
# is_cat e
# is_cat B
# is_cat j
# is_cat g
# is_cat e
# is_cat R
# is_cat n
# is_cat g
# is_cat s
# is_cat a
# is_cat P
# is_cat j
# is_cat M
# is_cat s
# is_cat m
# is_cat S
# is_cat s
# is_cat l
# is_cat B
# is_cat n
# is_cat g
# is_cat a
# is_cat e
# is_cat l
# is_cat S
# is_cat m
# is_cat b
# is_cat b
# is_cat y
# is_cat j
# is_cat B
# is_cat e
# is_cat M
# is_cat M
# is_cat s
# is_cat g
# is_cat h
# is_cat S
# is_cat a
# is_cat g
# is_cat M
# is_cat s
# is_cat B
# is_cat A
# is_cat s
# is_cat b
# is_cat p
# is_cat P
# is_cat a
# is_cat p
# is_cat b
# is_cat s
# is_cat a
# is_cat b
# is_cat b
# is_cat B
# is_cat M
# is_cat p
# is_cat e
# is_cat a
# is_cat p
# is_cat l
# is_cat a
# is_cat b
# is_cat s
# is_cat w
# is_cat a
# is_cat M
# is_cat w
# is_cat S
# is_cat E
# is_cat M
# is_cat E
# is_cat B
# is_cat A
# is_cat B
# is_cat M
# is_cat a
# is_cat j
# is_cat w
# is_cat m
# is_cat B
# is_cat p
# is_cat s
# is_cat s
# is_cat s
# is_cat e
# is_cat g
# is_cat e
# is_cat B
# is_cat B
# is_cat m
# is_cat s
# is_cat e
# is_cat R
# is_cat B
# is_cat a
# is_cat l
# is_cat E
# is_cat B
# is_cat y
# is_cat b
# is_cat S
# is_cat b
# is_cat R
# is_cat n
# is_cat s
# is_cat g
# is_cat B
# is_cat a
# is_cat B
# is_cat p
# is_cat A
# is_cat s
# is_cat p
# is_cat g
# is_cat e
# is_cat a
# is_cat B
# is_cat b
# is_cat E
# is_cat p
# is_cat l
# is_cat A
# is_cat R
# is_cat b
# is_cat g
# is_cat s
# is_cat E
# is_cat B
# is_cat e
# is_cat n
# is_cat g
# is_cat l
# is_cat b
# is_cat P
# is_cat S
# is_cat B
# is_cat s
# is_cat R
# is_cat s
# is_cat S
# is_cat a
# is_cat B
# is_cat p
# is_cat E
# is_cat g
# is_cat b
# is_cat B
# is_cat E
# is_cat g
# is_cat B
# is_cat b
# is_cat E
# is_cat a
# is_cat w
# is_cat n
# is_cat R
# is_cat l
# is_cat g
# is_cat E
# is_cat E
# is_cat g
# is_cat b
# is_cat e
# is_cat s
# is_cat y
# is_cat w
# is_cat b
# is_cat j
# is_cat B
# is_cat g
# is_cat h
# is_cat h
# is_cat s
# is_cat b
# is_cat R
# is_cat b
# is_cat s
# is_cat p
# is_cat h
# is_cat y
# is_cat n
# is_cat A
# is_cat p
# is_cat s
# is_cat p
# is_cat A
# is_cat b
# is_cat s
# is_cat B
# is_cat R
# is_cat w
# is_cat M
# is_cat p
# is_cat s
# is_cat c
# is_cat c
# is_cat B
# is_cat k
# is_cat m
# is_cat S
# is_cat y
# is_cat m
# is_cat P
# is_cat p
# is_cat g
# is_cat k
# is_cat p
# is_cat B
# is_cat n
# is_cat n
# is_cat S
# is_cat l
# is_cat M
# is_cat A
# is_cat a
# is_cat S
# is_cat w
# is_cat p
# is_cat S
# is_cat a
# is_cat b
# is_cat s
# is_cat y
# is_cat B
# is_cat s
# is_cat e
# is_cat s
# is_cat h
# is_cat M
# is_cat a
# is_cat S
# is_cat A
# is_cat c
# is_cat s
# is_cat k
# is_cat w
# is_cat y
# is_cat s
# is_cat n
# is_cat M
# is_cat m
# is_cat g
# is_cat s
# is_cat s
# is_cat j
# is_cat P
# is_cat l
# is_cat a
# is_cat h
# is_cat B
# is_cat b
# is_cat g
# is_cat g
# is_cat s
# is_cat s
# is_cat l
# is_cat B
# is_cat s
# is_cat h
# is_cat b
# is_cat b
# is_cat m
# is_cat B
# is_cat a
# is_cat B
# is_cat B
# is_cat e
# is_cat A
# is_cat h
# is_cat R
# is_cat s
# is_cat S
# is_cat S
# is_cat c
# is_cat B
# is_cat S
# is_cat l
# is_cat c
# is_cat s
# is_cat g
# is_cat b
# is_cat a
# is_cat n
# is_cat g
# is_cat s
# is_cat e
# is_cat A
# is_cat E
# is_cat s
# is_cat B
# is_cat b
# is_cat s
# is_cat s
# is_cat p
# is_cat g
# is_cat j
# is_cat s
# is_cat b
# is_cat e
# is_cat k
# is_cat A
# is_cat j
# is_cat B
# is_cat c
# is_cat b
# is_cat R
# is_cat p
# is_cat p
# is_cat P
# is_cat s
# is_cat B
# is_cat M
# is_cat S
# is_cat j
# is_cat g
# is_cat e
# is_cat s
# is_cat b
# is_cat s
# is_cat E
# is_cat h
# is_cat A
# is_cat R
# is_cat e
# is_cat E
# is_cat S
# is_cat l
# is_cat s
# is_cat b
# is_cat a
# is_cat g
# is_cat k
# is_cat c
# is_cat R
# is_cat c
# is_cat c
# is_cat B
# is_cat s
# is_cat k
# is_cat b
# is_cat e
# is_cat M
# is_cat y
# is_cat j
# is_cat S
# is_cat s
# is_cat j
# is_cat M
# is_cat R
# is_cat B
# is_cat B
# is_cat a
# is_cat w
# is_cat e
# is_cat E
# is_cat p
# is_cat s
# is_cat E
# is_cat B
# is_cat a
# is_cat s
# is_cat g
# is_cat s
# is_cat j
# is_cat p
# is_cat s
# is_cat k
# is_cat b
# is_cat R
# is_cat e
# is_cat M
# is_cat R
# is_cat P
# is_cat b
# is_cat b
# is_cat h
# is_cat P
# is_cat E
# is_cat b
# is_cat E
# is_cat g
# is_cat E
# is_cat R
# is_cat B
# is_cat g
# is_cat p
# is_cat a
# is_cat E
# is_cat y
# is_cat a
# is_cat B
# is_cat E
# is_cat g
# is_cat p
# is_cat h
# is_cat a
# is_cat a
# is_cat b
# is_cat s
# is_cat m
# is_cat l
# is_cat p
# is_cat M
# is_cat p
# is_cat S
# is_cat g
# is_cat A
# is_cat n
# is_cat B
# is_cat b
# is_cat b
# is_cat B
# is_cat c
# is_cat S
# is_cat l
# is_cat m
# is_cat s
# is_cat n
# is_cat g
# is_cat s
# is_cat n
# is_cat s
# is_cat e
# is_cat b
# is_cat j
# is_cat y
# is_cat B
# is_cat R
# is_cat R
# is_cat b
# is_cat e
# is_cat M
# is_cat j
# is_cat b
# is_cat m
# is_cat M
# is_cat s
# is_cat E
# is_cat b
# is_cat B
# is_cat s
# is_cat e
# is_cat b
# is_cat R
# is_cat B
# is_cat y
# is_cat j
# is_cat b
# is_cat S
# is_cat g
# is_cat B
# is_cat w
# is_cat g
# is_cat b
# is_cat s
# is_cat y
# is_cat g
# is_cat e
# is_cat k
# is_cat s
# is_cat l
# is_cat E
# is_cat A
# is_cat B
# is_cat g
# is_cat g
# is_cat m
# is_cat E
# is_cat j
# is_cat B
# is_cat s
# is_cat m
# is_cat s
# is_cat w
# is_cat A
# is_cat S
# is_cat s
# is_cat R
# is_cat a
# is_cat b
# is_cat s
# is_cat s
# is_cat A
# is_cat s
# is_cat b
# is_cat B
# is_cat p
# is_cat E
# is_cat A
# is_cat l
# is_cat B
# is_cat s
# is_cat w
# is_cat B
# is_cat B
# is_cat m
# is_cat M
# is_cat B
# is_cat A
# is_cat p
# is_cat l
# is_cat b
# is_cat h
# is_cat A
# is_cat k
# is_cat p
# is_cat E
# is_cat c
# is_cat M
# is_cat p
# is_cat B
# is_cat b
# is_cat w
# is_cat A
# is_cat b
# is_cat w
# is_cat j
# is_cat b
# is_cat E
# is_cat k
# is_cat p
# is_cat A
# is_cat b
# is_cat b
# is_cat e
# is_cat R
# is_cat M
# is_cat m
# is_cat A
# is_cat E
# is_cat e
# is_cat e
# is_cat R
# is_cat h
# is_cat b
# is_cat s
# is_cat B
# is_cat n
# is_cat S
# is_cat s
# is_cat R
# is_cat b
# is_cat k
# is_cat b
# is_cat P
# is_cat w
# is_cat g
# is_cat g
# is_cat w
# is_cat b
# is_cat g
# is_cat B
# is_cat e
# is_cat B
# is_cat s
# is_cat g
# is_cat S
# is_cat h
# is_cat p
# is_cat g
# is_cat b
# is_cat e
# is_cat R
# is_cat e
# is_cat g
# is_cat A
# is_cat b
# is_cat B
# is_cat c
# is_cat l
# is_cat M
# is_cat B
# is_cat B
# is_cat s
# is_cat S
# is_cat y
# is_cat l
# is_cat B
# is_cat A
# is_cat e
# is_cat m
# is_cat S
# is_cat k
# is_cat S
# is_cat e
# is_cat P
# is_cat g

# %% [markdown]
# Now we can export our trained `Learner`. This contains all the information needed to run the model:

# %%
learn.export('model.pkl')

# %% [markdown]
# Finally, open the Kaggle sidebar on the right if it's not already, and find the section marked "Output". Open the `/kaggle/working` folder, and you'll see `model.pkl`. Click on it, then click on the menu on the right that appears, and choose "Download". After a few seconds, your model will be downloaded to your computer, where you can then create your app that uses the model.
